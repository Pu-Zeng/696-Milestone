# %%
# Train the CNN Emotion Regression Model with MIDI data#
# Last editted by Pu Zeng, 18/10/2023 #

# %%
import pandas as pd
from tqdm import tqdm
import os
from sklearn.model_selection import KFold
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from torch.utils.data import TensorDataset
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset
import string
import numpy as np
import pickle
from sklearn import preprocessing
import torch
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings
import json
warnings.filterwarnings('ignore')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Calculate the mean Arousal and Valence score from raw json data
def read_json_av(fileName):
    file = open(fileName,'r')
    lines = json.load(file)
    file.close()
    file = pd.DataFrame(pd.DataFrame(lines['pieces']).T['midi'])
    ann = pd.DataFrame(lines['annotations']).T.reset_index()
    file['arousal'] = np.nan
    file['valence'] = np.nan
    i = 1
    for i in range(len(file)):
        f = file.iloc[i]
        raw = ann[ann['index'].str.contains(f.name+'_')]
        ar = []
        va = []
        for j in range(len(raw)):
            row = raw.iloc[j]
            ar.append(np.mean(row['arousal']))
            va.append(np.mean(row['valence']))
        file['arousal'].iloc[i] = np.mean(ar)
        file['valence'].iloc[i] = np.mean(va)
    return file.reset_index()[['midi','arousal','valence']]

# %%
j1 = read_json_av('vgmidi_raw_1.json');
j2 = read_json_av('vgmidi_raw_2.json');
data = pd.concat([j1,j2],ignore_index=True)

# %%
# Transform MIDI into MFCCs

res1 = []
from midi2audio import FluidSynth
import librosa
import librosa.display
import pretty_midi
import numpy as np
def parse_piano_most(file_path):
    mean_intensity = []
    midi_data = pretty_midi.PrettyMIDI(file_path)
    for instrument in midi_data.instruments:
        mean_intensity.append(instrument.get_piano_roll().mean())
    instruments_to_remove_index = np.argsort(mean_intensity)[:-1]
    instruments_to_remove = []
    for i in instruments_to_remove_index:
        instruments_to_remove.append(midi_data.instruments[i])
    for i in instruments_to_remove:
        midi_data.instruments.remove(i)
    midi_data.instruments[0].program=0
    return midi_data

for i in tqdm(range(len(data))):
    # try:
        m = data.iloc[i]
        filename = 'midi/'+ m['midi']
        midi_data = parse_piano_most(filename)
        if midi_data == None:
            continue
        midi_data.write('1.mid')
        fs = FluidSynth();
        fs.midi_to_audio('1.mid', 'output.wav');
        y, sr = librosa.load('output.wav');
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
        res1.append([mfccs, m['arousal'],m['valence']])
    # except:
    #     pass
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [02:36<00:00,  1.28it/s]

# %%
# Organize the dataset
import numpy as np
midi = []
for m in res1:
    midi.append([m[0], [m[1],m[2]]])

# %%
# Find the minimum length to uniform all MFCCs to the same shape
dim = np.min([m[0].shape[1] for m in res1])
dim
# Out:
# 359

# %%
# Final dataset
from tqdm import tqdm
X = []
y = []
for m in res1:
    # X.append(m[0][:, :dim])
    X.append(m[0].T[0:dim,:])
    y.append([m[1], m[2]])
X = np.array(X)

# %%
# Define CNN regression model
class CNNModel(nn.Module):
    def __init__(self, hiddenSize, outChannels, dropoutRate, activate):
        super().__init__()
        self.outChannels = outChannels
        self.activate = nn.Sigmoid() if activate == "Sigmoid" else nn.ReLU()
        self.conv1 = nn.Conv2d(1, 24, (10,1))
        self.pool = nn.MaxPool2d((2, 1))
        
        self.conv2 = nn.Conv2d(24, 48, (10,1))
        self.bn1 = nn.BatchNorm2d(48)
        self.conv3 = nn.Conv2d(48, 96, (10,1))
        self.bn2 = nn.BatchNorm2d(96)
        self.conv4 = nn.Conv2d(96, 192, (10,2))
        self.bn3 = nn.BatchNorm2d(192)
        self.conv5 = nn.Conv2d(192, 96, (5,2))
        self.bn4 = nn.BatchNorm2d(96)
        self.conv6 = nn.Conv2d(96, 96, (5,2))
        self.dense1 = nn.Linear(1632, hiddenSize)
        self.dropout = nn.Dropout(dropoutRate)
        self.dense2 = nn.Linear(hiddenSize, 2)

    def forward(self, x):
        x = self.pool(self.activate(self.conv1(x)))
        x = self.pool(self.bn1(self.activate(self.conv2(x))))
        # print(x.shape)
        x = self.dropout(self.pool(self.bn2(self.activate(self.conv3(x)))))
        x = self.pool(self.bn3(self.activate(self.conv4(x))))
        x = self.pool(self.bn4(self.activate(self.conv5(x))))
        
        x = self.activate(self.conv6(x))
        # print(x.shape)
        x = x.view(-1, 1632)
        
        x = self.dropout(self.activate(self.dense1(x)))
        # print(self.dense2(x))
        return self.dense2(x)

# Number of neurons in the first fully-connected layer
hiddenSize = 64
# Number of feature filters in second convolutional layer
numFilters = 25
# Dropout rate
dropoutRate = 0.3
# Activation function
activation = "ReLU"
# Learning rate
learningRate = 0.001
# Momentum for SGD optimizer
momentum = 0.8
# Number of training epochs
numEpochs = 200

# %%
# Define Train and Validation function
from tqdm import tqdm
def train_epoch(cnn,device,dataloader,loss_fn,optimizer, m, std):
    cnn.train()
    cnnRunningLoss = 0
    total = 0
    R2 = 0
    for i, (inputs, labels) in enumerate(dataloader, 0):
        optimizer.zero_grad()
        # Normalization
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to(device)
        labels = labels.to(device)
        # Forward propagation
        cnnOutputs = cnn(inputs)

        l2_lambda = 0.01
        l2_reg = torch.tensor(0.).to(device)

        for param in cnn.parameters():
            l2_reg += torch.norm(param)

        # Backpropagation
        cnnLoss = criterion(cnnOutputs, labels)+l2_reg*l2_lambda
        cnnLoss.backward()

        # Gradient update
        optimizer.step()

        cnnRunningLoss += cnnLoss.item()
        total += 1
        # if (i+1) % 20 == 0:    # print every 2000 mini-batches
        #     print(cnnLoss)
        R2 += sklearn.metrics.r2_score(labels.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy())
    print('Training Loss {}, Trainging R-squared {}'.format(str(cnnRunningLoss/total), str(R2/total)))
    return cnnRunningLoss/total, R2
def valid_epoch(cnn,device,dataloader,loss_fn, m, std):
    cnn.eval()
    totalLoss = 0
    total = 0
    R2 = 0
    for inputs, labels in dataloader:
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to(device)
        labels = labels.to(device)
        cnnOutputs = cnn(inputs)
        cnnLoss = criterion(cnnOutputs, labels)#+l2_reg*l2_lambda
        # print(cnnLoss)
        totalLoss += cnnLoss.item()
        total +=1
        R2 += sklearn.metrics.r2_score(labels.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy())
    print('\nCNN validation R2: {}\n '.format(str(R2/total)))
    cnn.train()
    return totalLoss/total, R2

# %%
import sklearn
X_train_v, X_test, y_train_v, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train_v = torch.as_tensor(X_train_v, dtype=torch.float) # an alternative to torch.from_numpy
y_train_v = torch.as_tensor(y_train_v, dtype=torch.float)
X_test = torch.as_tensor(X_test, dtype=torch.float)
y_test = torch.as_tensor(y_test, dtype=torch.float)
splits=KFold(n_splits=5,shuffle=True,random_state=42)
train_dataset = TensorDataset(X_train_v, y_train_v)
test_dataset = TensorDataset(X_test, y_test)
batch_size=128
models = []
history = {'fold':[], 'train_loss': [], 'test_loss': [],'train_R2':[],'test_R2':[]}


for fold, (train_idx,val_idx) in enumerate(splits.split(np.arange(len(X_train_v)))):
    print('Fold {}'.format(fold + 1))
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(val_idx)
    m = np.vstack(X_train_v[train_idx]).mean()
    std = np.vstack(X_train_v[train_idx]).std()
    train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler)
    test_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=test_sampler)
    
    model = CNNModel(hiddenSize, numFilters, dropoutRate, activation).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(list(model.parameters()), lr=learningRate, momentum=momentum)
    # optimizer = torch.optim.Adam(list(model.parameters()), lr=learningRate)
    best_test = -np.inf
    best_model = None
    for epoch in range(numEpochs):
        train_loss, train_R2=train_epoch(model,device,train_loader,criterion,optimizer, m, std)
        test_loss, test_R2=valid_epoch(model,device,test_loader,criterion, m, std)
        history['fold'].append(fold)
        history['train_loss'].append(train_loss)
        history['test_loss'].append(test_loss)
        history['train_R2'].append(train_R2)
        history['test_R2'].append(test_R2)   
        if test_R2>best_test:
            best_test = test_R2
            best_model = model
    models.append([best_model, m, std])
# Out:
# Fold 1
# Training Loss 0.9273755252361298, Trainging R-squared -1.3782567892326163
#
# CNN validation R2: -0.5086311739202303
#
# Training Loss 0.9040835797786713, Trainging R-squared -1.0788417988039614
#
# CNN validation R2: -0.4785747489208222
#
# Training Loss 0.9011194705963135, Trainging R-squared -0.8503861317964605
#
# CNN validation R2: -0.4582107033905144
#
# Training Loss 0.8644276261329651, Trainging R-squared -0.28434256744384423
#
# CNN validation R2: -0.4492401209265596
#
# Training Loss 0.8742866516113281, Trainging R-squared -0.3815755203212378
#
# CNN validation R2: -0.4473756905780547
#
# Training Loss 0.8589869439601898, Trainging R-squared -0.19531721758056078
#
# CNN validation R2: -0.4501161168016833
#
# Training Loss 0.8557921051979065, Trainging R-squared -0.19595048127936943
#
# CNN validation R2: -0.45535639563035013
#
# Training Loss 0.8761054873466492, Trainging R-squared -0.31918485286935927
#
# CNN validation R2: -0.46357530454828333
#
# Training Loss 0.8557625114917755, Trainging R-squared -0.02029595972026188
#
# CNN validation R2: -0.4729915895238993
#
# Training Loss 0.8484633266925812, Trainging R-squared 0.08249435631368846
#
# CNN validation R2: -0.4843581740504589
#
# Training Loss 0.8523625135421753, Trainging R-squared -0.006478021871730105
#
# CNN validation R2: -0.4910790149741491
#
# Training Loss 0.8595894575119019, Trainging R-squared -0.07860261166786858
#
# CNN validation R2: -0.49175127547306297
#
# Training Loss 0.853359043598175, Trainging R-squared -0.1272157416934908
#
# CNN validation R2: -0.48474908893982127
#
# Training Loss 0.8489733636379242, Trainging R-squared 0.03930340720066633
#
# CNN validation R2: -0.4779310626974994
#
# Training Loss 0.8568353354930878, Trainging R-squared -0.13537743779953296
#
# CNN validation R2: -0.4709107715290416
#
# Training Loss 0.8547396659851074, Trainging R-squared -0.14250194557571483
#
# CNN validation R2: -0.4583070171586665
#
# Training Loss 0.8553688824176788, Trainging R-squared -0.009940360489567535
#
# CNN validation R2: -0.4416417643869852
#
# Training Loss 0.8535971343517303, Trainging R-squared -0.20939753373092343
#
# CNN validation R2: -0.42077927806532944
#
# Training Loss 0.8602132797241211, Trainging R-squared -0.060462052129888866
#
# CNN validation R2: -0.4001106195380276
#
# Training Loss 0.8429434299468994, Trainging R-squared 0.0020896063547908295
#
# CNN validation R2: -0.38225465391644664
#
# Training Loss 0.8548760414123535, Trainging R-squared -0.004587510036963061
#
# CNN validation R2: -0.36322999872270845
#
# Training Loss 0.8550565838813782, Trainging R-squared -0.11837305382977709
#
# CNN validation R2: -0.3393227247053513
#
# Training Loss 0.8523831963539124, Trainging R-squared -0.006687650002826534
#
# CNN validation R2: -0.3179427778194286
#
# Training Loss 0.8430988788604736, Trainging R-squared 0.12921069580977831
#
# CNN validation R2: -0.3000010647551976
#
# Training Loss 0.8526610434055328, Trainging R-squared -0.13221875585185333
#
# CNN validation R2: -0.2810677055174662
#
# Training Loss 0.8470557034015656, Trainging R-squared 0.07485663121825889
#
# CNN validation R2: -0.25460603679008353
#
# Training Loss 0.8496021032333374, Trainging R-squared 0.039418148117026736
#
# CNN validation R2: -0.22606793781706513
#
# Training Loss 0.8473582565784454, Trainging R-squared -0.11196057076163737
#
# CNN validation R2: -0.2037321296131419
#
# Training Loss 0.8465173542499542, Trainging R-squared 0.08057093148686484
#
# CNN validation R2: -0.16796259214768183
#
# Training Loss 0.8495307266712189, Trainging R-squared 0.043542774807941664
#
# CNN validation R2: -0.13135995961948665
#
# Training Loss 0.84254390001297, Trainging R-squared 0.1425895716328288
#
# CNN validation R2: -0.09247012071518557
#
# Training Loss 0.8442740738391876, Trainging R-squared 0.12325946092472567
#
# CNN validation R2: -0.06039112840847999
#
# Training Loss 0.8437665104866028, Trainging R-squared -0.026989790355555043
#
# CNN validation R2: -0.030805097052250874
#
# Training Loss 0.8563647270202637, Trainging R-squared 0.0004716587314730625
#
# CNN validation R2: -0.015273632530213022
#
# Training Loss 0.8490932881832123, Trainging R-squared 0.004997154849507385
#
# CNN validation R2: 0.00040296263592859427
#
# Training Loss 0.8502435982227325, Trainging R-squared -0.002384827574674564
#
# CNN validation R2: 0.02117080665955079
#
# Training Loss 0.845867395401001, Trainging R-squared 0.11473364069256342
#
# CNN validation R2: 0.037479992474309776
#
# Training Loss 0.8509399890899658, Trainging R-squared -0.01772260420187821
#
# CNN validation R2: 0.04527605673873125
#
# Training Loss 0.8436456322669983, Trainging R-squared 0.14328166210983853
#
# CNN validation R2: 0.04988097108143824
#
# Training Loss 0.8414235711097717, Trainging R-squared 0.038763327726070496
#
# CNN validation R2: 0.052351024817363034
#
# Training Loss 0.8331111967563629, Trainging R-squared 0.2923118712427545
#
# CNN validation R2: 0.05964179709476569
#
# Training Loss 0.8453462421894073, Trainging R-squared 0.12868152884600173
#
# CNN validation R2: 0.07370696257689763
#
# Training Loss 0.8413514792919159, Trainging R-squared 0.11945810542769203
#
# CNN validation R2: 0.09091587315172506
#
# Training Loss 0.8404267430305481, Trainging R-squared 0.09629158747984903
#
# CNN validation R2: 0.10829214325412667
#
# Training Loss 0.8444172739982605, Trainging R-squared -0.023915300820206514
#
# CNN validation R2: 0.1154050089483819
#
# Training Loss 0.844069629907608, Trainging R-squared 0.1680223676400857
#
# CNN validation R2: 0.12060946457656113
#
# Training Loss 0.8447113037109375, Trainging R-squared 0.10501613299820015
#
# CNN validation R2: 0.12438966054637712
#
# Training Loss 0.8413700759410858, Trainging R-squared 0.15173218147997197
#
# CNN validation R2: 0.1355428546766272
#
# Training Loss 0.8447249829769135, Trainging R-squared 0.11487494255808142
#
# CNN validation R2: 0.13994315512807215
#
# Training Loss 0.8402542471885681, Trainging R-squared 0.13795890496247906
#
# CNN validation R2: 0.1337110455088762
#
# Training Loss 0.8402718007564545, Trainging R-squared 0.05457488067686764
#
# CNN validation R2: 0.13055298217082079
#
# Training Loss 0.8439821302890778, Trainging R-squared 0.15618487438531498
#
# CNN validation R2: 0.13279942950250367
#
# Training Loss 0.8364535868167877, Trainging R-squared 0.235465812753158
#
# CNN validation R2: 0.13888733478321286
#
# Training Loss 0.8417657315731049, Trainging R-squared 0.11275353445425709
#
# CNN validation R2: 0.14207009355192124
#
# Training Loss 0.8418123126029968, Trainging R-squared 0.17667327822041648
#
# CNN validation R2: 0.1506936816012835
#
# Training Loss 0.8341267108917236, Trainging R-squared 0.2555119857426644
#
# CNN validation R2: 0.1646411954354074
#
# Training Loss 0.8432000577449799, Trainging R-squared 0.16846721796646758
#
# CNN validation R2: 0.1685791633189943
#
# Training Loss 0.8368583023548126, Trainging R-squared 0.3143416688294875
#
# CNN validation R2: 0.1657474636050465
#
# Training Loss 0.8369143903255463, Trainging R-squared 0.15303681967253516
#
# CNN validation R2: 0.1644297018587097
#
# Training Loss 0.8356373608112335, Trainging R-squared 0.22983982623039995
#
# CNN validation R2: 0.1623346299301776
#
# Training Loss 0.8341467976570129, Trainging R-squared 0.28769005035838724
#
# CNN validation R2: 0.16261239546613598
#
# Training Loss 0.8379941880702972, Trainging R-squared 0.25253915321327114
#
# CNN validation R2: 0.15560745847480406
#
# Training Loss 0.8400615751743317, Trainging R-squared 0.26445339657396827
#
# CNN validation R2: 0.14879139949541198
#
# Training Loss 0.8377625346183777, Trainging R-squared 0.21800837333819867
#
# CNN validation R2: 0.1261718847599615
#
# Training Loss 0.8335711359977722, Trainging R-squared 0.3072132699400115
#
# CNN validation R2: 0.11539783977478268
#
# Training Loss 0.8330782949924469, Trainging R-squared 0.3323301576246419
#
# CNN validation R2: 0.11170602682413189
#
# Training Loss 0.8371943831443787, Trainging R-squared 0.2536804239547542
#
# CNN validation R2: 0.12441502272156196
#
# Training Loss 0.834729790687561, Trainging R-squared 0.29333507642360684
#
# CNN validation R2: 0.1432160992506044
#
# Training Loss 0.8397206366062164, Trainging R-squared 0.1536369891906562
#
# CNN validation R2: 0.15062232816072202
#
# Training Loss 0.8424397706985474, Trainging R-squared 0.2675558144549589
#
# CNN validation R2: 0.1401770335699533
#
# Training Loss 0.8412342965602875, Trainging R-squared 0.2394698042395227
#
# CNN validation R2: 0.13020169105743123
#
# Training Loss 0.8389236330986023, Trainging R-squared 0.20681472856833993
#
# CNN validation R2: 0.12955244675679445
#
# Training Loss 0.8287407159805298, Trainging R-squared 0.4007308517703405
#
# CNN validation R2: 0.13409245110702844
#
# Training Loss 0.8397840857505798, Trainging R-squared 0.23202701206300974
#
# CNN validation R2: 0.14300679259996224
#
# Training Loss 0.8325799107551575, Trainging R-squared 0.3587028410985797
#
# CNN validation R2: 0.1455726195901112
#
# Training Loss 0.8374603688716888, Trainging R-squared 0.2688121421156492
#
# CNN validation R2: 0.14613060030509978
#
# Training Loss 0.8344987034797668, Trainging R-squared 0.3640894674136543
#
# CNN validation R2: 0.14222781299876902
#
# Training Loss 0.8317841589450836, Trainging R-squared 0.36260699450298517
#
# CNN validation R2: 0.1384495806633687
#
# Training Loss 0.8346630930900574, Trainging R-squared 0.29515200223515614
#
# CNN validation R2: 0.13580328148299803
#
# Training Loss 0.8366032540798187, Trainging R-squared 0.26185477513459265
#
# CNN validation R2: 0.13203288384208361
#
# Training Loss 0.8272981643676758, Trainging R-squared 0.4070384688604456
#
# CNN validation R2: 0.13231602808349474
#
# Training Loss 0.8339813649654388, Trainging R-squared 0.29438832868169235
#
# CNN validation R2: 0.13476005752434272
#
# Training Loss 0.8293048739433289, Trainging R-squared 0.37311369402452127
#
# CNN validation R2: 0.1376725123737833
#
# Training Loss 0.8344912528991699, Trainging R-squared 0.2761060993703858
#
# CNN validation R2: 0.13436906948690153
#
# Training Loss 0.8326350152492523, Trainging R-squared 0.3642347609484835
#
# CNN validation R2: 0.13004044290671324
#
# Training Loss 0.8335075974464417, Trainging R-squared 0.320748180877931
#
# CNN validation R2: 0.12528777843316896
#
# Training Loss 0.8389481008052826, Trainging R-squared 0.21059046449529709
#
# CNN validation R2: 0.12650629601925178
#
# Training Loss 0.830561637878418, Trainging R-squared 0.31526906919802133
#
# CNN validation R2: 0.13264873809880873
#
# Training Loss 0.825212687253952, Trainging R-squared 0.4547692979185308
#
# CNN validation R2: 0.14080754457853334
#
# Training Loss 0.8329502940177917, Trainging R-squared 0.31114860457869775
#
# CNN validation R2: 0.14655665479061464
#
# Training Loss 0.8342011868953705, Trainging R-squared 0.26192002224275335
#
# CNN validation R2: 0.1516407603887729
#
# Training Loss 0.8303655385971069, Trainging R-squared 0.34870460545828263
#
# CNN validation R2: 0.15305290582501235
#
# Training Loss 0.8303907215595245, Trainging R-squared 0.3547364441675699
#
# CNN validation R2: 0.1619767964933419
#
# Training Loss 0.8290033340454102, Trainging R-squared 0.22803111387565994
#
# CNN validation R2: 0.17460701912971943
#
# Training Loss 0.832260936498642, Trainging R-squared 0.2755755562175097
#
# CNN validation R2: 0.17484687472281507
#
# Training Loss 0.8353650569915771, Trainging R-squared 0.07957744584925858
#
# CNN validation R2: 0.16829827962818222
#
# Training Loss 0.8324685990810394, Trainging R-squared 0.3708878310015941
#
# CNN validation R2: 0.1719035385181124
#
# Training Loss 0.8398391604423523, Trainging R-squared 0.2689286611785631
#
# CNN validation R2: 0.17904233512412976
#
# Training Loss 0.8327867090702057, Trainging R-squared 0.30088332474032176
#
# CNN validation R2: 0.18818309803237132
#
# Training Loss 0.8343417346477509, Trainging R-squared 0.36217113476626095
#
# CNN validation R2: 0.1884361943681973
#
# Training Loss 0.8302677869796753, Trainging R-squared 0.3036334638475099
#
# CNN validation R2: 0.18666011956612044
#
# Training Loss 0.8381544351577759, Trainging R-squared 0.27866216415203937
#
# CNN validation R2: 0.17887077894587078
#
# Training Loss 0.8288403451442719, Trainging R-squared 0.39097954300469806
#
# CNN validation R2: 0.16866552860106065
#
# Training Loss 0.829240083694458, Trainging R-squared 0.3302159671064504
#
# CNN validation R2: 0.165231224025638
#
# Training Loss 0.8308455944061279, Trainging R-squared 0.3786048077783475
#
# CNN validation R2: 0.16439464559481476
#
# Training Loss 0.828536331653595, Trainging R-squared 0.39395319592792
#
# CNN validation R2: 0.1626213113827384
#
# Training Loss 0.8391653895378113, Trainging R-squared 0.2741084270675966
#
# CNN validation R2: 0.15495205376070031
#
# Training Loss 0.8384697437286377, Trainging R-squared 0.12219212246415082
#
# CNN validation R2: 0.15613503366504944
#
# Training Loss 0.8275254666805267, Trainging R-squared 0.2311559798517489
#
# CNN validation R2: 0.15814060420926218
#
# Training Loss 0.8279153406620026, Trainging R-squared 0.3150413822780638
#
# CNN validation R2: 0.15030950772063834
#
# Training Loss 0.8312996327877045, Trainging R-squared 0.15874713754010356
#
# CNN validation R2: 0.1435089851728944
#
# Training Loss 0.8285198211669922, Trainging R-squared 0.3459656899460063
#
# CNN validation R2: 0.14472070628656397
#
# Training Loss 0.8264213800430298, Trainging R-squared 0.3795345343113021
#
# CNN validation R2: 0.14559578255721728
#
# Training Loss 0.8293303549289703, Trainging R-squared 0.375650869087744
#
# CNN validation R2: 0.14489333940428917
#
# Training Loss 0.8324888050556183, Trainging R-squared 0.34583143631721314
#
# CNN validation R2: 0.1485329587065794
#
# Training Loss 0.823866069316864, Trainging R-squared 0.4062152269445527
#
# CNN validation R2: 0.15736596612188675
#
# Training Loss 0.8223773241043091, Trainging R-squared 0.4850662013681699
#
# CNN validation R2: 0.16468620759090824
#
# Training Loss 0.8282922804355621, Trainging R-squared 0.438686339312078
#
# CNN validation R2: 0.16923795281250104
#
# Training Loss 0.8254874050617218, Trainging R-squared 0.47029351999964575
#
# CNN validation R2: 0.17314860737598947
#
# Training Loss 0.833842933177948, Trainging R-squared 0.35794669912044236
#
# CNN validation R2: 0.1849481400935752
#
# Training Loss 0.8251249492168427, Trainging R-squared 0.3317314766770443
#
# CNN validation R2: 0.19528820049052054
#
# Training Loss 0.8276756703853607, Trainging R-squared 0.3345838478394234
#
# CNN validation R2: 0.18392578584446773
#
# Training Loss 0.8276971578598022, Trainging R-squared 0.44168591110820565
#
# CNN validation R2: 0.1793870872527173
#
# Training Loss 0.8262214362621307, Trainging R-squared 0.38141626082753755
#
# CNN validation R2: 0.1762843459268098
#
# Training Loss 0.8280652463436127, Trainging R-squared 0.3773702477371146
#
# CNN validation R2: 0.17726653995326974
#
# Training Loss 0.826276957988739, Trainging R-squared 0.39196011675530473
#
# CNN validation R2: 0.17103912679181937
#
# Training Loss 0.8338521420955658, Trainging R-squared 0.31354942179775214
#
# CNN validation R2: 0.15354815770790076
#
# Training Loss 0.8289273083209991, Trainging R-squared 0.32376622512631736
#
# CNN validation R2: 0.1527486852158842
#
# Training Loss 0.8256930410861969, Trainging R-squared 0.4310230316406523
#
# CNN validation R2: 0.15593694151542875
#
# Training Loss 0.8248257040977478, Trainging R-squared 0.43481918175961576
#
# CNN validation R2: 0.1597253339873302
#
# Training Loss 0.8262610137462616, Trainging R-squared 0.41945161899421535
#
# CNN validation R2: 0.16077393740819007
#
# Training Loss 0.8304873406887054, Trainging R-squared 0.2969780538683379
#
# CNN validation R2: 0.16046142227568755
#
# Training Loss 0.8360267877578735, Trainging R-squared 0.1592587336154071
#
# CNN validation R2: 0.15639128268013908
#
# Training Loss 0.8231503665447235, Trainging R-squared 0.4463405077331753
#
# CNN validation R2: 0.1616912755349192
#
# Training Loss 0.8317999541759491, Trainging R-squared 0.2218005957140739
#
# CNN validation R2: 0.1626288498764613
#
# Training Loss 0.8263230621814728, Trainging R-squared 0.4067401770310449
#
# CNN validation R2: 0.13941207448740095
#
# Training Loss 0.8225211799144745, Trainging R-squared 0.4257623746138075
#
# CNN validation R2: 0.1557843261522271
#
# Training Loss 0.82655268907547, Trainging R-squared 0.39963330664431657
#
# CNN validation R2: 0.17145916801453986
#
# Training Loss 0.8253636360168457, Trainging R-squared 0.4338621177171872
#
# CNN validation R2: 0.18274349829842218
#
# Training Loss 0.8279722332954407, Trainging R-squared 0.4290020709658097
#
# CNN validation R2: 0.18384737515811372
#
# Training Loss 0.8280030190944672, Trainging R-squared 0.3672245820356269
#
# CNN validation R2: 0.17806910926285702
#
# Training Loss 0.8244927823543549, Trainging R-squared 0.4226311004072939
#
# CNN validation R2: 0.17020991228796573
#
# Training Loss 0.8230291903018951, Trainging R-squared 0.5080886275870811
#
# CNN validation R2: 0.1578021518838036
#
# Training Loss 0.8230370879173279, Trainging R-squared 0.459322048217617
#
# CNN validation R2: 0.14717646664173306
#
# Training Loss 0.8265408277511597, Trainging R-squared 0.3903387144424069
#
# CNN validation R2: 0.14251704721331443
#
# Training Loss 0.8174625337123871, Trainging R-squared 0.4998141519555317
#
# CNN validation R2: 0.13984792851209016
#
# Training Loss 0.83002769947052, Trainging R-squared 0.14017326084835033
#
# CNN validation R2: 0.14361688967715064
#
# Training Loss 0.826540470123291, Trainging R-squared 0.43366270454755607
#
# CNN validation R2: 0.15160208911892564
#
# Training Loss 0.8253799080848694, Trainging R-squared 0.4575747039875836
#
# CNN validation R2: 0.1544277745095074
#
# Training Loss 0.8258090615272522, Trainging R-squared 0.48428503040800697
#
# CNN validation R2: 0.15280737881239337
#
# Training Loss 0.8229411244392395, Trainging R-squared 0.45167569478037994
#
# CNN validation R2: 0.14003235348617105
#
# Training Loss 0.8246817588806152, Trainging R-squared 0.4145949511341189
#
# CNN validation R2: 0.12924316487938797
#
# Training Loss 0.8177845478057861, Trainging R-squared 0.5542993866788926
#
# CNN validation R2: 0.1437046897005121
#
# Training Loss 0.8267837166786194, Trainging R-squared 0.1795093581941393
#
# CNN validation R2: 0.16675928323742567
#
# Training Loss 0.8220418691635132, Trainging R-squared 0.45496673759488915
#
# CNN validation R2: 0.1762193185727836
#
# Training Loss 0.8250711560249329, Trainging R-squared 0.4879272891181682
#
# CNN validation R2: 0.17400127984368585
#
# Training Loss 0.8204965889453888, Trainging R-squared 0.5361322869212957
#
# CNN validation R2: 0.16481232611038032
#
# Training Loss 0.8230650722980499, Trainging R-squared 0.43501378076166963
#
# CNN validation R2: 0.14863856916340473
#
# Training Loss 0.8247116208076477, Trainging R-squared 0.46465316814385693
#
# CNN validation R2: 0.13907980344411336
#
# Training Loss 0.8260391056537628, Trainging R-squared 0.45283947397420454
#
# CNN validation R2: 0.13678502704393009
#
# Training Loss 0.8229361474514008, Trainging R-squared 0.4203390324546325
#
# CNN validation R2: 0.14121241774426302
#
# Training Loss 0.8201449811458588, Trainging R-squared 0.5060788756014305
#
# CNN validation R2: 0.14969484823812373
#
# Training Loss 0.8257183134555817, Trainging R-squared 0.49583243814283895
#
# CNN validation R2: 0.15406316872543568
#
# Training Loss 0.818619430065155, Trainging R-squared 0.5263157406331339
#
# CNN validation R2: 0.154134828533383
#
# Training Loss 0.8222805559635162, Trainging R-squared 0.5284475477106987
#
# CNN validation R2: 0.16329571382521074
#
# Training Loss 0.8192672431468964, Trainging R-squared 0.36712974775684876
#
# CNN validation R2: 0.17422224879338805
#
# Training Loss 0.8196803331375122, Trainging R-squared 0.4890883938294097
#
# CNN validation R2: 0.17478283374885684
#
# Training Loss 0.8196383416652679, Trainging R-squared 0.5387580714166598
#
# CNN validation R2: 0.16822426874564883
#
# Training Loss 0.8225720822811127, Trainging R-squared 0.48988419477144385
#
# CNN validation R2: 0.15798568854235723
#
# Training Loss 0.8165520131587982, Trainging R-squared 0.5655655522950174
#
# CNN validation R2: 0.146455810131757
#
# Training Loss 0.8258010149002075, Trainging R-squared 0.4796929621436112
#
# CNN validation R2: 0.15182317810959972
#
# Training Loss 0.8156619369983673, Trainging R-squared 0.6050436375648496
#
# CNN validation R2: 0.16502577398625085
#
# Training Loss 0.8214970827102661, Trainging R-squared 0.49232959348190986
#
# CNN validation R2: 0.1703608108054926
#
# Training Loss 0.8232486248016357, Trainging R-squared 0.4133691221165462
#
# CNN validation R2: 0.17306715313846116
#
# Training Loss 0.822077065706253, Trainging R-squared 0.4521541457253567
#
# CNN validation R2: 0.1640894864038382
#
# Training Loss 0.8252798020839691, Trainging R-squared 0.4562515363060642
#
# CNN validation R2: 0.16351719669799264
#
# Training Loss 0.8186270594596863, Trainging R-squared 0.5041638378751077
#
# CNN validation R2: 0.15973429010153445
#
# Training Loss 0.8198248744010925, Trainging R-squared 0.5143229396359071
#
# CNN validation R2: 0.16406287047496637
#
# Training Loss 0.8222937881946564, Trainging R-squared 0.48043124655572844
#
# CNN validation R2: 0.16511803429176553
#
# Training Loss 0.8209724426269531, Trainging R-squared 0.4631587974764683
#
# CNN validation R2: 0.16677597386088544
#
# Training Loss 0.820283830165863, Trainging R-squared 0.5086708457414976
#
# CNN validation R2: 0.17209798610804816
#
# Training Loss 0.81833416223526, Trainging R-squared 0.5498775488167096
#
# CNN validation R2: 0.17581129300755038
#
# Training Loss 0.8217653632164001, Trainging R-squared 0.5547664113126419
#
# CNN validation R2: 0.18065001160839805
#
# Training Loss 0.8213838636875153, Trainging R-squared 0.5528688092016585
#
# CNN validation R2: 0.18790422364019288
#
# Training Loss 0.8189984858036041, Trainging R-squared 0.5212456336145385
#
# CNN validation R2: 0.18961665609706063
#
# Training Loss 0.8201393783092499, Trainging R-squared 0.45312924448051217
#
# CNN validation R2: 0.18772088769976064
#
# Training Loss 0.81678107380867, Trainging R-squared 0.5028085612995323
#
# CNN validation R2: 0.18831945453053456
#
# Training Loss 0.8189639151096344, Trainging R-squared 0.5798841010641096
#
# CNN validation R2: 0.1839163589034996
#
# Training Loss 0.8199073970317841, Trainging R-squared 0.516800737379857
#
# CNN validation R2: 0.18080146734547065
#
# Training Loss 0.8166460394859314, Trainging R-squared 0.6129439069385458
#
# CNN validation R2: 0.17863102235459088
#
# Training Loss 0.821809709072113, Trainging R-squared 0.4442386784851282
#
# CNN validation R2: 0.1769121169829193
#
# Training Loss 0.8189343810081482, Trainging R-squared 0.514868915596594
#
# CNN validation R2: 0.17396231737931828
#
# Training Loss 0.817369669675827, Trainging R-squared 0.594965765893317
#
# CNN validation R2: 0.16836149930539573
#
# Training Loss 0.8208937048912048, Trainging R-squared 0.5108186662298119
#
# CNN validation R2: 0.1669195955821443
#
# Training Loss 0.8136491179466248, Trainging R-squared 0.6047050976215673
#
# CNN validation R2: 0.16358055004358252
#
# Training Loss 0.8193478286266327, Trainging R-squared 0.5263953084533614
#
# CNN validation R2: 0.1653826815241911
#
# Training Loss 0.8144888281822205, Trainging R-squared 0.6260324127208088
#
# CNN validation R2: 0.16842143779546365
#
# Training Loss 0.8202736079692841, Trainging R-squared 0.5197694149575165
#
# CNN validation R2: 0.17043357249637847
#
# Training Loss 0.8182735741138458, Trainging R-squared 0.5642231653986918
#
# CNN validation R2: 0.1691127062352279
#
# Training Loss 0.8196854591369629, Trainging R-squared 0.5014014113310915
#
# CNN validation R2: 0.16693052947086295
#
# Fold 2
# Training Loss 0.8777345716953278, Trainging R-squared -0.5378113940340188
#
# CNN validation R2: -1.006448519069087
#
# Training Loss 0.8791635036468506, Trainging R-squared -0.49181018758907336
#
# CNN validation R2: -0.9801617364552495
#
# Training Loss 0.8746169209480286, Trainging R-squared -0.482853674123921
#
# CNN validation R2: -0.9354178193731559
#
# Training Loss 0.8672577738761902, Trainging R-squared -0.27229952772787913
#
# CNN validation R2: -0.8844508586398675
#
# Training Loss 0.855859100818634, Trainging R-squared -0.2530429457247958
#
# CNN validation R2: -0.829736323112902
#
# Training Loss 0.8670211136341095, Trainging R-squared -0.14720730690359757
#
# CNN validation R2: -0.7825804259884492
#
# Training Loss 0.8598833382129669, Trainging R-squared -0.10713393874094773
#
# CNN validation R2: -0.7393903396804509
#
# Training Loss 0.8621345460414886, Trainging R-squared -0.08616381296376738
#
# CNN validation R2: -0.7004603995424797
#
# Training Loss 0.8676274418830872, Trainging R-squared -0.3510245502269251
#
# CNN validation R2: -0.6687106308319966
#
# Training Loss 0.8457849323749542, Trainging R-squared 0.07756612837196308
#
# CNN validation R2: -0.643215601435281
#
# Training Loss 0.8495595753192902, Trainging R-squared -0.1727373926140413
#
# CNN validation R2: -0.6123826909521797
#
# Training Loss 0.8570775389671326, Trainging R-squared -0.08150983758548552
#
# CNN validation R2: -0.5648256575288713
#
# Training Loss 0.8520075678825378, Trainging R-squared -0.053655999058946746
#
# CNN validation R2: -0.5228005107796512
#
# Training Loss 0.857985109090805, Trainging R-squared -0.10071752787825841
#
# CNN validation R2: -0.4819404386258637
#
# Training Loss 0.8520585298538208, Trainging R-squared -0.05760706597425175
#
# CNN validation R2: -0.43530077616899554
#
# Training Loss 0.8566529452800751, Trainging R-squared -0.14964850906763472
#
# CNN validation R2: -0.39465459253503726
#
# Training Loss 0.8480222523212433, Trainging R-squared 0.012943788534062917
#
# CNN validation R2: -0.3565949489991578
#
# Training Loss 0.8482460677623749, Trainging R-squared -0.05962100558582925
#
# CNN validation R2: -0.32328583475102035
#
# Training Loss 0.8540445566177368, Trainging R-squared -0.037239498384751546
#
# CNN validation R2: -0.2990742855546763
#
# Training Loss 0.852323055267334, Trainging R-squared 0.010601708082024125
#
# CNN validation R2: -0.27742599657306166
#
# Training Loss 0.8479070365428925, Trainging R-squared 0.018269299745900996
#
# CNN validation R2: -0.2497837395385133
#
# Training Loss 0.8504880964756012, Trainging R-squared -0.07396977827327683
#
# CNN validation R2: -0.22207435152818944
#
# Training Loss 0.843593418598175, Trainging R-squared 0.11803366733763043
#
# CNN validation R2: -0.2098318377353161
#
# Training Loss 0.8459358513355255, Trainging R-squared 0.07893042684636853
#
# CNN validation R2: -0.2054365816185344
#
# Training Loss 0.8468962609767914, Trainging R-squared 0.07917863082593804
#
# CNN validation R2: -0.20886083588400794
#
# Training Loss 0.8488510549068451, Trainging R-squared 0.03397018471062127
#
# CNN validation R2: -0.21417821754289879
#
# Training Loss 0.8524397313594818, Trainging R-squared -0.02257573909177904
#
# CNN validation R2: -0.21994692875288857
#
# Training Loss 0.8445156216621399, Trainging R-squared 0.17674009025142076
#
# CNN validation R2: -0.21644273362314265
#
# Training Loss 0.8481592535972595, Trainging R-squared 0.12944925921295652
#
# CNN validation R2: -0.2177457603526437
#
# Training Loss 0.8399085104465485, Trainging R-squared 0.20935134829529878
#
# CNN validation R2: -0.2255967564955932
#
# Training Loss 0.8452209830284119, Trainging R-squared 0.06606054471455264
#
# CNN validation R2: -0.22523456534856173
#
# Training Loss 0.8458949327468872, Trainging R-squared 0.04293999931869305
#
# CNN validation R2: -0.2211057931595331
#
# Training Loss 0.8446611762046814, Trainging R-squared 0.08704106565620648
#
# CNN validation R2: -0.2164253260244589
#
# Training Loss 0.8369979560375214, Trainging R-squared 0.19963094772775777
#
# CNN validation R2: -0.206898180835973
#
# Training Loss 0.8507184386253357, Trainging R-squared 0.044529968769426304
#
# CNN validation R2: -0.19759131719768003
#
# Training Loss 0.8385480344295502, Trainging R-squared 0.1905829644226422
#
# CNN validation R2: -0.19097664456934638
#
# Training Loss 0.8516122400760651, Trainging R-squared 0.1377630686260617
#
# CNN validation R2: -0.17387213694990455
#
# Training Loss 0.8404074609279633, Trainging R-squared 0.19675855466127032
#
# CNN validation R2: -0.14866806022651113
#
# Training Loss 0.8489603698253632, Trainging R-squared 0.10384961254559327
#
# CNN validation R2: -0.12376102293442559
#
# Training Loss 0.8486407399177551, Trainging R-squared 0.025427930982757974
#
# CNN validation R2: -0.1104531299626011
#
# Training Loss 0.8365589678287506, Trainging R-squared 0.17264854390790524
#
# CNN validation R2: -0.09515092216119658
#
# Training Loss 0.8423958122730255, Trainging R-squared 0.11661720770564585
#
# CNN validation R2: -0.10024706671440287
#
# Training Loss 0.841778576374054, Trainging R-squared 0.11687682755942255
#
# CNN validation R2: -0.10992451095955436
#
# Training Loss 0.8392684757709503, Trainging R-squared 0.21438812040375152
#
# CNN validation R2: -0.11622315415271389
#
# Training Loss 0.8453323841094971, Trainging R-squared 0.12535382116909607
#
# CNN validation R2: -0.11280582516585669
#
# Training Loss 0.8430725932121277, Trainging R-squared 0.0605561478394282
#
# CNN validation R2: -0.08840208262357069
#
# Training Loss 0.8444540798664093, Trainging R-squared 0.14728380048796638
#
# CNN validation R2: -0.05380497601329187
#
# Training Loss 0.8374672830104828, Trainging R-squared 0.26252803230797034
#
# CNN validation R2: -0.03809328072159457
#
# Training Loss 0.8387396931648254, Trainging R-squared 0.23085087643073235
#
# CNN validation R2: -0.03408016969408889
#
# Training Loss 0.8464819490909576, Trainging R-squared 0.10105023353986176
#
# CNN validation R2: -0.03125707876145384
#
# Training Loss 0.8426730632781982, Trainging R-squared 0.055630134549156274
#
# CNN validation R2: -0.036948183829533576
#
# Training Loss 0.8408837616443634, Trainging R-squared 0.13353671732705014
#
# CNN validation R2: -0.055552061289260324
#
# Training Loss 0.8368211984634399, Trainging R-squared 0.23270646555975724
#
# CNN validation R2: -0.07173196226495754
#
# Training Loss 0.8363061845302582, Trainging R-squared 0.31305283342282686
#
# CNN validation R2: -0.08041448178858396
#
# Training Loss 0.8342306315898895, Trainging R-squared 0.29174807694609584
#
# CNN validation R2: -0.08441025966196158
#
# Training Loss 0.8407339751720428, Trainging R-squared 0.17574020278649682
#
# CNN validation R2: -0.09062709245918094
#
# Training Loss 0.8398131430149078, Trainging R-squared 0.18372643079465883
#
# CNN validation R2: -0.10770870778015096
#
# Training Loss 0.8337778449058533, Trainging R-squared 0.24591597223544784
#
# CNN validation R2: -0.1134925077081419
#
# Training Loss 0.8377960324287415, Trainging R-squared 0.1669655411548129
#
# CNN validation R2: -0.11105384518039779
#
# Training Loss 0.8418009579181671, Trainging R-squared 0.06099196488874814
#
# CNN validation R2: -0.10073497067724663
#
# Training Loss 0.8442796468734741, Trainging R-squared 0.15228008274779714
#
# CNN validation R2: -0.09233400830568395
#
# Training Loss 0.8414968550205231, Trainging R-squared 0.12756231578662502
#
# CNN validation R2: -0.08861403602226231
#
# Training Loss 0.8371648788452148, Trainging R-squared 0.2973316176270564
#
# CNN validation R2: -0.08678209804837428
#
# Training Loss 0.8377836346626282, Trainging R-squared 0.25819607985477666
#
# CNN validation R2: -0.0750913995681527
#
# Training Loss 0.83936408162117, Trainging R-squared 0.23375467129691707
#
# CNN validation R2: -0.06624773644584198
#
# Training Loss 0.8359806835651398, Trainging R-squared 0.26180091460803534
#
# CNN validation R2: -0.06570272467085442
#
# Training Loss 0.8464106917381287, Trainging R-squared 0.08928860282329953
#
# CNN validation R2: -0.06794901710577422
#
# Training Loss 0.8286698162555695, Trainging R-squared 0.3552859378332489
#
# CNN validation R2: -0.06848067473490849
#
# Training Loss 0.8320517539978027, Trainging R-squared 0.31890939557325854
#
# CNN validation R2: -0.0762728557736484
#
# Training Loss 0.838040828704834, Trainging R-squared 0.2883454589392882
#
# CNN validation R2: -0.07460114369849669
#
# Training Loss 0.8304983377456665, Trainging R-squared 0.2731972568814208
#
# CNN validation R2: -0.07735461414868333
#
# Training Loss 0.8326800167560577, Trainging R-squared 0.33308699395597224
#
# CNN validation R2: -0.06789128804427402
#
# Training Loss 0.84020134806633, Trainging R-squared 0.18730093428807576
#
# CNN validation R2: -0.056633166457329354
#
# Training Loss 0.8367069661617279, Trainging R-squared 0.2731784764618261
#
# CNN validation R2: -0.05029185560559424
#
# Training Loss 0.8381410837173462, Trainging R-squared 0.30279715388836803
#
# CNN validation R2: -0.027606719511909794
#
# Training Loss 0.8278792798519135, Trainging R-squared 0.36469759146845626
#
# CNN validation R2: -0.014825543666814267
#
# Training Loss 0.836605042219162, Trainging R-squared 0.27546544747581425
#
# CNN validation R2: -0.013098763663250246
#
# Training Loss 0.8350199460983276, Trainging R-squared 0.28495400918777714
#
# CNN validation R2: -0.011822647746384363
#
# Training Loss 0.8281624019145966, Trainging R-squared 0.370804303348797
#
# CNN validation R2: -0.010179598996903405
#
# Training Loss 0.8359874784946442, Trainging R-squared 0.23571862691206344
#
# CNN validation R2: -0.021656292014811784
#
# Training Loss 0.8402307331562042, Trainging R-squared 0.19552273200241005
#
# CNN validation R2: -0.04661657064252955
#
# Training Loss 0.8379164636135101, Trainging R-squared 0.2046757338684473
#
# CNN validation R2: -0.05162516313759569
#
# Training Loss 0.8313601315021515, Trainging R-squared 0.2864959647518487
#
# CNN validation R2: -0.07781678345927917
#
# Training Loss 0.8314309418201447, Trainging R-squared 0.30313330748110023
#
# CNN validation R2: -0.08598888130054105
#
# Training Loss 0.8297013938426971, Trainging R-squared 0.2780148954879122
#
# CNN validation R2: -0.07799966499275474
#
# Training Loss 0.8340820670127869, Trainging R-squared 0.2906426963518527
#
# CNN validation R2: -0.07481244711623725
#
# Training Loss 0.8354945778846741, Trainging R-squared 0.29215946043289753
#
# CNN validation R2: -0.049888442316648685
#
# Training Loss 0.8373914659023285, Trainging R-squared 0.23132202589793172
#
# CNN validation R2: -0.0453176500551728
#
# Training Loss 0.8347399234771729, Trainging R-squared 0.22745497549911944
#
# CNN validation R2: -0.04733088390858914
#
# Training Loss 0.8364626169204712, Trainging R-squared 0.24593049962161376
#
# CNN validation R2: -0.048328487027605116
#
# Training Loss 0.832790732383728, Trainging R-squared 0.32545098969775627
#
# CNN validation R2: -0.02985694368759778
#
# Training Loss 0.826737105846405, Trainging R-squared 0.4199780669340127
#
# CNN validation R2: -0.004973485677598588
#
# Training Loss 0.8281140923500061, Trainging R-squared 0.4079517701370445
#
# CNN validation R2: 0.009170376615357467
#
# Training Loss 0.8272998929023743, Trainging R-squared 0.4149278992751104
#
# CNN validation R2: 0.02136734751342162
#
# Training Loss 0.8316687643527985, Trainging R-squared 0.35342035406894845
#
# CNN validation R2: 0.02101384902059006
#
# Training Loss 0.8257397413253784, Trainging R-squared 0.45425340631799366
#
# CNN validation R2: 0.020013820466927124
#
# Training Loss 0.8276851773262024, Trainging R-squared 0.4301282383206736
#
# CNN validation R2: 0.008710984719555337
#
# Training Loss 0.8326278328895569, Trainging R-squared 0.24010968804236998
#
# CNN validation R2: 0.0016990916891217456
#
# Training Loss 0.8332865238189697, Trainging R-squared 0.24634796050495192
#
# CNN validation R2: 0.00417454439582754
#
# Training Loss 0.8230907618999481, Trainging R-squared 0.45089652437479655
#
# CNN validation R2: 0.014011669936443039
#
# Training Loss 0.8258766531944275, Trainging R-squared 0.4608989457442255
#
# CNN validation R2: 0.01561956655000546
#
# Training Loss 0.8255462944507599, Trainging R-squared 0.44779020777456185
#
# CNN validation R2: 0.022111743550744856
#
# Training Loss 0.8292363882064819, Trainging R-squared 0.4145870845008788
#
# CNN validation R2: 0.025986814489340038
#
# Training Loss 0.8275448381900787, Trainging R-squared 0.3684540355105883
#
# CNN validation R2: 0.019136312484621776
#
# Training Loss 0.8231121599674225, Trainging R-squared 0.3337476485285633
#
# CNN validation R2: 0.010776703268510823
#
# Training Loss 0.8390407860279083, Trainging R-squared 0.2615611826245241
#
# CNN validation R2: 0.011252205057661835
#
# Training Loss 0.8290348947048187, Trainging R-squared 0.3959348055498656
#
# CNN validation R2: 0.020088133883819415
#
# Training Loss 0.8312340974807739, Trainging R-squared 0.4274569261660224
#
# CNN validation R2: 0.018395154941380942
#
# Training Loss 0.8249208927154541, Trainging R-squared 0.43695444176949017
#
# CNN validation R2: 0.02734423843857603
#
# Training Loss 0.8235060572624207, Trainging R-squared 0.46197924309926264
#
# CNN validation R2: 0.03749275741336894
#
# Training Loss 0.8283473253250122, Trainging R-squared 0.3741708848368477
#
# CNN validation R2: 0.044909235028526506
#
# Training Loss 0.8335928022861481, Trainging R-squared 0.36616449515388116
#
# CNN validation R2: 0.043576574895928866
#
# Training Loss 0.8270275890827179, Trainging R-squared 0.4372820388074403
#
# CNN validation R2: 0.03144228821868589
#
# Training Loss 0.8299983441829681, Trainging R-squared 0.31203698341741815
#
# CNN validation R2: 0.01669490888943781
#
# Training Loss 0.8290225863456726, Trainging R-squared 0.33137705629954767
#
# CNN validation R2: 0.018647912858362203
#
# Training Loss 0.8216860294342041, Trainging R-squared 0.5208917992353298
#
# CNN validation R2: 0.014548308289489165
#
# Training Loss 0.8308119177818298, Trainging R-squared 0.30980941797327716
#
# CNN validation R2: 0.006112587459732921
#
# Training Loss 0.8226741552352905, Trainging R-squared 0.4133550145774464
#
# CNN validation R2: 0.0021795315806568683
#
# Training Loss 0.8224518895149231, Trainging R-squared 0.45441434054232355
#
# CNN validation R2: -0.015191813505025187
#
# Training Loss 0.8266582489013672, Trainging R-squared 0.43730887832393034
#
# CNN validation R2: -0.021360662175494982
#
# Training Loss 0.8266006410121918, Trainging R-squared 0.3804876938706008
#
# CNN validation R2: -0.0016119916411099222
#
# Training Loss 0.8259409368038177, Trainging R-squared 0.41194172606624
#
# CNN validation R2: 0.022552873016335795
#
# Training Loss 0.8294051587581635, Trainging R-squared 0.3123102565684388
#
# CNN validation R2: 0.03130740789072517
#
# Training Loss 0.8271081745624542, Trainging R-squared 0.3692262614652286
#
# CNN validation R2: 0.037126935647883386
#
# Training Loss 0.8281989991664886, Trainging R-squared 0.35009630865704344
#
# CNN validation R2: 0.054308864007231006
#
# Training Loss 0.8236838579177856, Trainging R-squared 0.4434804245522278
#
# CNN validation R2: 0.060619031147342683
#
# Training Loss 0.8261540532112122, Trainging R-squared 0.4389529489444419
#
# CNN validation R2: 0.04763374604764581
#
# Training Loss 0.8311140537261963, Trainging R-squared 0.3424900234696541
#
# CNN validation R2: 0.03183496656660645
#
# Training Loss 0.8272084295749664, Trainging R-squared 0.37543921340573905
#
# CNN validation R2: 0.009091028205543972
#
# Training Loss 0.8246616721153259, Trainging R-squared 0.4964316234515619
#
# CNN validation R2: -0.00750417237719464
#
# Training Loss 0.8244271874427795, Trainging R-squared 0.4491903939019259
#
# CNN validation R2: -0.024208201685908037
#
# Training Loss 0.8207886219024658, Trainging R-squared 0.5424823058864185
#
# CNN validation R2: -0.023371383670137247
#
# Training Loss 0.8254510164260864, Trainging R-squared 0.45185848172200993
#
# CNN validation R2: -0.0382908215112478
#
# Training Loss 0.8209506571292877, Trainging R-squared 0.5058873540767046
#
# CNN validation R2: -0.05348062254449598
#
# Training Loss 0.8251126706600189, Trainging R-squared 0.441983150080389
#
# CNN validation R2: -0.058450095828178616
#
# Training Loss 0.8270538747310638, Trainging R-squared 0.4103715755165542
#
# CNN validation R2: -0.05345780874121131
#
# Training Loss 0.8232192695140839, Trainging R-squared 0.500222512976777
#
# CNN validation R2: -0.040193219918798206
#
# Training Loss 0.8236077427864075, Trainging R-squared 0.4048542815469001
#
# CNN validation R2: -0.020544027832280987
#
# Training Loss 0.8248108625411987, Trainging R-squared 0.3919908650680476
#
# CNN validation R2: -0.010099735528334097
#
# Training Loss 0.8237080574035645, Trainging R-squared 0.4468840712072759
#
# CNN validation R2: -0.006774145700373435
#
# Training Loss 0.824348509311676, Trainging R-squared 0.3685809700999717
#
# CNN validation R2: -0.007435765960676133
#
# Training Loss 0.827168881893158, Trainging R-squared 0.41071116711128147
#
# CNN validation R2: -0.0028639394263632045
#
# Training Loss 0.8178490102291107, Trainging R-squared 0.5423104725166046
#
# CNN validation R2: 0.015560347399510066
#
# Training Loss 0.818993479013443, Trainging R-squared 0.5099539327899252
#
# CNN validation R2: 0.029057810816045693
#
# Training Loss 0.8260539770126343, Trainging R-squared 0.5035845663281256
#
# CNN validation R2: 0.05836150132858753
#
# Training Loss 0.8177174627780914, Trainging R-squared 0.4800671289394774
#
# CNN validation R2: 0.07460472961032849
#
# Training Loss 0.8186481893062592, Trainging R-squared 0.5421875333319828
#
# CNN validation R2: 0.08004763050978636
#
# Training Loss 0.8218640685081482, Trainging R-squared 0.47250460166810215
#
# CNN validation R2: 0.0728490188628329
#
# Training Loss 0.8233898878097534, Trainging R-squared 0.3421987343426178
#
# CNN validation R2: 0.07131410488561374
#
# Training Loss 0.8209279477596283, Trainging R-squared 0.47922376933275246
#
# CNN validation R2: 0.07530160539456199
#
# Training Loss 0.8225120902061462, Trainging R-squared 0.4779520092057232
#
# CNN validation R2: 0.06963985999815692
#
# Training Loss 0.8263512253761292, Trainging R-squared 0.38641914143517075
#
# CNN validation R2: 0.04774230531597767
#
# Training Loss 0.8197353482246399, Trainging R-squared 0.471222288810378
#
# CNN validation R2: 0.018462069677236015
#
# Training Loss 0.8191332519054413, Trainging R-squared 0.5128681956464155
#
# CNN validation R2: -0.00038826828907734257
#
# Training Loss 0.8185200989246368, Trainging R-squared 0.5368902215001623
#
# CNN validation R2: -0.004656629824447256
#
# Training Loss 0.8247795701026917, Trainging R-squared 0.4456709719029115
#
# CNN validation R2: 0.005013691497839701
#
# Training Loss 0.8180117607116699, Trainging R-squared 0.5900402112431679
#
# CNN validation R2: 0.008820057760636935
#
# Training Loss 0.8264255821704865, Trainging R-squared 0.40116847124765076
#
# CNN validation R2: 0.009201036071361024
#
# Training Loss 0.8231083750724792, Trainging R-squared 0.4889750567321884
#
# CNN validation R2: 0.0029210052614925264
#
# Training Loss 0.8191355764865875, Trainging R-squared 0.5576865260175987
#
# CNN validation R2: -0.011863970957496861
#
# Training Loss 0.8236286044120789, Trainging R-squared 0.41072501701037456
#
# CNN validation R2: -0.026165019337632878
#
# Training Loss 0.8268966972827911, Trainging R-squared 0.3626881856202729
#
# CNN validation R2: -0.027305897175935456
#
# Training Loss 0.8289136290550232, Trainging R-squared 0.37830006678879924
#
# CNN validation R2: -0.002260248858696301
#
# Training Loss 0.822174459695816, Trainging R-squared 0.5079909817111933
#
# CNN validation R2: 0.03830404593976533
#
# Training Loss 0.8199892342090607, Trainging R-squared 0.537464749837739
#
# CNN validation R2: 0.04328804341442105
#
# Training Loss 0.819044679403305, Trainging R-squared 0.5547082478036953
#
# CNN validation R2: 0.04359875701246524
#
# Training Loss 0.8233520984649658, Trainging R-squared 0.5084388834516894
#
# CNN validation R2: 0.051868180059589986
#
# Training Loss 0.822033166885376, Trainging R-squared 0.45983402188848865
#
# CNN validation R2: 0.045844662195659636
#
# Training Loss 0.8158408105373383, Trainging R-squared 0.5449173393797389
#
# CNN validation R2: 0.03471022762194825
#
# Training Loss 0.8205794095993042, Trainging R-squared 0.5700587671736574
#
# CNN validation R2: 0.037964736708711866
#
# Training Loss 0.8225504159927368, Trainging R-squared 0.4392916611152336
#
# CNN validation R2: 0.061920869317681204
#
# Training Loss 0.8206288814544678, Trainging R-squared 0.5511647158935455
#
# CNN validation R2: 0.10258827102128931
#
# Training Loss 0.8205058872699738, Trainging R-squared 0.46392204708348284
#
# CNN validation R2: 0.11941495491444182
#
# Training Loss 0.8164702653884888, Trainging R-squared 0.6100656824463853
#
# CNN validation R2: 0.11739626851690993
#
# Training Loss 0.8205872774124146, Trainging R-squared 0.4880440187810432
#
# CNN validation R2: 0.10375860132063652
#
# Training Loss 0.8208492398262024, Trainging R-squared 0.4376737412596993
#
# CNN validation R2: 0.08622965585413456
#
# Training Loss 0.8185598254203796, Trainging R-squared 0.5304697357033656
#
# CNN validation R2: 0.06887051458455473
#
# Training Loss 0.8161403834819794, Trainging R-squared 0.5789519384908406
#
# CNN validation R2: 0.0509077840149505
#
# Training Loss 0.8170727491378784, Trainging R-squared 0.5679543016907405
#
# CNN validation R2: 0.035833549281545585
#
# Training Loss 0.8221721053123474, Trainging R-squared 0.472470364550466
#
# CNN validation R2: 0.023819311395656406
#
# Training Loss 0.8191434741020203, Trainging R-squared 0.5342532519888156
#
# CNN validation R2: 0.0004069788266659602
#
# Training Loss 0.8202831149101257, Trainging R-squared 0.5152272347618484
#
# CNN validation R2: -0.00316714732064044
#
# Training Loss 0.8139267563819885, Trainging R-squared 0.5980478207094564
#
# CNN validation R2: 0.010081469265985632
#
# Training Loss 0.8168945908546448, Trainging R-squared 0.5626255445536277
#
# CNN validation R2: 0.013526439539979507
#
# Training Loss 0.8167974948883057, Trainging R-squared 0.5359438962115273
#
# CNN validation R2: 0.0029437723186815368
#
# Training Loss 0.8171955943107605, Trainging R-squared 0.5642960812321465
#
# CNN validation R2: 0.007950223947460255
#
# Training Loss 0.8207898139953613, Trainging R-squared 0.4529756623525839
#
# CNN validation R2: 0.017837420719289343
#
# Training Loss 0.8202723562717438, Trainging R-squared 0.466668090746844
#
# CNN validation R2: 0.012777634603351629
#
# Training Loss 0.8213387429714203, Trainging R-squared 0.3732699221412833
#
# CNN validation R2: 0.015525687302137992
#
# Training Loss 0.8180345892906189, Trainging R-squared 0.5510351237526203
#
# CNN validation R2: 0.022222467859080552
#
# Training Loss 0.8162432610988617, Trainging R-squared 0.5380554489289073
#
# CNN validation R2: 0.016229800507918557
#
# Training Loss 0.8191929757595062, Trainging R-squared 0.5499174792517021
#
# CNN validation R2: 0.010317318383719964
#
# Training Loss 0.8172763288021088, Trainging R-squared 0.5221264052091222
#
# CNN validation R2: 0.006377745518948041
#
# Training Loss 0.815874308347702, Trainging R-squared 0.5176792818895257
#
# CNN validation R2: 0.006985003426040859
#
# Training Loss 0.8158926963806152, Trainging R-squared 0.5861293081228593
#
# CNN validation R2: 0.019506970791472844
#
# Training Loss 0.8174099028110504, Trainging R-squared 0.5458370384494025
#
# CNN validation R2: 0.026016874627632247
#
# Training Loss 0.8188534677028656, Trainging R-squared 0.5808995312589618
#
# CNN validation R2: 0.03099233797797446
#
# Training Loss 0.8155142664909363, Trainging R-squared 0.4633712832397531
#
# CNN validation R2: 0.03456411819087918
#
# Training Loss 0.8155819773674011, Trainging R-squared 0.56459763769884
#
# CNN validation R2: 0.02439335434629425
#
# Training Loss 0.8184315860271454, Trainging R-squared 0.5017303169348021
#
# CNN validation R2: 0.024533207971519977
#
# Fold 3
# Training Loss 0.8678162097930908, Trainging R-squared -0.32587691607255814
#
# CNN validation R2: -0.0009354424895797742
#
# Training Loss 0.8705069124698639, Trainging R-squared -0.37302340597095174
#
# CNN validation R2: -0.0008756423976525873
#
# Training Loss 0.8575527369976044, Trainging R-squared -0.2445733957553374
#
# CNN validation R2: -0.0010420892084445077
#
# Training Loss 0.8600738644599915, Trainging R-squared -0.15894399458677677
#
# CNN validation R2: -0.0016817861796979416
#
# Training Loss 0.8561988174915314, Trainging R-squared -0.10852802248786089
#
# CNN validation R2: -0.0017885976343182675
#
# Training Loss 0.8534922897815704, Trainging R-squared -0.05092471682418559
#
# CNN validation R2: -0.0021052803771135498
#
# Training Loss 0.8677607178688049, Trainging R-squared -0.32631736735857464
#
# CNN validation R2: -0.002184559329991509
#
# Training Loss 0.8544604778289795, Trainging R-squared -0.2744764210581811
#
# CNN validation R2: -0.0023763291541127884
#
# Training Loss 0.865816205739975, Trainging R-squared -0.3404096938645731
#
# CNN validation R2: -0.0016765900352384011
#
# Training Loss 0.8501763939857483, Trainging R-squared -0.03466558227344399
#
# CNN validation R2: -0.0012804366123211897
#
# Training Loss 0.8510770499706268, Trainging R-squared -0.09546310561110866
#
# CNN validation R2: -0.0011631033479925224
#
# Training Loss 0.8496038913726807, Trainging R-squared -0.04489159214660732
#
# CNN validation R2: -0.0018805629636277632
#
# Training Loss 0.8508490324020386, Trainging R-squared -0.004318069980088074
#
# CNN validation R2: -0.0018550510844282941
#
# Training Loss 0.8557327091693878, Trainging R-squared -0.08801784916352842
#
# ...
#
# Training Loss 0.8326992988586426, Trainging R-squared 0.2925120601406671
#
# CNN validation R2: 0.05552548571302801
#
# Training Loss 0.8251813054084778, Trainging R-squared 0.37408917296896815
#
# CNN validation R2: 0.04890898227845758
#
# Training Loss 0.8284006118774414, Trainging R-squared 0.3503824077852275
#
# CNN validation R2: 0.04345333014442854
#
# Training Loss 0.8298326134681702, Trainging R-squared 0.22660275637372143
#
# CNN validation R2: 0.037236465219277204
#
# Training Loss 0.8285592198371887, Trainging R-squared 0.28434079290947856
#
# CNN validation R2: 0.03293389305656552
#
# Training Loss 0.8343565165996552, Trainging R-squared 0.331059954004112
#
# CNN validation R2: 0.03430068626764382
#
# Training Loss 0.8279887437820435, Trainging R-squared 0.4071248957475492
#
# CNN validation R2: 0.03606477929533625
#
# Training Loss 0.8315885365009308, Trainging R-squared 0.26387392335276383
#
# CNN validation R2: 0.034527894353807764
#
# Training Loss 0.8267854750156403, Trainging R-squared 0.3406711325515359
#
# CNN validation R2: 0.04412762106082457
#
# Training Loss 0.8295824229717255, Trainging R-squared 0.2744750924263247
#
# CNN validation R2: 0.05091278028806334
#
# Training Loss 0.8298407196998596, Trainging R-squared 0.27570706373388554
#
# CNN validation R2: 0.05078006235708238
#
# Training Loss 0.8277400434017181, Trainging R-squared 0.24601798421623058
#
# CNN validation R2: 0.05360581704707629
#
# Training Loss 0.8339262902736664, Trainging R-squared 0.23129335894779202
#
# CNN validation R2: 0.048408353580822516
#
# Training Loss 0.8284150958061218, Trainging R-squared 0.3374067031113683
#
# CNN validation R2: 0.0449303652172493
#
# Training Loss 0.8319809138774872, Trainging R-squared 0.3735372789070952
#
# CNN validation R2: 0.042657627257812414
#
# Training Loss 0.8276959657669067, Trainging R-squared 0.3470196850912527
#
# CNN validation R2: 0.04166175118902671
#
# Training Loss 0.8274517059326172, Trainging R-squared 0.36229681237815653
#
# CNN validation R2: 0.03803489414556621
#
# Training Loss 0.830423504114151, Trainging R-squared 0.24388854054611825
#
# CNN validation R2: 0.03247308027723256
#
# Training Loss 0.8229311406612396, Trainging R-squared 0.3910043341655943
#
# CNN validation R2: 0.034499236542683775
#
# Training Loss 0.832877516746521, Trainging R-squared 0.31875889132875024
#
# CNN validation R2: 0.035867389816789
#
# Training Loss 0.827748566865921, Trainging R-squared 0.33438515058053964
#
# CNN validation R2: 0.039818693045138465
#
# Training Loss 0.8255418837070465, Trainging R-squared 0.41207539457995346
#
# CNN validation R2: 0.04469875092640341
#
# Training Loss 0.8340929448604584, Trainging R-squared 0.2763893473511234
#
# CNN validation R2: 0.043749317940096455
#
# Training Loss 0.8284604549407959, Trainging R-squared 0.37724160477742785
#
# CNN validation R2: 0.03883582895494947
#
# Training Loss 0.8224370777606964, Trainging R-squared 0.4289609128663032
#
# CNN validation R2: 0.03564931358085832
#
# Training Loss 0.827688068151474, Trainging R-squared 0.22904795850992282
#
# CNN validation R2: 0.03689173192559392
#
# Training Loss 0.8214104473590851, Trainging R-squared 0.3099024768090207
#
# CNN validation R2: 0.04038846621658432
#
# Training Loss 0.8228415846824646, Trainging R-squared 0.4618859537466342
#
# CNN validation R2: 0.04298081840986423
#
# Training Loss 0.8298037648200989, Trainging R-squared 0.32658798371324255
#
# CNN validation R2: 0.04111893198146316
#
# Training Loss 0.8236846327781677, Trainging R-squared 0.42086359428715525
#
# CNN validation R2: 0.038942889052965834
#
# Training Loss 0.8214997351169586, Trainging R-squared 0.45099873963818965
#
# CNN validation R2: 0.03690048917280109
#
# Training Loss 0.824171632528305, Trainging R-squared 0.3714611566846082
#
# CNN validation R2: 0.03618152915377071
#
# Training Loss 0.8221378922462463, Trainging R-squared 0.4578085074893157
#
# CNN validation R2: 0.037149213220449895
#
# Training Loss 0.8237549960613251, Trainging R-squared 0.3706284615072504
#
# CNN validation R2: 0.036957400189571055
#
# Training Loss 0.8232941031455994, Trainging R-squared 0.41716250060068394
#
# CNN validation R2: 0.0361322527375863
#
# Training Loss 0.8222555816173553, Trainging R-squared 0.5029043907560957
#
# CNN validation R2: 0.03418102225889841
#
# Training Loss 0.823449045419693, Trainging R-squared 0.3893138106727743
#
# CNN validation R2: 0.029461765899465475
#
# Training Loss 0.8218717575073242, Trainging R-squared 0.3868719303249092
#
# CNN validation R2: 0.023920812216823628
#
# Training Loss 0.8233112096786499, Trainging R-squared 0.4497848577486084
#
# CNN validation R2: 0.027160795318793896
#
# Training Loss 0.8307913839817047, Trainging R-squared 0.3544984653153762
#
# CNN validation R2: 0.026801936101636337
#
# Training Loss 0.8276098668575287, Trainging R-squared 0.3090400695982256
#
# CNN validation R2: 0.032790263910532746
#
# Training Loss 0.822012335062027, Trainging R-squared 0.3976292700204835
#
# CNN validation R2: 0.03292001523637694
#
# Training Loss 0.8209245502948761, Trainging R-squared 0.5045828748712582
#
# CNN validation R2: 0.025639701062709574
#
# Training Loss 0.8236179947853088, Trainging R-squared 0.3656152517629444
#
# CNN validation R2: 0.018925365001333516
#
# Training Loss 0.8215746879577637, Trainging R-squared 0.45116850022935706
#
# CNN validation R2: 0.01086255158517746
#
# Training Loss 0.8282228112220764, Trainging R-squared 0.37117572637350116
#
# CNN validation R2: 0.012085075945797108
#
# Training Loss 0.8245582580566406, Trainging R-squared 0.4410126568862145
#
# CNN validation R2: 0.00937889281371973
#
# Training Loss 0.8186923861503601, Trainging R-squared 0.507110518404263
#
# CNN validation R2: 0.0063838282191286955
#
# Training Loss 0.8214277029037476, Trainging R-squared 0.3348707784943884
#
# CNN validation R2: 0.0035194613156944166
#
# Training Loss 0.8259021937847137, Trainging R-squared 0.28918843705079755
#
# CNN validation R2: 0.006450667631419549
#
# Training Loss 0.8188316822052002, Trainging R-squared 0.46868770308418917
#
# CNN validation R2: 0.009305511557210044
#
# Training Loss 0.8253419697284698, Trainging R-squared 0.43720945426601265
#
# CNN validation R2: 0.01053925224325708
#
# Training Loss 0.8188696503639221, Trainging R-squared 0.5322933727442032
#
# CNN validation R2: 0.013377101621143306
#
# Training Loss 0.8195962011814117, Trainging R-squared 0.4109238814775322
#
# CNN validation R2: 0.014722937374375189
#
# Training Loss 0.826481282711029, Trainging R-squared 0.3672093514331324
#
# CNN validation R2: 0.013816545474414743
#
# Training Loss 0.8242276906967163, Trainging R-squared 0.3573274684810217
#
# CNN validation R2: 0.005399644756687694
#
# Training Loss 0.8213580250740051, Trainging R-squared 0.4347217526316714
#
# CNN validation R2: -0.0022167312472128886
#
# Training Loss 0.8250592052936554, Trainging R-squared 0.40096416727891815
#
# CNN validation R2: -0.007102244313760164
#
# Training Loss 0.8155581057071686, Trainging R-squared 0.5409130174605126
#
# CNN validation R2: -0.008052616965442794
#
# Training Loss 0.823863297700882, Trainging R-squared 0.46081837768513406
#
# CNN validation R2: -0.006722655691541957
#
# Training Loss 0.8249995410442352, Trainging R-squared 0.39653451021644603
#
# CNN validation R2: -0.003210362382259191
#
# Training Loss 0.8231680691242218, Trainging R-squared 0.26529411462462155
#
# CNN validation R2: 0.0005495054654068854
#
# Training Loss 0.820550411939621, Trainging R-squared 0.48162992503039836
#
# CNN validation R2: 0.005430513366309342
#
# Training Loss 0.8203825056552887, Trainging R-squared 0.4662593647201069
#
# CNN validation R2: 0.016535918612919975
#
# Training Loss 0.8189109265804291, Trainging R-squared 0.5164049403805244
#
# CNN validation R2: 0.017754440037062225
#
# Training Loss 0.8177480399608612, Trainging R-squared 0.5431441472399949
#
# CNN validation R2: 0.01223314704720413
#
# Training Loss 0.8130576908588409, Trainging R-squared 0.5726261656981686
#
# CNN validation R2: 0.008675065500530876
#
# Training Loss 0.819096177816391, Trainging R-squared 0.47873797443843713
#
# CNN validation R2: 0.008209897565185365
#
# Training Loss 0.8238497674465179, Trainging R-squared 0.4026980912811706
#
# CNN validation R2: 0.009998522204943183
#
# Training Loss 0.8223822712898254, Trainging R-squared 0.3419939196148867
#
# CNN validation R2: 0.013987098850150814
#
# Training Loss 0.8194017708301544, Trainging R-squared 0.5204609134758431
#
# CNN validation R2: 0.01747488114674589
#
# Training Loss 0.8174050748348236, Trainging R-squared 0.4559904869487037
#
# CNN validation R2: 0.02036265515896829
#
# Training Loss 0.8181981444358826, Trainging R-squared 0.521864423232395
#
# CNN validation R2: 0.022080736046514726
#
# Training Loss 0.818440705537796, Trainging R-squared 0.5255312676473347
#
# CNN validation R2: 0.02164903077507313
#
# Training Loss 0.8198008835315704, Trainging R-squared 0.4731540318508615
#
# CNN validation R2: 0.021848973609568112
#
# Training Loss 0.8167440295219421, Trainging R-squared 0.5647940400761406
#
# CNN validation R2: 0.02291978468775835
#
# Training Loss 0.8203461170196533, Trainging R-squared 0.4848740953741356
#
# CNN validation R2: 0.019025452600889226
#
# Training Loss 0.8170435428619385, Trainging R-squared 0.5045615901898369
#
# CNN validation R2: 0.016370648168478275
#
# Training Loss 0.8207595348358154, Trainging R-squared 0.4935212163079075
#
# CNN validation R2: 0.0210695679911021
#
# Training Loss 0.8203733861446381, Trainging R-squared 0.5118031837470447
#
# CNN validation R2: 0.023018502808009822
#
# Training Loss 0.8180656135082245, Trainging R-squared 0.44266761731981774
#
# CNN validation R2: 0.01725044789375335
#
# Training Loss 0.8177337050437927, Trainging R-squared 0.4702417610416891
#
# CNN validation R2: 0.017780702242264024
#
# Training Loss 0.8214187920093536, Trainging R-squared 0.4071827148818566
#
# CNN validation R2: 0.022880282012007425
#
# Training Loss 0.8161199390888214, Trainging R-squared 0.4995098888544253
#
# CNN validation R2: 0.03223746311866604
#
# Training Loss 0.8222958147525787, Trainging R-squared 0.44081569234882745
#
# CNN validation R2: 0.037153312119783066
#
# Training Loss 0.8177265822887421, Trainging R-squared 0.5110683719398963
#
# CNN validation R2: 0.03889828228244724
#
# Training Loss 0.8214867413043976, Trainging R-squared 0.48527606839518483
#
# CNN validation R2: 0.03655935932151305
#
# Training Loss 0.8233719170093536, Trainging R-squared 0.4478728190933531
#
# CNN validation R2: 0.0374979043477221
#
# Training Loss 0.819598376750946, Trainging R-squared 0.46687291224835614
#
# CNN validation R2: 0.03501047587663081
#
# Training Loss 0.8171815276145935, Trainging R-squared 0.5454267322484413
#
# CNN validation R2: 0.03248715458618162
#
# Training Loss 0.8190476894378662, Trainging R-squared 0.4078355603057444
#
# CNN validation R2: 0.028100653449941948
#
# Training Loss 0.8188279271125793, Trainging R-squared 0.42773436857957936
#
# CNN validation R2: 0.02734466625526738
#
# Training Loss 0.8200287520885468, Trainging R-squared 0.4866988837278191
#
# CNN validation R2: 0.024880278745375073
#
# Training Loss 0.8112714290618896, Trainging R-squared 0.5722384448655765
#
# CNN validation R2: 0.029458326055933348
#
# Training Loss 0.8148057758808136, Trainging R-squared 0.5421016720293756
#
# CNN validation R2: 0.030706205384521845
#
# Training Loss 0.8148709535598755, Trainging R-squared 0.5482683132602364
#
# CNN validation R2: 0.03011923922158488
#
# Training Loss 0.8160167634487152, Trainging R-squared 0.5024859545506608
#
# CNN validation R2: 0.024527721919774814
#
# Training Loss 0.8165670335292816, Trainging R-squared 0.4706274877542149
#
# CNN validation R2: 0.021607599487934837
#
# Training Loss 0.8155996203422546, Trainging R-squared 0.547773266749507
#
# CNN validation R2: 0.022333870138917133
#
# Training Loss 0.816455066204071, Trainging R-squared 0.5022048886628352
#
# CNN validation R2: 0.02047285985307873
#
# Training Loss 0.8167562484741211, Trainging R-squared 0.5452781638390695
#
# CNN validation R2: 0.01535124566049001
#
# Training Loss 0.8144670724868774, Trainging R-squared 0.5505823206576622
#
# CNN validation R2: 0.006612912129087434
#
# Training Loss 0.8168954253196716, Trainging R-squared 0.4936617840105644
#
# CNN validation R2: 0.006212665753233315
#
# Training Loss 0.8163373470306396, Trainging R-squared 0.5230727221310937
#
# CNN validation R2: 0.004629543748593978
#
# Training Loss 0.8169878721237183, Trainging R-squared 0.3228677150835077
#
# CNN validation R2: 0.008792467058427622
#
# Training Loss 0.8095088601112366, Trainging R-squared 0.6218434401843793
#
# CNN validation R2: 0.0027552341647544276
#
# Training Loss 0.815005898475647, Trainging R-squared 0.5551084735280312
#
# CNN validation R2: 0.005013209691517806
#
# Training Loss 0.8203712105751038, Trainging R-squared 0.40328823612691117
#
# CNN validation R2: 0.01233691729804709
#
# Training Loss 0.8127930462360382, Trainging R-squared 0.5648900495729748
#
# CNN validation R2: 0.018593445814174492
#
# Training Loss 0.8169199824333191, Trainging R-squared 0.49029855271409367
#
# CNN validation R2: 0.015364494739371126
#
# Training Loss 0.8130406141281128, Trainging R-squared 0.5305738671717145
#
# CNN validation R2: 0.011825937253967356
#
# Training Loss 0.8176540434360504, Trainging R-squared 0.467786329678817
#
# CNN validation R2: 0.010658977532053748
#
# Training Loss 0.8151264488697052, Trainging R-squared 0.4453213862083253
#
# CNN validation R2: 0.007989302759871975
#
# Training Loss 0.8175261318683624, Trainging R-squared 0.4447901232649323
#
# CNN validation R2: 0.010729228367408361
#
# Training Loss 0.8151414692401886, Trainging R-squared 0.5246927610285125
#
# CNN validation R2: 0.007247293746883876
#
# Training Loss 0.8168879449367523, Trainging R-squared 0.5052256232484656
#
# CNN validation R2: -0.0020662698979591054
#
# Training Loss 0.8189796507358551, Trainging R-squared 0.40367326727125724
#
# CNN validation R2: -0.005214925175235752
#
# Training Loss 0.8116862773895264, Trainging R-squared 0.5377677398356769
#
# CNN validation R2: -0.004743849487849727
#
# Training Loss 0.81552454829216, Trainging R-squared 0.5060933397531301
#
# CNN validation R2: 0.0023066778928295117
#
# Training Loss 0.8179977536201477, Trainging R-squared 0.45630799733741967
#
# CNN validation R2: 0.004314887016987623
#
# Training Loss 0.8107315301895142, Trainging R-squared 0.6185325099020013
#
# CNN validation R2: 0.00734461353106719
#
# Training Loss 0.8091605305671692, Trainging R-squared 0.6694600774642285
#
# CNN validation R2: 0.007052747460342346
#
# Training Loss 0.8106374442577362, Trainging R-squared 0.6317110124420589
#
# CNN validation R2: 0.006402019160629713
#
# Training Loss 0.8201329708099365, Trainging R-squared 0.4850680957184288
#
# CNN validation R2: -0.008859766939214808
#
# Training Loss 0.8150894939899445, Trainging R-squared 0.4915090115754591
#
# CNN validation R2: -0.00953417863287831
#
# Training Loss 0.8108659386634827, Trainging R-squared 0.6139590446252103
#
# CNN validation R2: -0.014159221337006367
#
# Training Loss 0.8116320073604584, Trainging R-squared 0.5969567960513412
#
# CNN validation R2: -0.017863968491219184
#
# Training Loss 0.8116731345653534, Trainging R-squared 0.5565670708128282
#
# CNN validation R2: -0.0235240763018974
#
# Training Loss 0.8176303803920746, Trainging R-squared 0.4887875363526121
#
# CNN validation R2: -0.026088638882665105
#
# Training Loss 0.8164982199668884, Trainging R-squared 0.5055597408690526
#
# CNN validation R2: -0.02815567567896793
#
# Training Loss 0.8135215640068054, Trainging R-squared 0.5927800852384612
#
# CNN validation R2: -0.02695407341346223
#
# Training Loss 0.8142688572406769, Trainging R-squared 0.5578321492116747
#
# CNN validation R2: -0.019273654215357927
#
# Training Loss 0.8161187171936035, Trainging R-squared 0.5349472155440949
#
# CNN validation R2: -0.0109138734056477
#
# Training Loss 0.8117075264453888, Trainging R-squared 0.5677612837021715
#
# CNN validation R2: -0.004046163464330066
#
# Training Loss 0.8091335594654083, Trainging R-squared 0.6020664343202207
#
# CNN validation R2: -0.005968650169844436
#
# Training Loss 0.8113988935947418, Trainging R-squared 0.6160636624762552
#
# CNN validation R2: -0.010874968455967748
#
# Training Loss 0.8110993504524231, Trainging R-squared 0.5581756618526373
#
# CNN validation R2: -0.013114068793164513
#
# Training Loss 0.8126648366451263, Trainging R-squared 0.5386187319701714
#
# CNN validation R2: -0.013509434063616932

# %%
r2 = []
r2_r = []
r2_v = []
for best_model, m, std in models:
    i = 0
    # best_model=models[1]
    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    best_model.eval()
    for inputs, labels in test_loader:
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to('cuda')
        labels = labels.to('cuda')
        if i == 0:
            cnnOutputs = best_model(inputs).to('cpu')
            l = labels.to('cpu')
        else:
            cnnOutputs = torch.cat((cnnOutputs, best_model(inputs).to('cpu')), 0)
            l = torch.cat((l, labels.to('cpu')), 0)
        i+=1
    r2_v.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy()[:,1], cnnOutputs.to('cpu').detach().numpy()[:,1]))
    r2_r.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy()[:,0], cnnOutputs.to('cpu').detach().numpy()[:,0]))
    r2.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy()))

# %%
np.mean(r2)
# Out:
# 0.07156436389475344

# %%
np.mean(r2_v)
# Out:
# 0.07078726482468553

# %%
np.mean(r2_r)
# Out:
# 0.07234144655813124
