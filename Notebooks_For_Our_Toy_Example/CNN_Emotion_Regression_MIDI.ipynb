# %%
# Train the CNN Emotion Regression Model with MIDI data#
# Last editted by Pu Zeng, 18/10/2023 #

# %%
import pandas as pd
from tqdm import tqdm
import os
from sklearn.model_selection import KFold
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from torch.utils.data import TensorDataset
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset
import string
import numpy as np
import pickle
from sklearn import preprocessing
import torch
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings
import json
warnings.filterwarnings('ignore')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Calculate the mean Arousal and Valence score from raw json data
def read_json_av(fileName):
    file = open(fileName,'r')
    lines = json.load(file)
    file.close()
    file = pd.DataFrame(pd.DataFrame(lines['pieces']).T['midi'])
    ann = pd.DataFrame(lines['annotations']).T.reset_index()
    file['arousal'] = np.nan
    file['valence'] = np.nan
    i = 1
    for i in range(len(file)):
        f = file.iloc[i]
        raw = ann[ann['index'].str.contains(f.name+'_')]
        ar = []
        va = []
        for j in range(len(raw)):
            row = raw.iloc[j]
            ar.append(np.mean(row['arousal']))
            va.append(np.mean(row['valence']))
        file['arousal'].iloc[i] = np.mean(ar)
        file['valence'].iloc[i] = np.mean(va)
    return file.reset_index()[['midi','arousal','valence']]

# %%
j1 = read_json_av('../Toy_Dataset/VGG/vgmidi_raw_1.json');
j2 = read_json_av('../Toy_Dataset/VGG/vgmidi_raw_2.json');
data = pd.concat([j1,j2],ignore_index=True)

# %%
# Transform MIDI into MFCCs

res1 = []
from midi2audio import FluidSynth
import librosa
import librosa.display
import pretty_midi
import numpy as np
def parse_piano_most(file_path):
    mean_intensity = []
    midi_data = pretty_midi.PrettyMIDI(file_path)
    for instrument in midi_data.instruments:
        mean_intensity.append(instrument.get_piano_roll().mean())
    instruments_to_remove_index = np.argsort(mean_intensity)[:-1]
    instruments_to_remove = []
    for i in instruments_to_remove_index:
        instruments_to_remove.append(midi_data.instruments[i])
    for i in instruments_to_remove:
        midi_data.instruments.remove(i)
    midi_data.instruments[0].program=0
    return midi_data

for i in tqdm(range(len(data))):
    try:
        m = data.iloc[i]
        filename = '../Toy_Dataset/VGG/midi/'+ m['midi']
        midi_data = parse_piano_most(filename)
        if midi_data == None:
            continue
        midi_data.write('1.mid')
        fs = FluidSynth();
        fs.midi_to_audio('1.mid', 'output.wav');
        y, sr = librosa.load('output.wav');
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
        res1.append([mfccs, m['arousal'],m['valence']])
    except:
        pass
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [04:24<00:00,  1.32s/it]

# %%
# Organize the dataset
import numpy as np
midi = []
for m in res1:
    midi.append([m[0], [m[1],m[2]]])

# %%
# Find the minimum length to uniform all MFCCs to the same shape
dim = np.min([m[0].shape[1] for m in res1])
dim
# Out:
# 359

# %%
# Final dataset
from tqdm import tqdm
X = []
y = []
for m in res1:
    # X.append(m[0][:, :dim])
    X.append(m[0].T[0:dim,:])
    y.append([m[1], m[2]])
X = np.array(X)

# %%
# Define CNN regression model
class CNNModel(nn.Module):
    def __init__(self, hiddenSize, outChannels, dropoutRate, activate):
        super().__init__()
        self.outChannels = outChannels
        self.activate = nn.Sigmoid() if activate == "Sigmoid" else nn.ReLU()
        self.conv1 = nn.Conv2d(1, 24, (10,1))
        self.pool = nn.MaxPool2d((2, 1))
        
        self.conv2 = nn.Conv2d(24, 48, (10,1))
        self.bn1 = nn.BatchNorm2d(48)
        self.conv3 = nn.Conv2d(48, 96, (10,1))
        self.bn2 = nn.BatchNorm2d(96)
        self.conv4 = nn.Conv2d(96, 192, (10,2))
        self.bn3 = nn.BatchNorm2d(192)
        self.conv5 = nn.Conv2d(192, 96, (5,2))
        self.bn4 = nn.BatchNorm2d(96)
        self.conv6 = nn.Conv2d(96, 96, (5,2))
        self.dense1 = nn.Linear(1632, hiddenSize)
        self.dropout = nn.Dropout(dropoutRate)
        self.dense2 = nn.Linear(hiddenSize, 2)

    def forward(self, x):
        x = self.pool(self.activate(self.conv1(x)))
        x = self.pool(self.bn1(self.activate(self.conv2(x))))
        # print(x.shape)
        x = self.dropout(self.pool(self.bn2(self.activate(self.conv3(x)))))
        x = self.pool(self.bn3(self.activate(self.conv4(x))))
        x = self.pool(self.bn4(self.activate(self.conv5(x))))
        
        x = self.activate(self.conv6(x))
        # print(x.shape)
        x = x.view(-1, 1632)
        
        x = self.dropout(self.activate(self.dense1(x)))
        # print(self.dense2(x))
        return self.dense2(x)

# Number of neurons in the first fully-connected layer
hiddenSize = 64
# Number of feature filters in second convolutional layer
numFilters = 25
# Dropout rate
dropoutRate = 0.3
# Activation function
activation = "ReLU"
# Learning rate
learningRate = 0.001
# Momentum for SGD optimizer
momentum = 0.8
# Number of training epochs
numEpochs = 200

# %%
# Define Train and Validation function
from tqdm import tqdm
def train_epoch(cnn,device,dataloader,loss_fn,optimizer, m, std):
    cnn.train()
    cnnRunningLoss = 0
    total = 0
    R2 = 0
    for i, (inputs, labels) in enumerate(dataloader, 0):
        optimizer.zero_grad()
        # Normalization
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to(device)
        labels = labels.to(device)
        # Forward propagation
        cnnOutputs = cnn(inputs)

        l2_lambda = 0.01
        l2_reg = torch.tensor(0.).to(device)

        for param in cnn.parameters():
            l2_reg += torch.norm(param)

        # Backpropagation
        cnnLoss = criterion(cnnOutputs, labels)+l2_reg*l2_lambda
        cnnLoss.backward()

        # Gradient update
        optimizer.step()

        cnnRunningLoss += cnnLoss.item()
        total += 1
        # if (i+1) % 20 == 0:    # print every 2000 mini-batches
        #     print(cnnLoss)
        R2 += sklearn.metrics.r2_score(labels.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy())
    print('Training Loss {}, Trainging R-squared {}'.format(str(cnnRunningLoss/total), str(R2/total)))
    return cnnRunningLoss/total, R2
def valid_epoch(cnn,device,dataloader,loss_fn, m, std):
    cnn.eval()
    totalLoss = 0
    total = 0
    R2 = 0
    for inputs, labels in dataloader:
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to(device)
        labels = labels.to(device)
        cnnOutputs = cnn(inputs)
        cnnLoss = criterion(cnnOutputs, labels)#+l2_reg*l2_lambda
        # print(cnnLoss)
        totalLoss += cnnLoss.item()
        total +=1
        R2 += sklearn.metrics.r2_score(labels.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy())
    print('\nCNN validation R2: {}\n '.format(str(R2/total)))
    cnn.train()
    return totalLoss/total, R2

# %%
import sklearn
X_train_v, X_test, y_train_v, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train_v = torch.as_tensor(X_train_v, dtype=torch.float) # an alternative to torch.from_numpy
y_train_v = torch.as_tensor(y_train_v, dtype=torch.float)
X_test = torch.as_tensor(X_test, dtype=torch.float)
y_test = torch.as_tensor(y_test, dtype=torch.float)
splits=KFold(n_splits=5,shuffle=True,random_state=42)
train_dataset = TensorDataset(X_train_v, y_train_v)
test_dataset = TensorDataset(X_test, y_test)
batch_size=128
models = []
history = {'fold':[], 'train_loss': [], 'test_loss': [],'train_R2':[],'test_R2':[]}


for fold, (train_idx,val_idx) in enumerate(splits.split(np.arange(len(X_train_v)))):
    print('Fold {}'.format(fold + 1))
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(val_idx)
    m = np.vstack(X_train_v[train_idx]).mean()
    std = np.vstack(X_train_v[train_idx]).std()
    train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler)
    test_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=test_sampler)
    
    model = CNNModel(hiddenSize, numFilters, dropoutRate, activation).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(list(model.parameters()), lr=learningRate, momentum=momentum)
    # optimizer = torch.optim.Adam(list(model.parameters()), lr=learningRate)
    best_test = -np.inf
    best_model = None
    for epoch in range(numEpochs):
        train_loss, train_R2=train_epoch(model,device,train_loader,criterion,optimizer, m, std)
        test_loss, test_R2=valid_epoch(model,device,test_loader,criterion, m, std)
        history['fold'].append(fold)
        history['train_loss'].append(train_loss)
        history['test_loss'].append(test_loss)
        history['train_R2'].append(train_R2)
        history['test_R2'].append(test_R2)   
        if test_R2>best_test:
            best_test = test_R2
            best_model = model
    models.append([best_model, m, std])
# Out:
# Fold 1
# Training Loss 0.8883683979511261, Trainging R-squared -0.71922868559512
#
# CNN validation R2: -0.5924767279498604
#
# Training Loss 0.8730755746364594, Trainging R-squared -0.46519375148667735
#
# CNN validation R2: -0.589629197142566
#
# Training Loss 0.8814115226268768, Trainging R-squared -0.6475037131048493
#
# CNN validation R2: -0.5847355371007656
#
# Training Loss 0.8754326403141022, Trainging R-squared -0.4633856073084207
#
# CNN validation R2: -0.5844088804760241
#
# Training Loss 0.8712138831615448, Trainging R-squared -0.25573721914072456
#
# CNN validation R2: -0.5858422163586051
#
# Training Loss 0.8569222688674927, Trainging R-squared -0.22603838852008198
#
# CNN validation R2: -0.5875088330500474
#
# Training Loss 0.863812267780304, Trainging R-squared -0.20696149183040297
#
# CNN validation R2: -0.5892590263389372
#
# Training Loss 0.8614230155944824, Trainging R-squared -0.34204292082364024
#
# CNN validation R2: -0.5919845242585575
#
# Training Loss 0.8478294909000397, Trainging R-squared -0.07264079028289686
#
# CNN validation R2: -0.5961787867412719
#
# Training Loss 0.856210321187973, Trainging R-squared -0.11358262490889845
#
# CNN validation R2: -0.6007133702731006
#
# Training Loss 0.858082115650177, Trainging R-squared -0.07423363778936345
#
# CNN validation R2: -0.6032702740715132
#
# Training Loss 0.8497669994831085, Trainging R-squared -0.009597126839526654
#
# CNN validation R2: -0.6075935506557089
#
# Training Loss 0.8467783033847809, Trainging R-squared -0.04192427270131019
#
# CNN validation R2: -0.6064005131719352
#
# Training Loss 0.8609634041786194, Trainging R-squared -0.14000857778450776
#
# CNN validation R2: -0.5948512824121155
#
# Training Loss 0.8524368107318878, Trainging R-squared -0.06316631813130463
#
# CNN validation R2: -0.5799920412906004
#
# Training Loss 0.8554365634918213, Trainging R-squared -0.1919114810199697
#
# CNN validation R2: -0.5613386059709784
#
# Training Loss 0.8547376096248627, Trainging R-squared -0.05996432933528992
#
# CNN validation R2: -0.5393299345002706
#
# Training Loss 0.8463667631149292, Trainging R-squared -0.10421086595862952
#
# CNN validation R2: -0.5121274456946904
#
# Training Loss 0.8562744855880737, Trainging R-squared -0.09911162996680734
#
# CNN validation R2: -0.4849272685493692
#
# Training Loss 0.8410836756229401, Trainging R-squared 0.1408604699146208
#
# CNN validation R2: -0.4623554214800265
#
# Training Loss 0.8517019152641296, Trainging R-squared 0.03702207410668834
#
# CNN validation R2: -0.4429804962682139
#
# Training Loss 0.8516799807548523, Trainging R-squared -0.040981964043512925
#
# CNN validation R2: -0.42241520074729066
#
# Training Loss 0.8483247756958008, Trainging R-squared -0.006845808448677659
#
# CNN validation R2: -0.3944052798908386
#
# Training Loss 0.8402403891086578, Trainging R-squared 0.15019480802110094
#
# CNN validation R2: -0.36758065442059085
#
# Training Loss 0.8476589620113373, Trainging R-squared 0.10764213858088759
#
# CNN validation R2: -0.34610125747777043
#
# Training Loss 0.8516902029514313, Trainging R-squared 0.02010292045904019
#
# CNN validation R2: -0.3318353465348445
#
# Training Loss 0.8459082841873169, Trainging R-squared 0.10723292865355147
#
# CNN validation R2: -0.3194072142580615
#
# Training Loss 0.8468291759490967, Trainging R-squared 0.11444893880873952
#
# CNN validation R2: -0.31372639789618406
#
# Training Loss 0.8519579470157623, Trainging R-squared 0.002699551689066826
#
# CNN validation R2: -0.3075290180034965
#
# Training Loss 0.8420341908931732, Trainging R-squared 0.12179851901896357
#
# CNN validation R2: -0.3027484015864508
#
# Training Loss 0.8512084484100342, Trainging R-squared -0.020038731459340292
#
# CNN validation R2: -0.30044906650200487
#
# Training Loss 0.850588321685791, Trainging R-squared 0.08307595261521483
#
# CNN validation R2: -0.2890977377914069
#
# Training Loss 0.8439242541790009, Trainging R-squared 0.11096242576659862
#
# CNN validation R2: -0.27074588635422037
#
# Training Loss 0.8560039103031158, Trainging R-squared -0.2586784651851996
#
# CNN validation R2: -0.24548883820852263
#
# Training Loss 0.8534219264984131, Trainging R-squared 0.02713455525914915
#
# CNN validation R2: -0.2001562764368251
#
# Training Loss 0.8464734852313995, Trainging R-squared 0.06639774549170405
#
# CNN validation R2: -0.15968689172097283
#
# Training Loss 0.8484389185905457, Trainging R-squared 0.03648559016122288
#
# CNN validation R2: -0.13968623378384015
#
# Training Loss 0.8435628712177277, Trainging R-squared 0.15603563758273553
#
# CNN validation R2: -0.12120693958010909
#
# Training Loss 0.8456110656261444, Trainging R-squared 0.04791934088383301
#
# CNN validation R2: -0.11705014632948663
#
# Training Loss 0.8505761325359344, Trainging R-squared 0.00023906518966318457
#
# CNN validation R2: -0.12766228064842378
#
# Training Loss 0.8425047397613525, Trainging R-squared 0.062392621415857136
#
# CNN validation R2: -0.12227572829928546
#
# Training Loss 0.8379369676113129, Trainging R-squared 0.259778944187639
#
# CNN validation R2: -0.10804185233487884
#
# Training Loss 0.8457432687282562, Trainging R-squared 0.1743414262065654
#
# CNN validation R2: -0.09812704053347643
#
# Training Loss 0.8340743780136108, Trainging R-squared 0.283695668696638
#
# CNN validation R2: -0.09360335515088525
#
# Training Loss 0.841444730758667, Trainging R-squared 0.042018784517013935
#
# CNN validation R2: -0.08931034675420524
#
# Training Loss 0.847030758857727, Trainging R-squared 0.05671131298502469
#
# CNN validation R2: -0.07642062140401551
#
# Training Loss 0.844068169593811, Trainging R-squared 0.11599345216262666
#
# CNN validation R2: -0.05994741518248292
#
# Training Loss 0.8459767997264862, Trainging R-squared 0.17050844085669345
#
# CNN validation R2: -0.026695574445238512
#
# Training Loss 0.8433889448642731, Trainging R-squared 0.07762956148484979
#
# CNN validation R2: -0.013916299515034591
#
# Training Loss 0.8390921652317047, Trainging R-squared 0.2542428903909346
#
# CNN validation R2: -0.019251636794317295
#
# Training Loss 0.8393653035163879, Trainging R-squared 0.21492192649875147
#
# CNN validation R2: -0.03997415962856121
#
# Training Loss 0.8380258083343506, Trainging R-squared 0.03503256202780802
#
# CNN validation R2: -0.03559152022855794
#
# Training Loss 0.8447657823562622, Trainging R-squared 0.08927151561177718
#
# CNN validation R2: -0.02674113788584953
#
# Training Loss 0.8421965837478638, Trainging R-squared 0.15840114923149942
#
# CNN validation R2: 0.012913790111163281
#
# Training Loss 0.8417144417762756, Trainging R-squared 0.23728441677455922
#
# CNN validation R2: 0.053046655055333125
#
# Training Loss 0.845797598361969, Trainging R-squared 0.14785718468282072
#
# CNN validation R2: 0.03186853909590254
#
# Training Loss 0.8401467502117157, Trainging R-squared 0.21557842963073523
#
# CNN validation R2: 0.028085593645355122
#
# Training Loss 0.8430609405040741, Trainging R-squared 0.1550440792183213
#
# CNN validation R2: 0.03155357260652303
#
# Training Loss 0.8403200209140778, Trainging R-squared 0.1584161764086354
#
# CNN validation R2: 0.027701625861841273
#
# Training Loss 0.841278612613678, Trainging R-squared 0.16121081723971806
#
# CNN validation R2: -0.009889321629183212
#
# Training Loss 0.8372202217578888, Trainging R-squared 0.2115787626487708
#
# CNN validation R2: -0.03565739493196418
#
# Training Loss 0.8392059206962585, Trainging R-squared 0.2361191505722619
#
# CNN validation R2: -0.012691857941239393
#
# Training Loss 0.8358366191387177, Trainging R-squared 0.17959414547619804
#
# CNN validation R2: 6.285745518641583e-06
#
# Training Loss 0.8379462659358978, Trainging R-squared 0.12686096713094308
#
# CNN validation R2: 0.0065342501285564625
#
# Training Loss 0.8383592963218689, Trainging R-squared 0.15678916197160273
#
# CNN validation R2: -0.004826986060140648
#
# Training Loss 0.8387731313705444, Trainging R-squared 0.2111452302216069
#
# CNN validation R2: 0.0013157892694159457
#
# Training Loss 0.8347494304180145, Trainging R-squared 0.24904263179041028
#
# CNN validation R2: -0.011729050631288318
#
# Training Loss 0.8352623581886292, Trainging R-squared 0.11471645749027348
#
# CNN validation R2: -0.023465482959990458
#
# Training Loss 0.8426775932312012, Trainging R-squared 0.05718803671072972
#
# CNN validation R2: -0.030683466523806713
#
# Training Loss 0.83821702003479, Trainging R-squared 0.2867768382420224
#
# CNN validation R2: -0.022946502928005374
#
# Training Loss 0.8304925858974457, Trainging R-squared 0.2581379247016682
#
# CNN validation R2: -0.007075811313009661
#
# Training Loss 0.835627019405365, Trainging R-squared 0.27134549359252824
#
# CNN validation R2: 0.002847260336383717
#
# Training Loss 0.8342709541320801, Trainging R-squared 0.22088285962324797
#
# CNN validation R2: 0.005221139932865437
#
# Training Loss 0.8390945792198181, Trainging R-squared 0.2533431161055748
#
# CNN validation R2: 0.011448775632800834
#
# Training Loss 0.8316478133201599, Trainging R-squared 0.2861725531767997
#
# CNN validation R2: 0.011213351616690459
#
# Training Loss 0.8379524648189545, Trainging R-squared 0.2108615935530215
#
# CNN validation R2: 0.012096360026141728
#
# Training Loss 0.8382435441017151, Trainging R-squared 0.21423698550482578
#
# CNN validation R2: 0.005211262906753722
#
# Training Loss 0.8401819169521332, Trainging R-squared 0.2057747805512408
#
# CNN validation R2: 0.0009046801531921722
#
# Training Loss 0.8327635526657104, Trainging R-squared 0.31625785249921334
#
# CNN validation R2: -0.005291283168572025
#
# Training Loss 0.8331666886806488, Trainging R-squared 0.329500071015448
#
# CNN validation R2: -0.018894849740547393
#
# Training Loss 0.8383093178272247, Trainging R-squared 0.21378840457325235
#
# CNN validation R2: -0.03966434211782033
#
# Training Loss 0.8423301875591278, Trainging R-squared 0.25589802663786854
#
# CNN validation R2: -0.05385147029842374
#
# Training Loss 0.8322476446628571, Trainging R-squared 0.25545700694934853
#
# CNN validation R2: -0.07380628559019864
#
# Training Loss 0.8325304985046387, Trainging R-squared 0.27668202715904544
#
# CNN validation R2: -0.06744684402943457
#
# Training Loss 0.838871568441391, Trainging R-squared 0.26699069573294454
#
# CNN validation R2: -0.05627797803878665
#
# Training Loss 0.8323169350624084, Trainging R-squared 0.3210316908736136
#
# CNN validation R2: -0.032507340728005873
#
# Training Loss 0.8388598263263702, Trainging R-squared 0.18067359995203824
#
# CNN validation R2: -0.023716668633147697
#
# Training Loss 0.8320203423500061, Trainging R-squared 0.360571651549502
#
# CNN validation R2: -0.012721769356772883
#
# Training Loss 0.8283815383911133, Trainging R-squared 0.3433686789510725
#
# CNN validation R2: 0.0012383465658215576
#
# Training Loss 0.8332106173038483, Trainging R-squared 0.31312615855250403
#
# CNN validation R2: 0.024053222607269553
#
# Training Loss 0.83904829621315, Trainging R-squared 0.18138747604229188
#
# CNN validation R2: 0.04255625204478558
#
# Training Loss 0.8315739929676056, Trainging R-squared 0.2286056554447092
#
# CNN validation R2: 0.04701584177882062
#
# Training Loss 0.8315880000591278, Trainging R-squared 0.24860462912622652
#
# CNN validation R2: 0.05033583350289139
#
# Training Loss 0.8359392285346985, Trainging R-squared 0.22466566055738107
#
# CNN validation R2: 0.056944803933371035
#
# Training Loss 0.8296285569667816, Trainging R-squared 0.35418124505007853
#
# CNN validation R2: 0.05610765852715782
#
# Training Loss 0.8373388946056366, Trainging R-squared 0.27076543178520024
#
# CNN validation R2: 0.029473440662277917
#
# Training Loss 0.8367151916027069, Trainging R-squared 0.24799460081012897
#
# CNN validation R2: 0.0049667040008290475
#
# Training Loss 0.8313775956630707, Trainging R-squared 0.358536153635765
#
# CNN validation R2: -0.0033281051678966667
#
# Training Loss 0.8323079347610474, Trainging R-squared 0.326231235633903
#
# CNN validation R2: 0.013603433060172199
#
# Training Loss 0.8315856754779816, Trainging R-squared 0.28564129662887777
#
# CNN validation R2: 0.020066645984862908
#
# Training Loss 0.8341271579265594, Trainging R-squared 0.2687507523168223
#
# CNN validation R2: 0.019589478825681517
#
# Training Loss 0.8345046937465668, Trainging R-squared 0.2934512441873208
#
# CNN validation R2: 0.027999660015185945
#
# Training Loss 0.8277122676372528, Trainging R-squared 0.3875656050656964
#
# CNN validation R2: 0.0198038836845974
#
# Training Loss 0.8341040015220642, Trainging R-squared 0.32800346808520375
#
# CNN validation R2: -0.0003788506229372435
#
# Training Loss 0.8350534439086914, Trainging R-squared 0.2563481184233778
#
# CNN validation R2: -0.00419267243135335
#
# Training Loss 0.8317567110061646, Trainging R-squared 0.28685984526928054
#
# CNN validation R2: 0.000897515030724827
#
# Training Loss 0.8248913586139679, Trainging R-squared 0.4621587948371101
#
# CNN validation R2: -0.00023084040848964094
#
# Training Loss 0.833160400390625, Trainging R-squared 0.2941687103855918
#
# CNN validation R2: -0.01536323289741981
#
# Training Loss 0.8275195062160492, Trainging R-squared 0.311127141745292
#
# CNN validation R2: -0.021410709514684878
#
# Training Loss 0.8349058330059052, Trainging R-squared 0.3405018932859535
#
# CNN validation R2: -0.02049676148724383
#
# Training Loss 0.8352736830711365, Trainging R-squared 0.28026268197558424
#
# CNN validation R2: -0.010444207661670646
#
# Training Loss 0.8304206430912018, Trainging R-squared 0.38295014346301226
#
# CNN validation R2: 0.002807054090726624
#
# Training Loss 0.8313460946083069, Trainging R-squared 0.3712147731482308
#
# CNN validation R2: 0.010930856858693605
#
# Training Loss 0.8227836787700653, Trainging R-squared 0.42449351973698046
#
# CNN validation R2: 0.01595794717865867
#
# Training Loss 0.8242765963077545, Trainging R-squared 0.42613768412929454
#
# CNN validation R2: 0.0213161698569288
#
# Training Loss 0.8291439116001129, Trainging R-squared 0.38270530450469714
#
# CNN validation R2: 0.0246657247998584
#
# Training Loss 0.8290223777294159, Trainging R-squared 0.3966201832738335
#
# CNN validation R2: 0.03011485489409932
#
# Training Loss 0.826018214225769, Trainging R-squared 0.39598465410488726
#
# CNN validation R2: 0.02616922427826779
#
# Training Loss 0.83156418800354, Trainging R-squared 0.31277586448584943
#
# CNN validation R2: 0.020688136779557664
#
# Training Loss 0.8296860456466675, Trainging R-squared 0.35393887548552916
#
# CNN validation R2: 0.02818724188277988
#
# Training Loss 0.8275964558124542, Trainging R-squared 0.44548149340813015
#
# CNN validation R2: 0.025278215530252612
#
# Training Loss 0.8300290405750275, Trainging R-squared 0.275223518320696
#
# CNN validation R2: 0.019042687861882734
#
# Training Loss 0.8309763967990875, Trainging R-squared 0.31288890059883157
#
# CNN validation R2: 0.014177888605320044
#
# Training Loss 0.8300696909427643, Trainging R-squared 0.3277418842854908
#
# CNN validation R2: 0.018373985486645705
#
# Training Loss 0.8283683061599731, Trainging R-squared 0.36009482958116773
#
# CNN validation R2: 0.024028774571919098
#
# Training Loss 0.821168065071106, Trainging R-squared 0.4828510627178321
#
# CNN validation R2: 0.02977303498253009
#
# Training Loss 0.8256325423717499, Trainging R-squared 0.44016380250888365
#
# CNN validation R2: 0.028858196021111338
#
# Training Loss 0.8246589004993439, Trainging R-squared 0.4184557252725767
#
# CNN validation R2: 0.033510795890773326
#
# Training Loss 0.8265424370765686, Trainging R-squared 0.38868588111682356
#
# CNN validation R2: 0.03738628384491788
#
# Training Loss 0.8252840340137482, Trainging R-squared 0.40629306505128854
#
# CNN validation R2: 0.03832068931258775
#
# Training Loss 0.8301196396350861, Trainging R-squared 0.4041795472720949
#
# CNN validation R2: 0.03753937582570821
#
# Training Loss 0.823600560426712, Trainging R-squared 0.39989935116597086
#
# CNN validation R2: 0.03734265384827962
#
# Training Loss 0.8230637609958649, Trainging R-squared 0.4385983775257631
#
# CNN validation R2: 0.03436534216006637
#
# Training Loss 0.8255891799926758, Trainging R-squared 0.42343392831414534
#
# CNN validation R2: 0.0260411102897809
#
# Training Loss 0.8206379115581512, Trainging R-squared 0.5034763233687033
#
# CNN validation R2: 0.025220158628988243
#
# Training Loss 0.8242376744747162, Trainging R-squared 0.3443268248436513
#
# CNN validation R2: 0.027277185803531945
#
# Training Loss 0.8241944909095764, Trainging R-squared 0.44507560070899754
#
# CNN validation R2: 0.03328900009744101
#
# Training Loss 0.8259540796279907, Trainging R-squared 0.4184009876413517
#
# CNN validation R2: 0.04117459862529238
#
# Training Loss 0.8212049305438995, Trainging R-squared 0.3354796870519449
#
# CNN validation R2: 0.03727242336834319
#
# Training Loss 0.8255151212215424, Trainging R-squared 0.38815019489648533
#
# CNN validation R2: 0.03231594787557823
#
# Training Loss 0.8256316483020782, Trainging R-squared 0.3544317993645304
#
# CNN validation R2: 0.02937176561618593
#
# Training Loss 0.8239070773124695, Trainging R-squared 0.3985766968650174
#
# CNN validation R2: 0.029394317978236495
#
# Training Loss 0.824627012014389, Trainging R-squared 0.4531939439156671
#
# CNN validation R2: 0.028188615858156296
#
# Training Loss 0.832173079252243, Trainging R-squared 0.32297530923077167
#
# CNN validation R2: 0.02749746209856624
#
# Training Loss 0.8258858323097229, Trainging R-squared 0.43608596034774927
#
# CNN validation R2: 0.028481782320422422
#
# Training Loss 0.8249188363552094, Trainging R-squared 0.45612427096851726
#
# CNN validation R2: 0.02755707255008527
#
# Training Loss 0.8225586712360382, Trainging R-squared 0.4567636878314283
#
# CNN validation R2: 0.024490758330758755
#
# Training Loss 0.8208174705505371, Trainging R-squared 0.45826607466032776
#
# CNN validation R2: 0.019723572024528346
#
# Training Loss 0.8289480209350586, Trainging R-squared 0.35970045646068194
#
# CNN validation R2: 0.026032957578233873
#
# Training Loss 0.8257308304309845, Trainging R-squared 0.4289336624221001
#
# CNN validation R2: 0.036458651783604745
#
# Training Loss 0.8233630955219269, Trainging R-squared 0.41895685735210086
#
# CNN validation R2: 0.039976227472166226
#
# Training Loss 0.81853386759758, Trainging R-squared 0.49692641766863693
#
# CNN validation R2: 0.04483332256985251
#
# Training Loss 0.8203118443489075, Trainging R-squared 0.468920194908268
#
# CNN validation R2: 0.05029328687188245
#
# Training Loss 0.82225102186203, Trainging R-squared 0.41267192122900537
#
# CNN validation R2: 0.04833297469522008
#
# Training Loss 0.8236805200576782, Trainging R-squared 0.4451196514873359
#
# CNN validation R2: 0.04931545190261388
#
# Training Loss 0.8217401206493378, Trainging R-squared 0.457234614265362
#
# CNN validation R2: 0.0502220497054508
#
# Training Loss 0.8250895440578461, Trainging R-squared 0.46887998468572334
#
# CNN validation R2: 0.05289832193347782
#
# Training Loss 0.8236945867538452, Trainging R-squared 0.34891361079610933
#
# CNN validation R2: 0.05023287016598815
#
# Training Loss 0.8233398795127869, Trainging R-squared 0.470053114846747
#
# CNN validation R2: 0.03545561568084554
#
# Training Loss 0.8249724507331848, Trainging R-squared 0.49063858161445406
#
# CNN validation R2: 0.026624172514046474
#
# Training Loss 0.8236749470233917, Trainging R-squared 0.4930559150815228
#
# CNN validation R2: 0.01660496194753608
#
# Training Loss 0.8204455673694611, Trainging R-squared 0.5351034079941986
#
# CNN validation R2: 0.010653995414044992
#
# Training Loss 0.8199152052402496, Trainging R-squared 0.5122096968468295
#
# CNN validation R2: 0.013652624577067618
#
# Training Loss 0.8207045197486877, Trainging R-squared 0.49007699102388447
#
# CNN validation R2: 0.01488134370525207
#
# Training Loss 0.8226460814476013, Trainging R-squared 0.4008285563888605
#
# CNN validation R2: 0.013056912720210312
#
# Training Loss 0.8180899620056152, Trainging R-squared 0.5295380420272543
#
# CNN validation R2: 0.009921233806311547
#
# Training Loss 0.8153340220451355, Trainging R-squared 0.5864631877017894
#
# CNN validation R2: 0.00825843118456504
#
# Training Loss 0.8268719613552094, Trainging R-squared 0.37737841986838916
#
# CNN validation R2: 0.011248954330722594
#
# Training Loss 0.8187665939331055, Trainging R-squared 0.5600399977865613
#
# CNN validation R2: 0.005094589045264164
#
# Training Loss 0.8239557147026062, Trainging R-squared 0.44019395330002886
#
# CNN validation R2: 0.007309067048247075
#
# Training Loss 0.8241462707519531, Trainging R-squared 0.38603257823856924
#
# CNN validation R2: 0.009527113033666823
#
# Training Loss 0.8200749754905701, Trainging R-squared 0.4575131854739557
#
# CNN validation R2: 0.0037034594738655224
#
# Training Loss 0.8172661364078522, Trainging R-squared 0.5652220380841343
#
# CNN validation R2: 0.0034310483500591404
#
# Training Loss 0.8216316401958466, Trainging R-squared 0.4535033533212419
#
# CNN validation R2: -0.00015621744836713525
#
# Training Loss 0.823912501335144, Trainging R-squared 0.4178215167132198
#
# CNN validation R2: -0.014357657292518311
#
# Training Loss 0.8196589052677155, Trainging R-squared 0.4800744718792891
#
# CNN validation R2: -0.016271890266223832
#
# Training Loss 0.8176537156105042, Trainging R-squared 0.48415745911634545
#
# CNN validation R2: -0.004306777731888423
#
# Training Loss 0.8242000341415405, Trainging R-squared 0.4375637723467164
#
# CNN validation R2: 0.019424253687379156
#
# Training Loss 0.8204001188278198, Trainging R-squared 0.5283995845192748
#
# CNN validation R2: 0.03601428379693983
#
# Training Loss 0.8233297765254974, Trainging R-squared 0.3746530693779217
#
# CNN validation R2: 0.03947413669180255
#
# Training Loss 0.8180501163005829, Trainging R-squared 0.467731570280959
#
# CNN validation R2: 0.02982505203819097
#
# Training Loss 0.8285822868347168, Trainging R-squared 0.20428304216929488
#
# CNN validation R2: 0.020525989165303904
#
# Training Loss 0.8217082917690277, Trainging R-squared 0.4272315985441083
#
# CNN validation R2: 0.007676259484119596
#
# Training Loss 0.8179105222225189, Trainging R-squared 0.5279758209790645
#
# CNN validation R2: 0.0076748422078248835
#
# Training Loss 0.8200207948684692, Trainging R-squared 0.5366643088701682
#
# CNN validation R2: 0.006927774611145743
#
# Training Loss 0.8212171196937561, Trainging R-squared 0.4998362511082465
#
# CNN validation R2: -0.0004646839377511758
#
# Training Loss 0.8209024369716644, Trainging R-squared 0.3651990192269665
#
# CNN validation R2: 0.00492495983057506
#
# Training Loss 0.8213663697242737, Trainging R-squared 0.4557609442783812
#
# CNN validation R2: 0.011858946446912932
#
# Training Loss 0.8220470249652863, Trainging R-squared 0.4530674755300287
#
# CNN validation R2: 0.021482597286845928
#
# Training Loss 0.8198246657848358, Trainging R-squared 0.4885811472689313
#
# CNN validation R2: 0.024877813769168422
#
# Training Loss 0.8178731203079224, Trainging R-squared 0.5604868184540795
#
# CNN validation R2: 0.027816276273935403
#
# Training Loss 0.8177798986434937, Trainging R-squared 0.6009606305737756
#
# CNN validation R2: 0.02931791226247299
#
# Training Loss 0.8240590393543243, Trainging R-squared 0.4679848790964555
#
# CNN validation R2: 0.014115908435286595
#
# Training Loss 0.8187618553638458, Trainging R-squared 0.4033011008853598
#
# CNN validation R2: 0.024746735345085258
#
# Training Loss 0.8170275986194611, Trainging R-squared 0.5670447828368192
#
# CNN validation R2: 0.044627467194317316
#
# Training Loss 0.8150542974472046, Trainging R-squared 0.5714603045775585
#
# CNN validation R2: 0.06623113854085771
#
# Training Loss 0.8164946436882019, Trainging R-squared 0.5392913028583881
#
# CNN validation R2: 0.06758824932034618
#
# Training Loss 0.8223987817764282, Trainging R-squared 0.49091876175678406
#
# CNN validation R2: 0.0657079866512611
#
# Training Loss 0.8219878971576691, Trainging R-squared 0.4642774284779935
#
# CNN validation R2: 0.06115969057017845
#
# Training Loss 0.8160290718078613, Trainging R-squared 0.5562334293370845
#
# CNN validation R2: 0.06292003066666418
#
# Fold 2
# Training Loss 0.8890600204467773, Trainging R-squared -0.6228440725238467
#
# CNN validation R2: -0.09830245151847761
#
# Training Loss 0.8885422646999359, Trainging R-squared -0.8516592104779639
#
# CNN validation R2: -0.08663751482449211
#
# Training Loss 0.8643113672733307, Trainging R-squared -0.24133514335763825
#
# CNN validation R2: -0.07576276028068496
#
# Training Loss 0.8802929520606995, Trainging R-squared -0.40238312947637034
#
# CNN validation R2: -0.06522728922352694
#
# Training Loss 0.8735893964767456, Trainging R-squared -0.27806870557768815
#
# CNN validation R2: -0.05718720928493848
#
# Training Loss 0.8675839900970459, Trainging R-squared -0.18358931129910594
#
# CNN validation R2: -0.05053329646393456
#
# Training Loss 0.8552228212356567, Trainging R-squared -0.017211641910623826
#
# CNN validation R2: -0.04272027696576053
#
# Training Loss 0.8581172823905945, Trainging R-squared -0.0627137145841799
#
# CNN validation R2: -0.03485153355185733
#
# Training Loss 0.8548745810985565, Trainging R-squared 0.04215190520935502
#
# CNN validation R2: -0.027914303631754733
#
# Training Loss 0.855562835931778, Trainging R-squared -0.017119934031548656
#
# CNN validation R2: -0.023176262489745025
#
# Training Loss 0.8535110652446747, Trainging R-squared -0.0954585807360955
#
# CNN validation R2: -0.01913956043352999
#
# Training Loss 0.845932126045227, Trainging R-squared 0.09422974355181757
#
# CNN validation R2: -0.01669567613666223
#
# Training Loss 0.8593312203884125, Trainging R-squared -0.06823943897175258
#
# CNN validation R2: -0.01744143711233337
#
# Training Loss 0.8558538854122162, Trainging R-squared -0.013380927332532405
#
# CNN validation R2: -0.01790216950514112
#
# Training Loss 0.8540380299091339, Trainging R-squared 0.02260227760105324
#
# CNN validation R2: -0.018824443383809897
#
# Training Loss 0.8546308279037476, Trainging R-squared 0.011001002299477952
#
# CNN validation R2: -0.018495069043060974
#
# Training Loss 0.8496749699115753, Trainging R-squared 0.1377225837833083
#
# CNN validation R2: -0.01649829089541449
#
# Training Loss 0.8579632639884949, Trainging R-squared -0.036346492946061515
#
# CNN validation R2: -0.01762704865712561
#
# Training Loss 0.8504641652107239, Trainging R-squared 0.07330804795057794
#
# CNN validation R2: -0.018473172764935764
#
# Training Loss 0.8579542636871338, Trainging R-squared -0.02176828111388146
#
# CNN validation R2: -0.01968575248455251
#
# Training Loss 0.8392797708511353, Trainging R-squared 0.21928043809307246
#
# CNN validation R2: -0.019945645257461453
#
# Training Loss 0.8499479591846466, Trainging R-squared 0.13278091454143742
#
# CNN validation R2: -0.020158656733986036
#
# Training Loss 0.8517029285430908, Trainging R-squared 0.0026764878593013852
#
# CNN validation R2: -0.021261825281796765
#
# Training Loss 0.8585505187511444, Trainging R-squared -0.013515126798951227
#
# CNN validation R2: -0.02325989509397125
#
# Training Loss 0.8491917252540588, Trainging R-squared 0.13759603447415963
#
# CNN validation R2: -0.02632855893571706
#
# Training Loss 0.8536287248134613, Trainging R-squared 0.042186486434397485
#
# CNN validation R2: -0.031189256199396442
#
# Training Loss 0.841546505689621, Trainging R-squared 0.20878682649338878
#
# CNN validation R2: -0.03734132815231217
#
# Training Loss 0.8467651307582855, Trainging R-squared 0.1607319294193291
#
# CNN validation R2: -0.04285348180378318
#
# Training Loss 0.8443796038627625, Trainging R-squared 0.20265754120146348
#
# CNN validation R2: -0.04430118338141009
#
# Training Loss 0.851004421710968, Trainging R-squared -0.0651126624177859
#
# CNN validation R2: -0.045217528156403675
#
# Training Loss 0.8412580192089081, Trainging R-squared 0.19629243211034522
#
# CNN validation R2: -0.04793357984665103
#
# Training Loss 0.8467515110969543, Trainging R-squared 0.0149319105869343
#
# CNN validation R2: -0.06009640769588087
#
# Training Loss 0.8457536101341248, Trainging R-squared 0.17419468805946506
#
# CNN validation R2: -0.06024175365773171
#
# Training Loss 0.8465267419815063, Trainging R-squared 0.12542205744128013
#
# CNN validation R2: -0.060634085836080986
#
# Training Loss 0.8403829336166382, Trainging R-squared 0.15255867537064477
#
# CNN validation R2: -0.06596750589959721
#
# Training Loss 0.84334397315979, Trainging R-squared 0.17874303448158846
#
# CNN validation R2: -0.06971165555356806
#
# Training Loss 0.8459602296352386, Trainging R-squared 0.1511536354615994
#
# CNN validation R2: -0.06178539455024229
#
# Training Loss 0.842435359954834, Trainging R-squared 0.11541142737634758
#
# CNN validation R2: -0.053916332131729694
#
# Training Loss 0.843841940164566, Trainging R-squared 0.1128838066593017
#
# CNN validation R2: -0.04392415088032564
#
# Training Loss 0.8485194742679596, Trainging R-squared 0.10627054113546186
#
# CNN validation R2: -0.020010707930825822
#
# Training Loss 0.8426421582698822, Trainging R-squared 0.20209332009579542
#
# CNN validation R2: -0.0031438747599174532
#
# Training Loss 0.8434857428073883, Trainging R-squared 0.0944495293045304
#
# CNN validation R2: 0.0006992482721815407
#
# Training Loss 0.8392322063446045, Trainging R-squared 0.20589550150328795
#
# CNN validation R2: 0.0027623217014348667
#
# Training Loss 0.8458862900733948, Trainging R-squared 0.08080900123213575
#
# CNN validation R2: 0.005507234246829029
#
# Training Loss 0.8460131883621216, Trainging R-squared 0.18298140862884055
#
# CNN validation R2: 0.00912211419943837
#
# Training Loss 0.8406101763248444, Trainging R-squared 0.22066679102737488
#
# CNN validation R2: 0.018409278251688477
#
# Training Loss 0.8431107103824615, Trainging R-squared 0.22919974923794784
#
# CNN validation R2: 0.03306282816253914
#
# Training Loss 0.8393429815769196, Trainging R-squared 0.1958630248863715
#
# CNN validation R2: 0.03431595377544072
#
# Training Loss 0.8348886370658875, Trainging R-squared 0.28577312709658304
#
# CNN validation R2: 0.033754001144945145
#
# Training Loss 0.8412511348724365, Trainging R-squared 0.1628234013123904
#
# CNN validation R2: 0.03384114936223154
#
# Training Loss 0.8368271589279175, Trainging R-squared 0.18508807834332486
#
# CNN validation R2: 0.0313422224448926
#
# Training Loss 0.838044673204422, Trainging R-squared 0.24986498799989473
#
# CNN validation R2: 0.028283631552671495
#
# Training Loss 0.8381924331188202, Trainging R-squared 0.29178151381330947
#
# CNN validation R2: 0.037850125717555416
#
# Training Loss 0.8417092561721802, Trainging R-squared 0.2131302981842087
#
# CNN validation R2: 0.03916914280795614
#
# Training Loss 0.8381587862968445, Trainging R-squared 0.21433612148630532
#
# CNN validation R2: 0.03009937203671509
#
# Training Loss 0.8414826095104218, Trainging R-squared 0.17635782406140993
#
# CNN validation R2: 0.02850052306781653
#
# Training Loss 0.8418190181255341, Trainging R-squared 0.2591836132221965
#
# CNN validation R2: 0.03392499402159482
#
# Training Loss 0.8467217683792114, Trainging R-squared 0.22276702234107873
#
# CNN validation R2: 0.028186066665060072
#
# Training Loss 0.8376404643058777, Trainging R-squared 0.24636644864440213
#
# CNN validation R2: 0.030353109037696058
#
# Training Loss 0.8326879739761353, Trainging R-squared 0.331389739258538
#
# CNN validation R2: 0.04230402725555976
#
# Training Loss 0.8329529166221619, Trainging R-squared 0.3339488250366348
#
# CNN validation R2: 0.05832680835934834
#
# Training Loss 0.8341973721981049, Trainging R-squared 0.22184953930982543
#
# CNN validation R2: 0.0684747008969882
#
# Training Loss 0.8375275135040283, Trainging R-squared 0.25131157456896225
#
# CNN validation R2: 0.07629127733413743
#
# Training Loss 0.8317285478115082, Trainging R-squared 0.23707962465912516
#
# CNN validation R2: 0.09867438250322497
#
# Training Loss 0.8386028110980988, Trainging R-squared 0.191850594222158
#
# CNN validation R2: 0.11087862203809717
#
# Training Loss 0.8320338428020477, Trainging R-squared 0.3528176174646491
#
# CNN validation R2: 0.10720828181290404
#
# Training Loss 0.8361411094665527, Trainging R-squared 0.30181685155694726
#
# CNN validation R2: 0.11004228831137908
#
# Training Loss 0.84158656001091, Trainging R-squared 0.14859486186442947
#
# CNN validation R2: 0.09620368857103256
#
# Training Loss 0.8441910445690155, Trainging R-squared 0.24316042316307987
#
# CNN validation R2: 0.07086858080301095
#
# Training Loss 0.8330802619457245, Trainging R-squared 0.36171039609078437
#
# CNN validation R2: 0.05396462833964211
#
# Training Loss 0.837060421705246, Trainging R-squared 0.24891714966841036
#
# CNN validation R2: 0.04506706189116033
#
# Training Loss 0.8290608823299408, Trainging R-squared 0.3985941486726915
#
# CNN validation R2: 0.044612922640231534
#
# Training Loss 0.8384277522563934, Trainging R-squared 0.34110131143031563
#
# CNN validation R2: 0.043217821100185905
#
# Training Loss 0.8310805559158325, Trainging R-squared 0.3558919186066201
#
# CNN validation R2: 0.04177096950045284
#
# Training Loss 0.8299632370471954, Trainging R-squared 0.32959200300791824
#
# CNN validation R2: 0.040594428349502776
#
# Training Loss 0.8378140330314636, Trainging R-squared 0.2790218447832779
#
# CNN validation R2: 0.03607402804418258
#
# Training Loss 0.8402083218097687, Trainging R-squared 0.27947725385170685
#
# CNN validation R2: 0.04413528176320802
#
# Training Loss 0.8327253460884094, Trainging R-squared 0.37276950763474964
#
# CNN validation R2: 0.05563198602904229
#
# Training Loss 0.8302333354949951, Trainging R-squared 0.38582619878891145
#
# CNN validation R2: 0.05763518029785364
#
# Training Loss 0.8361568748950958, Trainging R-squared 0.3508798816346178
#
# CNN validation R2: 0.052784078179576976
#
# Training Loss 0.8286327719688416, Trainging R-squared 0.3593193588277564
#
# CNN validation R2: 0.04355038491493046
#
# Training Loss 0.8296566605567932, Trainging R-squared 0.4204479136986734
#
# CNN validation R2: 0.029077944388903376
#
# Training Loss 0.8282276093959808, Trainging R-squared 0.4144759259113958
#
# CNN validation R2: 0.01684513408292454
#
# Training Loss 0.8336234092712402, Trainging R-squared 0.271731501441959
#
# CNN validation R2: 0.015865518714252402
#
# Training Loss 0.8331513702869415, Trainging R-squared 0.35588164926567006
#
# CNN validation R2: 0.025404779807383093
#
# Training Loss 0.8305943310260773, Trainging R-squared 0.3494024367362101
#
# CNN validation R2: 0.03862862767725922
#
# Training Loss 0.8292931616306305, Trainging R-squared 0.36662542712705526
#
# CNN validation R2: 0.04300666549040055
#
# Training Loss 0.8292597830295563, Trainging R-squared 0.38124955038805575
#
# CNN validation R2: 0.059080575515940925
#
# Training Loss 0.833368331193924, Trainging R-squared 0.287516144131471
#
# CNN validation R2: 0.07803092589805805
#
# Training Loss 0.8328733444213867, Trainging R-squared 0.35113261441342736
#
# CNN validation R2: 0.09384558755534489
#
# Training Loss 0.8327431678771973, Trainging R-squared 0.32491858499996334
#
# CNN validation R2: 0.11036243873150142
#
# Training Loss 0.8288984298706055, Trainging R-squared 0.42449663453553
#
# CNN validation R2: 0.11505673428151736
#
# Training Loss 0.8322097063064575, Trainging R-squared 0.30637210795156156
#
# CNN validation R2: 0.11371095759759231
#
# Training Loss 0.8340670168399811, Trainging R-squared 0.2875073868902771
#
# CNN validation R2: 0.10197273918592953
#
# Training Loss 0.8276795148849487, Trainging R-squared 0.39660640339397824
#
# CNN validation R2: 0.09755897610495229
#
# Training Loss 0.8277496695518494, Trainging R-squared 0.4208859414821745
#
# CNN validation R2: 0.08541277355441296
#
# Training Loss 0.8273354172706604, Trainging R-squared 0.4261145991264754
#
# CNN validation R2: 0.08468176803063981
#
# Training Loss 0.8296607136726379, Trainging R-squared 0.3664716273482552
#
# CNN validation R2: 0.07370873439970177
#
# Training Loss 0.8280614912509918, Trainging R-squared 0.4355516793943122
#
# CNN validation R2: 0.08126859414669446
#
# Training Loss 0.8231753706932068, Trainging R-squared 0.4934441248016286
#
# CNN validation R2: 0.09713925082791358
#
# Training Loss 0.8254163861274719, Trainging R-squared 0.4329047897085973
#
# CNN validation R2: 0.10643349277710534
#
# Training Loss 0.8315499424934387, Trainging R-squared 0.3656719627259568
#
# CNN validation R2: 0.11887052327667624
#
# Training Loss 0.8289779424667358, Trainging R-squared 0.4145791202909116
#
# CNN validation R2: 0.11905158967654961
#
# Training Loss 0.8333887457847595, Trainging R-squared 0.3137066853094919
#
# CNN validation R2: 0.10206539334841613
#
# Training Loss 0.8270650804042816, Trainging R-squared 0.4142046877408645
#
# CNN validation R2: 0.09454048098949075
#
# Training Loss 0.8312835991382599, Trainging R-squared 0.3630487489659795
#
# CNN validation R2: 0.09948368743326891
#
# Training Loss 0.8274444043636322, Trainging R-squared 0.4317493848426024
#
# CNN validation R2: 0.11412768170545229
#
# Training Loss 0.8311256468296051, Trainging R-squared 0.3851372762160328
#
# CNN validation R2: 0.12290286691523922
#
# Training Loss 0.8272976279258728, Trainging R-squared 0.49828416281736926
#
# CNN validation R2: 0.12526193013281695
#
# Training Loss 0.8336887359619141, Trainging R-squared 0.37462468048353126
#
# CNN validation R2: 0.11857630239135969
#
# Training Loss 0.8320139348506927, Trainging R-squared 0.3411089953149304
#
# CNN validation R2: 0.10727711429074616
#
# Training Loss 0.829493373632431, Trainging R-squared 0.41230333123747276
#
# CNN validation R2: 0.10964494942485908
#
# Training Loss 0.8302316963672638, Trainging R-squared 0.3683773557334321
#
# CNN validation R2: 0.1049856530804244
#
# Training Loss 0.8299334049224854, Trainging R-squared 0.34433069700035746
#
# CNN validation R2: 0.10055575840884456
#
# Training Loss 0.8288177847862244, Trainging R-squared 0.3851636522562673
#
# CNN validation R2: 0.11879623705519299
#
# Training Loss 0.8285164833068848, Trainging R-squared 0.4266162043970396
#
# CNN validation R2: 0.1312747490994277
#
# Training Loss 0.8267921209335327, Trainging R-squared 0.34273910384387596
#
# CNN validation R2: 0.13138274115218967
#
# Training Loss 0.8317266404628754, Trainging R-squared 0.33386890069867037
#
# CNN validation R2: 0.12678626157686412
#
# Training Loss 0.8289601504802704, Trainging R-squared 0.3440908424515
#
# CNN validation R2: 0.1128418325583257
#
# Training Loss 0.8260753154754639, Trainging R-squared 0.37082576458401095
#
# CNN validation R2: 0.09233942341352785
#
# Training Loss 0.8292357623577118, Trainging R-squared 0.47911382678770226
#
# CNN validation R2: 0.0859440059904234
#
# Training Loss 0.8255650997161865, Trainging R-squared 0.4526944992216084
#
# CNN validation R2: 0.08236053046844588
#
# Training Loss 0.8311120271682739, Trainging R-squared 0.2581049410070462
#
# CNN validation R2: 0.07056465032549064
#
# Training Loss 0.8261454701423645, Trainging R-squared 0.4677256979762556
#
# CNN validation R2: 0.06962259646261465
#
# Training Loss 0.8231140375137329, Trainging R-squared 0.4830591651203816
#
# CNN validation R2: 0.07617815086450913
#
# Training Loss 0.8249971270561218, Trainging R-squared 0.47767868981652173
#
# CNN validation R2: 0.07493970573890091
#
# Training Loss 0.8228211402893066, Trainging R-squared 0.456946260941876
#
# CNN validation R2: 0.06630008877784649
#
# Training Loss 0.8251402974128723, Trainging R-squared 0.4537961371697665
#
# CNN validation R2: 0.07453580693822326
#
# Training Loss 0.8240322768688202, Trainging R-squared 0.45450463836001215
#
# CNN validation R2: 0.087383394543402
#
# Training Loss 0.8281767964363098, Trainging R-squared 0.4355651473687787
#
# CNN validation R2: 0.08592657836009115
#
# Training Loss 0.8281184434890747, Trainging R-squared 0.4384638987337526
#
# CNN validation R2: 0.08993696958741604
#
# Training Loss 0.8238945007324219, Trainging R-squared 0.520495337533893
#
# CNN validation R2: 0.09394295814981563
#
# Training Loss 0.818893164396286, Trainging R-squared 0.5161265538399495
#
# CNN validation R2: 0.10093556553765926
#
# Training Loss 0.8258919417858124, Trainging R-squared 0.49661916202777107
#
# CNN validation R2: 0.11246080789780871
#
# Training Loss 0.8277513086795807, Trainging R-squared 0.41213351084939764
#
# CNN validation R2: 0.11545018605621438
#
# Training Loss 0.8261607587337494, Trainging R-squared 0.3801502308514186
#
# CNN validation R2: 0.10642364974299584
#
# Training Loss 0.8215053081512451, Trainging R-squared 0.5300096058440222
#
# CNN validation R2: 0.0917680976532752
#
# Training Loss 0.827655702829361, Trainging R-squared 0.36810989568544983
#
# CNN validation R2: 0.07612530185208644
#
# Training Loss 0.8244727849960327, Trainging R-squared 0.4320450764944736
#
# CNN validation R2: 0.07058760570134631
#
# Training Loss 0.8190065026283264, Trainging R-squared 0.5724997268251424
#
# CNN validation R2: 0.07316677983692155
#
# Training Loss 0.8305339217185974, Trainging R-squared 0.34867743495951503
#
# CNN validation R2: 0.0653716608288446
#
# Training Loss 0.8208749294281006, Trainging R-squared 0.5141669766406284
#
# CNN validation R2: 0.04644773909512484
#
# Training Loss 0.8178101181983948, Trainging R-squared 0.48763053845899396
#
# CNN validation R2: 0.02647731079296206
#
# Training Loss 0.8218510448932648, Trainging R-squared 0.526302951963129
#
# CNN validation R2: 0.02426889078374439
#
# Training Loss 0.8219040930271149, Trainging R-squared 0.47453052648192295
#
# CNN validation R2: 0.043448224193747276
#
# Training Loss 0.8217586874961853, Trainging R-squared 0.49738263626531226
#
# CNN validation R2: 0.06745709819741658
#
# Training Loss 0.8235481083393097, Trainging R-squared 0.47286304218554626
#
# CNN validation R2: 0.09269957008878676
#
# Training Loss 0.8215964138507843, Trainging R-squared 0.5387059011378335
#
# CNN validation R2: 0.10080525179227845
#
# Training Loss 0.8203195631504059, Trainging R-squared 0.5248395359798704
#
# CNN validation R2: 0.11430083660154139
#
# Training Loss 0.8238478899002075, Trainging R-squared 0.4716467765944483
#
# CNN validation R2: 0.12114600848246321
#
# Training Loss 0.8275071680545807, Trainging R-squared 0.2500392756641838
#
# CNN validation R2: 0.11942194897649461
#
# Training Loss 0.8216853141784668, Trainging R-squared 0.5261500693258574
#
# CNN validation R2: 0.1150685927859661
#
# Training Loss 0.8201690018177032, Trainging R-squared 0.522450648856999
#
# CNN validation R2: 0.11306621064099692
#
# Training Loss 0.8190474212169647, Trainging R-squared 0.5351245981067457
#
# CNN validation R2: 0.12007761920546961
#
# Training Loss 0.823170006275177, Trainging R-squared 0.44722740102467184
#
# CNN validation R2: 0.12352438581382358
#
# Training Loss 0.8267291486263275, Trainging R-squared 0.43292535779173313
#
# CNN validation R2: 0.11733777975757709
#
# Training Loss 0.8188027143478394, Trainging R-squared 0.46811258842956105
#
# CNN validation R2: 0.1003531444877947
#
# Training Loss 0.8174997866153717, Trainging R-squared 0.6182719155455418
#
# CNN validation R2: 0.08444979598188279
#
# Training Loss 0.8240228295326233, Trainging R-squared 0.5143243481734395
#
# CNN validation R2: 0.08481906588538168
#
# Training Loss 0.8202716112136841, Trainging R-squared 0.5244425754077406
#
# CNN validation R2: 0.07635524765578938
#
# Training Loss 0.8239973485469818, Trainging R-squared 0.44925771083625365
#
# CNN validation R2: 0.06934812333759899
#
# Training Loss 0.8188524842262268, Trainging R-squared 0.535969648632214
#
# CNN validation R2: 0.06267089287345928
#
# Training Loss 0.8194644749164581, Trainging R-squared 0.5548034179269994
#
# CNN validation R2: 0.06198855952772436
#
# Training Loss 0.8206822574138641, Trainging R-squared 0.5166442120610139
#
# CNN validation R2: 0.07362145853226076
#
# Training Loss 0.8214603364467621, Trainging R-squared 0.5385533729114769
#
# CNN validation R2: 0.09100525935969667
#
# Training Loss 0.8256436288356781, Trainging R-squared 0.32130576938400646
#
# CNN validation R2: 0.10737200091236743
#
# Training Loss 0.8211600184440613, Trainging R-squared 0.4858605714490105
#
# CNN validation R2: 0.11148355079348332
#
# Training Loss 0.821401059627533, Trainging R-squared 0.5243946759658459
#
# CNN validation R2: 0.10098181102325521
#
# Training Loss 0.8222986161708832, Trainging R-squared 0.5302577414394138
#
# CNN validation R2: 0.0935088640521306
#
# Training Loss 0.8169655203819275, Trainging R-squared 0.6329498829958258
#
# CNN validation R2: 0.08498615524206654
#
# Training Loss 0.819899708032608, Trainging R-squared 0.5429231718659218
#
# CNN validation R2: 0.07915976243429301
#
# Training Loss 0.8190683126449585, Trainging R-squared 0.49539636329834713
#
# CNN validation R2: 0.06368126482652553
#
# Training Loss 0.8183930218219757, Trainging R-squared 0.561805543083079
#
# CNN validation R2: 0.04433667424874049
#
# Training Loss 0.8174645602703094, Trainging R-squared 0.5811943728035058
#
# CNN validation R2: 0.03598705629105409
#
# Training Loss 0.8174624145030975, Trainging R-squared 0.555424303452988
#
# CNN validation R2: 0.04996802431099173
#
# Training Loss 0.8185419142246246, Trainging R-squared 0.5338993465702687
#
# CNN validation R2: 0.05678099002440373
#
# Training Loss 0.8181605339050293, Trainging R-squared 0.5701890892977612
#
# CNN validation R2: 0.060313244044904124
#
# Training Loss 0.8147222399711609, Trainging R-squared 0.65109231235659
#
# CNN validation R2: 0.08398364385213025
#
# Training Loss 0.8183344006538391, Trainging R-squared 0.5687765713063809
#
# CNN validation R2: 0.0917853931663366
#
# Training Loss 0.8226901888847351, Trainging R-squared 0.5263887565138616
#
# CNN validation R2: 0.09788724912432711
#
# Training Loss 0.8158733546733856, Trainging R-squared 0.6103781124229608
#
# CNN validation R2: 0.10731259319489173
#
# Training Loss 0.8205298483371735, Trainging R-squared 0.5218039984602816
#
# CNN validation R2: 0.1109648111438849
#
# Training Loss 0.8173366785049438, Trainging R-squared 0.5580632985296017
#
# CNN validation R2: 0.10366782175029904
#
# Training Loss 0.8190565407276154, Trainging R-squared 0.5680711432156226
#
# CNN validation R2: 0.09690460466510048
#
# Training Loss 0.8169143199920654, Trainging R-squared 0.5970360218780018
#
# CNN validation R2: 0.10026719895384206
#
# Training Loss 0.8186628222465515, Trainging R-squared 0.5614499511441122
#
# CNN validation R2: 0.10132533993735054
#
# Training Loss 0.8178198039531708, Trainging R-squared 0.6085698819608878
#
# CNN validation R2: 0.09184927030509143
#
# Training Loss 0.8170689344406128, Trainging R-squared 0.6216668437102888
#
# CNN validation R2: 0.08844731617288903
#
# Training Loss 0.8135907351970673, Trainging R-squared 0.6553028734706041
#
# CNN validation R2: 0.09130578255483501
#
# Training Loss 0.8159536719322205, Trainging R-squared 0.6069841609986235
#
# CNN validation R2: 0.09454405269871641
#
# Training Loss 0.8191019296646118, Trainging R-squared 0.49014688540110496
#
# CNN validation R2: 0.10203060364928818
#
# Training Loss 0.8242723643779755, Trainging R-squared 0.5130974090690753
#
# CNN validation R2: 0.10938026769908799
#
# Training Loss 0.8176859617233276, Trainging R-squared 0.6003353427594387
#
# CNN validation R2: 0.11963872245893703
#
# Training Loss 0.8175036013126373, Trainging R-squared 0.5718563513258528
#
# CNN validation R2: 0.11414605468692451
#
# Training Loss 0.8147917985916138, Trainging R-squared 0.6427444305117466
#
# CNN validation R2: 0.10959202573970062
#
# Training Loss 0.8192049264907837, Trainging R-squared 0.47234796214411967
#
# CNN validation R2: 0.10855854513696733
#
# Training Loss 0.8209843337535858, Trainging R-squared 0.5503424699669536
#
# CNN validation R2: 0.10964390651775685
#
# Training Loss 0.8172744810581207, Trainging R-squared 0.49359850519265225
#
# CNN validation R2: 0.10674884987975741
#
# Training Loss 0.8177534639835358, Trainging R-squared 0.5992628907331925
#
# CNN validation R2: 0.09669057037963352
#
# Training Loss 0.8174638152122498, Trainging R-squared 0.606345416225901
#
# CNN validation R2: 0.08045614260427542
#
# Fold 3
# Training Loss 0.882213681936264, Trainging R-squared -0.5070097702603196
#
# CNN validation R2: -0.2894268469946676
#
# Training Loss 0.8774457275867462, Trainging R-squared -0.2923722223451284
#
# CNN validation R2: -0.28351151532536134
#
# Training Loss 0.8519649803638458, Trainging R-squared -0.164381841806686
#
# CNN validation R2: -0.27527862777571743
#
# Training Loss 0.8550337851047516, Trainging R-squared -0.04264996129172649
#
# CNN validation R2: -0.26704278789423175
#
# Training Loss 0.8486320674419403, Trainging R-squared -0.09047592694301387
#
# CNN validation R2: -0.25902854225822025
#
# Training Loss 0.8464423418045044, Trainging R-squared 0.05575835954403688
#
# CNN validation R2: -0.25000952818657174
#
# Training Loss 0.85453861951828, Trainging R-squared -0.06952238726124027
#
# CNN validation R2: -0.24083275586532893
#
# Training Loss 0.8526654541492462, Trainging R-squared 0.05578795654715196
#
# CNN validation R2: -0.22936375232455997
#
# Training Loss 0.8568155467510223, Trainging R-squared -0.1095729400308848
#
# CNN validation R2: -0.21587108281227751
#
# Training Loss 0.8569341897964478, Trainging R-squared -0.11763105752297531
#
# CNN validation R2: -0.2013260830403132
#
# Training Loss 0.8570932745933533, Trainging R-squared -0.02965862535274233
#
# CNN validation R2: -0.19085035075453693
#
# Training Loss 0.8540137410163879, Trainging R-squared -0.03855394668536255
#
# CNN validation R2: -0.1832545877070063
#
# Training Loss 0.8610682487487793, Trainging R-squared -0.12673019317420364
#
# CNN validation R2: -0.17903595310587084
#
# ...
#
# Training Loss 0.8373129963874817, Trainging R-squared 0.24736912445716383
#
# CNN validation R2: -0.026931897785934855
#
# Training Loss 0.8400892913341522, Trainging R-squared 0.22148846838805633
#
# CNN validation R2: -0.02130401390804415
#
# Training Loss 0.83917635679245, Trainging R-squared 0.24070371141360217
#
# CNN validation R2: -0.015201876934918257
#
# Training Loss 0.8380323052406311, Trainging R-squared 0.24634659104658022
#
# CNN validation R2: -0.014872100994787862
#
# Training Loss 0.8353630602359772, Trainging R-squared 0.2911200395373391
#
# CNN validation R2: -0.017252255723002152
#
# Training Loss 0.8398913145065308, Trainging R-squared 0.1896525161537894
#
# CNN validation R2: -0.02509528214951129
#
# Training Loss 0.8356138467788696, Trainging R-squared 0.17693330511600192
#
# CNN validation R2: -0.025734309615550177
#
# Training Loss 0.8367566466331482, Trainging R-squared 0.20672383095777755
#
# CNN validation R2: -0.023466435198477575
#
# Training Loss 0.8382461369037628, Trainging R-squared 0.20280816458788675
#
# CNN validation R2: -0.01457207624707424
#
# Training Loss 0.8395599722862244, Trainging R-squared 0.16794747374663835
#
# CNN validation R2: -0.0072901845592849845
#
# Training Loss 0.8373821079730988, Trainging R-squared 0.09867876064508371
#
# CNN validation R2: -0.013699941831005091
#
# Training Loss 0.8391162753105164, Trainging R-squared 0.20390460017321257
#
# CNN validation R2: -0.016784690638431576
#
# Training Loss 0.8337923288345337, Trainging R-squared 0.2853263435314506
#
# CNN validation R2: -0.01683488770288938
#
# Training Loss 0.833377480506897, Trainging R-squared 0.2710805973715922
#
# CNN validation R2: -0.026496012942476888
#
# Training Loss 0.8393668532371521, Trainging R-squared 0.2159243071439302
#
# CNN validation R2: -0.023181983702964093
#
# Training Loss 0.8342678248882294, Trainging R-squared 0.28818465113082814
#
# CNN validation R2: -0.01968927485382921
#
# Training Loss 0.8352493941783905, Trainging R-squared 0.20900163351353787
#
# CNN validation R2: -0.01880603304948736
#
# Training Loss 0.8345730602741241, Trainging R-squared 0.2545414914002109
#
# CNN validation R2: -0.02251314368595403
#
# Training Loss 0.8311798870563507, Trainging R-squared 0.31199804915501966
#
# CNN validation R2: -0.02559722329436087
#
# Training Loss 0.8367198407649994, Trainging R-squared 0.2879807881819913
#
# CNN validation R2: -0.0338055358048156
#
# Training Loss 0.8399772942066193, Trainging R-squared 0.2454163633886626
#
# CNN validation R2: -0.043360215678781344
#
# Training Loss 0.8335874676704407, Trainging R-squared 0.20013449695407934
#
# CNN validation R2: -0.04706049441277593
#
# Training Loss 0.8346363306045532, Trainging R-squared 0.27468365592902033
#
# CNN validation R2: -0.055205068437781835
#
# Training Loss 0.8310810327529907, Trainging R-squared 0.27081605757840654
#
# CNN validation R2: -0.0554654258246402
#
# Training Loss 0.829094409942627, Trainging R-squared 0.28134356596743954
#
# CNN validation R2: -0.058519615783213075
#
# Training Loss 0.8306263983249664, Trainging R-squared 0.3389264880047701
#
# CNN validation R2: -0.05133837129781482
#
# Training Loss 0.831872969865799, Trainging R-squared 0.36997203088983316
#
# CNN validation R2: -0.0382060083927136
#
# Training Loss 0.8311217427253723, Trainging R-squared 0.3428041173753715
#
# CNN validation R2: -0.02354543077448701
#
# Training Loss 0.8278079926967621, Trainging R-squared 0.3408845343231017
#
# CNN validation R2: -0.021047297211830907
#
# Training Loss 0.8260703682899475, Trainging R-squared 0.4275929764374576
#
# CNN validation R2: -0.026020512563348752
#
# Training Loss 0.8312364220619202, Trainging R-squared 0.34889296088424404
#
# CNN validation R2: -0.02247034050052671
#
# Training Loss 0.8367711901664734, Trainging R-squared 0.27558549438982083
#
# CNN validation R2: -0.014204809597751777
#
# Training Loss 0.8290303945541382, Trainging R-squared 0.3493385975473472
#
# CNN validation R2: -0.010431375442503554
#
# Training Loss 0.8247991502285004, Trainging R-squared 0.46767611759640926
#
# CNN validation R2: -0.012613086952467711
#
# Training Loss 0.8286569714546204, Trainging R-squared 0.3055922145138457
#
# CNN validation R2: -0.017231599255668306
#
# Training Loss 0.830101877450943, Trainging R-squared 0.32842500346799264
#
# CNN validation R2: -0.01627990641707494
#
# Training Loss 0.8277883529663086, Trainging R-squared 0.4028035512397262
#
# CNN validation R2: -0.013286419344179456
#
# Training Loss 0.830470621585846, Trainging R-squared 0.34976193120602084
#
# CNN validation R2: -0.019459109165261168
#
# Training Loss 0.828795850276947, Trainging R-squared 0.3754393799604141
#
# CNN validation R2: -0.02076066128799353
#
# Training Loss 0.8245782852172852, Trainging R-squared 0.372949046883694
#
# CNN validation R2: -0.02406006550483253
#
# Training Loss 0.8288340866565704, Trainging R-squared 0.31111185588630713
#
# CNN validation R2: -0.02736049627990439
#
# Training Loss 0.8295240104198456, Trainging R-squared 0.3936910265881046
#
# CNN validation R2: -0.026066105339124346
#
# Training Loss 0.8239427804946899, Trainging R-squared 0.42510035972864546
#
# CNN validation R2: -0.02545504032058299
#
# Training Loss 0.8263862431049347, Trainging R-squared 0.4098355284603591
#
# CNN validation R2: -0.024699229664636835
#
# Training Loss 0.8242420852184296, Trainging R-squared 0.4516628774365943
#
# CNN validation R2: -0.021805448731540278
#
# Training Loss 0.8234245181083679, Trainging R-squared 0.4319741536873365
#
# CNN validation R2: -0.017839322250574163
#
# Training Loss 0.826764702796936, Trainging R-squared 0.40252828843834476
#
# CNN validation R2: -0.020195540921965127
#
# Training Loss 0.829661637544632, Trainging R-squared 0.33169751086944566
#
# CNN validation R2: -0.025899409859837685
#
# Training Loss 0.8242602050304413, Trainging R-squared 0.38569863075530897
#
# CNN validation R2: -0.02890891985567301
#
# Training Loss 0.8307602107524872, Trainging R-squared 0.3910833944764374
#
# CNN validation R2: -0.029739879406115777
#
# Training Loss 0.8317723870277405, Trainging R-squared 0.34611472713500424
#
# CNN validation R2: -0.031711050542987285
#
# Training Loss 0.8257856965065002, Trainging R-squared 0.44866767424709975
#
# CNN validation R2: -0.03396097293600797
#
# Training Loss 0.8272292912006378, Trainging R-squared 0.3083159061306944
#
# CNN validation R2: -0.031147206081241274
#
# Training Loss 0.83201003074646, Trainging R-squared 0.25053216342756124
#
# CNN validation R2: -0.024946281713907836
#
# Training Loss 0.8312931656837463, Trainging R-squared 0.3780180108465745
#
# CNN validation R2: -0.020177685141935464
#
# Training Loss 0.8276138603687286, Trainging R-squared 0.4035508502178825
#
# CNN validation R2: -0.017162743345600084
#
# Training Loss 0.824142575263977, Trainging R-squared 0.4065129459108694
#
# CNN validation R2: -0.01190231038109707
#
# Training Loss 0.8282710313796997, Trainging R-squared 0.3442835518802148
#
# CNN validation R2: -0.005673076171226088
#
# Training Loss 0.827069103717804, Trainging R-squared 0.34687242769918336
#
# CNN validation R2: -0.019809050141161577
#
# Training Loss 0.8210004270076752, Trainging R-squared 0.5122428603418632
#
# CNN validation R2: -0.052735662150547924
#
# Training Loss 0.8240522742271423, Trainging R-squared 0.4416258192804655
#
# CNN validation R2: -0.06885296315633338
#
# Training Loss 0.8244733512401581, Trainging R-squared 0.4311450952926848
#
# CNN validation R2: -0.054937558534377984
#
# Training Loss 0.825691819190979, Trainging R-squared 0.36478907574777664
#
# CNN validation R2: -0.03267853571115026
#
# Training Loss 0.8291064202785492, Trainging R-squared 0.4006239428361832
#
# CNN validation R2: -0.009452030247037002
#
# Training Loss 0.8252922892570496, Trainging R-squared 0.4733029410018341
#
# CNN validation R2: -0.0037008093882433535
#
# Training Loss 0.8213965594768524, Trainging R-squared 0.4999559682861684
#
# CNN validation R2: -0.004217195919001215
#
# Training Loss 0.8283802270889282, Trainging R-squared 0.3087358685452662
#
# CNN validation R2: -0.010930142278512245
#
# Training Loss 0.8253694176673889, Trainging R-squared 0.4249659334072776
#
# CNN validation R2: -0.00991728577559231
#
# Training Loss 0.8245518803596497, Trainging R-squared 0.4371116698061566
#
# CNN validation R2: -0.009485163144831943
#
# Training Loss 0.8261905014514923, Trainging R-squared 0.4074898671195744
#
# CNN validation R2: -0.012071822754208261
#
# Training Loss 0.8248550891876221, Trainging R-squared 0.3869482388792857
#
# CNN validation R2: -0.010912186752261854
#
# Training Loss 0.8224909007549286, Trainging R-squared 0.4559573844505873
#
# CNN validation R2: -0.013059354874372486
#
# Training Loss 0.8226225972175598, Trainging R-squared 0.42552548836036574
#
# CNN validation R2: -0.02015086450795417
#
# Training Loss 0.8205795288085938, Trainging R-squared 0.5203532103320986
#
# CNN validation R2: -0.022661502283651824
#
# Training Loss 0.8261904120445251, Trainging R-squared 0.39032816268389803
#
# CNN validation R2: -0.02405627377727304
#
# Training Loss 0.8196612298488617, Trainging R-squared 0.5194407403241977
#
# CNN validation R2: -0.029156849626038484
#
# Training Loss 0.826559454202652, Trainging R-squared 0.3083119163720003
#
# CNN validation R2: -0.03030174884446546
#
# Training Loss 0.8210181295871735, Trainging R-squared 0.4869907036848161
#
# CNN validation R2: -0.033329541694076203
#
# Training Loss 0.8215037286281586, Trainging R-squared 0.44650455071529527
#
# CNN validation R2: -0.036709566073651834
#
# Training Loss 0.8243128061294556, Trainging R-squared 0.4394162128184408
#
# CNN validation R2: -0.0450152215495917
#
# Training Loss 0.8202463090419769, Trainging R-squared 0.5539566866041983
#
# CNN validation R2: -0.05232724715915815
#
# Training Loss 0.8210422992706299, Trainging R-squared 0.45767660050997594
#
# CNN validation R2: -0.05641655911213439
#
# Training Loss 0.8203625082969666, Trainging R-squared 0.5105398624365839
#
# CNN validation R2: -0.06446891814435951
#
# Training Loss 0.8230116069316864, Trainging R-squared 0.41768176202282925
#
# CNN validation R2: -0.06636810856186437
#
# Training Loss 0.8186873197555542, Trainging R-squared 0.47210283951820475
#
# CNN validation R2: -0.053040576918257254
#
# Training Loss 0.8214410841464996, Trainging R-squared 0.4800609832461026
#
# CNN validation R2: -0.039467284284108506
#
# Training Loss 0.819702684879303, Trainging R-squared 0.47452272899312403
#
# CNN validation R2: -0.0357011893004755
#
# Training Loss 0.8240537941455841, Trainging R-squared 0.4427738439151001
#
# CNN validation R2: -0.0428241706352156
#
# Training Loss 0.8225332796573639, Trainging R-squared 0.4870696450970337
#
# CNN validation R2: -0.0367401372614109
#
# Training Loss 0.8225276172161102, Trainging R-squared 0.47945596872326446
#
# CNN validation R2: -0.023252030741767904
#
# Training Loss 0.8194118142127991, Trainging R-squared 0.43665561779888706
#
# CNN validation R2: -0.01895127135082647
#
# Training Loss 0.8239338397979736, Trainging R-squared 0.39207746359435924
#
# CNN validation R2: -0.015366140358221536
#
# Training Loss 0.8212514519691467, Trainging R-squared 0.4783677840229332
#
# CNN validation R2: -0.015789639676505818
#
# Training Loss 0.8232075572013855, Trainging R-squared 0.462050402497415
#
# CNN validation R2: -0.023071382266696527
#
# Training Loss 0.8218075037002563, Trainging R-squared 0.4907301302123469
#
# CNN validation R2: -0.03269072367473741
#
# Training Loss 0.8199940025806427, Trainging R-squared 0.5249139617921175
#
# CNN validation R2: -0.03989359103299245
#
# Training Loss 0.8200992047786713, Trainging R-squared 0.4910712294948953
#
# CNN validation R2: -0.050096315638698985
#
# Training Loss 0.8180911242961884, Trainging R-squared 0.4817845382663183
#
# CNN validation R2: -0.048871435479489134
#
# Training Loss 0.8201631307601929, Trainging R-squared 0.5003638981342737
#
# CNN validation R2: -0.037386687591854095
#
# Training Loss 0.8200191855430603, Trainging R-squared 0.4500453766269902
#
# CNN validation R2: -0.02367887092099119
#
# Training Loss 0.8231714069843292, Trainging R-squared 0.4506640087248957
#
# CNN validation R2: -0.013417473585332795
#
# Training Loss 0.8162302076816559, Trainging R-squared 0.5603482982260819
#
# CNN validation R2: -0.002460001065438644
#
# Training Loss 0.8216590285301208, Trainging R-squared 0.5375019030270642
#
# CNN validation R2: 0.0013764572457110047
#
# Training Loss 0.8176078498363495, Trainging R-squared 0.5225712749876941
#
# CNN validation R2: 0.002390012670861752
#
# Training Loss 0.8205263018608093, Trainging R-squared 0.4797197369067878
#
# CNN validation R2: 0.0012598498671664848
#
# Training Loss 0.8172855377197266, Trainging R-squared 0.552856667235198
#
# CNN validation R2: -0.0024718818481777594
#
# Training Loss 0.823889285326004, Trainging R-squared 0.3263191346714249
#
# CNN validation R2: -0.00619055410659014
#
# Training Loss 0.8171910643577576, Trainging R-squared 0.5516128609500768
#
# CNN validation R2: -0.010116725862873488
#
# Training Loss 0.8173113167285919, Trainging R-squared 0.5130829783633073
#
# CNN validation R2: -0.014645631072699283
#
# Training Loss 0.8157131671905518, Trainging R-squared 0.5692006598070212
#
# CNN validation R2: -0.018713687583918226
#
# Training Loss 0.8235030472278595, Trainging R-squared 0.3806484460962687
#
# CNN validation R2: -0.02437142326641406
#
# Training Loss 0.8136281669139862, Trainging R-squared 0.639347156918348
#
# CNN validation R2: -0.03322812575523648
#
# Training Loss 0.8176645934581757, Trainging R-squared 0.5366079046438007
#
# CNN validation R2: -0.03623622841224727
#
# Training Loss 0.8199450671672821, Trainging R-squared 0.5063086405205971
#
# CNN validation R2: -0.0441687729781538
#
# Training Loss 0.8178451657295227, Trainging R-squared 0.5581431696199819
#
# CNN validation R2: -0.05006600779275783
#
# Training Loss 0.815288245677948, Trainging R-squared 0.5816344720887825
#
# CNN validation R2: -0.054727154703087644
#
# Training Loss 0.8177027404308319, Trainging R-squared 0.5342445824111551
#
# CNN validation R2: -0.0590888184515902
#
# Training Loss 0.8203997910022736, Trainging R-squared 0.4270165722999315
#
# CNN validation R2: -0.0662205385616611
#
# Training Loss 0.8168109953403473, Trainging R-squared 0.5531667428916085
#
# CNN validation R2: -0.06416061440406584
#
# Training Loss 0.8211717009544373, Trainging R-squared 0.42388251446418235
#
# CNN validation R2: -0.04992093435035372
#
# Training Loss 0.8177675008773804, Trainging R-squared 0.4898964837271754
#
# CNN validation R2: -0.036498471389908804
#
# Training Loss 0.8173003196716309, Trainging R-squared 0.5553931836042374
#
# CNN validation R2: -0.0416041451025313
#
# Training Loss 0.8185021877288818, Trainging R-squared 0.4604842859472959
#
# CNN validation R2: -0.03348534167496331
#
# Training Loss 0.8159733712673187, Trainging R-squared 0.5873029578331174
#
# CNN validation R2: -0.028961014507889404
#
# Training Loss 0.8234611749649048, Trainging R-squared 0.48685534303584443
#
# CNN validation R2: -0.02589029092889228
#
# Training Loss 0.8182255327701569, Trainging R-squared 0.5176547860689026
#
# CNN validation R2: -0.03739207525630728
#
# Training Loss 0.8163625001907349, Trainging R-squared 0.5321472361685048
#
# CNN validation R2: -0.05549505780954356
#
# Training Loss 0.8186911940574646, Trainging R-squared 0.4940317326566894
#
# CNN validation R2: -0.05944451360639491
#
# Training Loss 0.8181693255901337, Trainging R-squared 0.5182668118787317
#
# CNN validation R2: -0.06495530435285068
#
# Training Loss 0.8219229280948639, Trainging R-squared 0.45384880389897886
#
# CNN validation R2: -0.07850873399402536
#
# Training Loss 0.8140515685081482, Trainging R-squared 0.612954602919676
#
# CNN validation R2: -0.10006319294582766
#
# Training Loss 0.8167579472064972, Trainging R-squared 0.5674372664799416
#
# CNN validation R2: -0.12683045573176344
#
# Training Loss 0.8215272128582001, Trainging R-squared 0.47591556100801
#
# CNN validation R2: -0.11980751648663956
#
# Training Loss 0.8174391984939575, Trainging R-squared 0.5903247496279511
#
# CNN validation R2: -0.11428222129806687
#
# Training Loss 0.8125579953193665, Trainging R-squared 0.6190026516745291
#
# CNN validation R2: -0.08932116506826704
#
# Training Loss 0.8180007338523865, Trainging R-squared 0.44758823880435283
#
# CNN validation R2: -0.04821684406747351
#
# Training Loss 0.8168173134326935, Trainging R-squared 0.543114388000774
#
# CNN validation R2: -0.028405207669126242

# %%
r2 = []
r2_r = []
r2_v = []
for best_model, m, std in models:
    i = 0
    # best_model=models[1]
    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    best_model.eval()
    for inputs, labels in test_loader:
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to('cuda')
        labels = labels.to('cuda')
        if i == 0:
            cnnOutputs = best_model(inputs).to('cpu')
            l = labels.to('cpu')
        else:
            cnnOutputs = torch.cat((cnnOutputs, best_model(inputs).to('cpu')), 0)
            l = torch.cat((l, labels.to('cpu')), 0)
        i+=1
    r2_v.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy()[:,1], cnnOutputs.to('cpu').detach().numpy()[:,1]))
    r2_r.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy()[:,0], cnnOutputs.to('cpu').detach().numpy()[:,0]))
    r2.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy()))

# %%
np.mean(r2)
# Out:
# 0.03192516909693901

# %%
np.mean(r2_v)
# Out:
# 0.04082095171521418

# %%
np.mean(r2_r)
# Out:
# 0.023029369542872047
