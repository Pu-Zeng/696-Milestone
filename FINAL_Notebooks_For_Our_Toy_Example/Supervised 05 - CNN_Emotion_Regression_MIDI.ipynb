# %%
# Train the CNN Emotion Regression Model with MIDI data#
# Last editted by Pu Zeng, 18/10/2023 #

# %%
# !git clone https://github.com/Pu-Zeng/696-Milestone.git
# Out:
# fatal: destination path '696-Milestone' already exists and is not an empty directory.

# %%
# !pip install midi2audio
# !pip install pretty_midi
# !pip install librosa
# !apt install fluidsynth
# Out:
# Requirement already satisfied: midi2audio in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: pretty_midi in /usr/local/lib/python3.10/dist-packages (0.2.10)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.23.5)
# Requirement already satisfied: mido>=1.1.16 in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.16.0)
# Requirement already satisfied: packaging~=23.1 in /usr/local/lib/python3.10/dist-packages (from mido>=1.1.16->pretty_midi) (23.2)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (67.7.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fluidsynth is already the newest version (2.2.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %%
import pandas as pd
from tqdm import tqdm
import os
from sklearn.model_selection import KFold
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from torch.utils.data import TensorDataset
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset
import string
import numpy as np
import pickle
from sklearn import preprocessing
import torch
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings
import json
warnings.filterwarnings('ignore')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Calculate the mean Arousal and Valence score from raw json data
def read_json_av(fileName):
    file = open(fileName,'r')
    lines = json.load(file)
    file.close()
    file = pd.DataFrame(pd.DataFrame(lines['pieces']).T['midi'])
    ann = pd.DataFrame(lines['annotations']).T.reset_index()
    file['arousal'] = np.nan
    file['valence'] = np.nan
    i = 1
    for i in range(len(file)):
        f = file.iloc[i]
        raw = ann[ann['index'].str.contains(f.name+'_')]
        ar = []
        va = []
        for j in range(len(raw)):
            row = raw.iloc[j]
            ar.append(np.mean(row['arousal']))
            va.append(np.mean(row['valence']))
        file['arousal'].iloc[i] = np.mean(ar)
        file['valence'].iloc[i] = np.mean(va)
    return file.reset_index()[['midi','arousal','valence']]

# %%
j1 = read_json_av('/content/696-Milestone/Toy_Dataset/VGG/vgmidi_raw_1.json');
j2 = read_json_av('/content/696-Milestone/Toy_Dataset/VGG/vgmidi_raw_2.json');
data = pd.concat([j1,j2],ignore_index=True)

# %%
# Transform MIDI into MFCCs

res1 = []
from midi2audio import FluidSynth
import librosa
import librosa.display
import pretty_midi
import numpy as np
def parse_piano_most(file_path):
    mean_intensity = []
    midi_data = pretty_midi.PrettyMIDI(file_path)
    for instrument in midi_data.instruments:
        mean_intensity.append(instrument.get_piano_roll().mean())
    instruments_to_remove_index = np.argsort(mean_intensity)[:-1]
    instruments_to_remove = []
    for i in instruments_to_remove_index:
        instruments_to_remove.append(midi_data.instruments[i])
    for i in instruments_to_remove:
        midi_data.instruments.remove(i)
    midi_data.instruments[0].program=0
    return midi_data

for i in tqdm(range(len(data))):
    try:
        m = data.iloc[i]
        filename = '/content/696-Milestone/Toy_Dataset/VGG/midi/'+ m['midi']
        midi_data = parse_piano_most(filename)
        if midi_data == None:
            continue
        midi_data.write('1.mid')
        fs = FluidSynth();
        fs.midi_to_audio('1.mid', 'output.wav');
        y, sr = librosa.load('output.wav');
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
        res1.append([mfccs, m['arousal'],m['valence']])
    except:
        pass
# Out:
# 100%|██████████| 200/200 [10:24<00:00,  3.12s/it]

# %%
# Organize the dataset
import numpy as np
midi = []
for m in res1:
    midi.append([m[0], [m[1],m[2]]])

# %%
# Find the minimum length to uniform all MFCCs to the same shape
dim=359

# %%
# Final dataset
from tqdm import tqdm
X = []
y = []
for m in res1:
    # X.append(m[0][:, :dim])
    if m[0].shape[1]>=359:
      X.append(m[0].T[0:dim,:])
      y.append([m[1], m[2]])
X = np.array(X)

# %%
# Define CNN regression model
class CNNModel(nn.Module):
    def __init__(self, hiddenSize, outChannels, dropoutRate, activate):
        super().__init__()
        self.outChannels = outChannels
        self.activate = nn.Sigmoid() if activate == "Sigmoid" else nn.ReLU()
        self.conv1 = nn.Conv2d(1, 24, (10,1))
        self.pool = nn.MaxPool2d((2, 1))

        self.conv2 = nn.Conv2d(24, 48, (10,1))
        self.bn1 = nn.BatchNorm2d(48)
        self.conv3 = nn.Conv2d(48, 96, (10,1))
        self.bn2 = nn.BatchNorm2d(96)
        self.conv4 = nn.Conv2d(96, 192, (10,2))
        self.bn3 = nn.BatchNorm2d(192)
        self.conv5 = nn.Conv2d(192, 96, (5,2))
        self.bn4 = nn.BatchNorm2d(96)
        self.conv6 = nn.Conv2d(96, 96, (5,2))
        self.dense1 = nn.Linear(1632, hiddenSize)
        self.dropout = nn.Dropout(dropoutRate)
        self.dense2 = nn.Linear(hiddenSize, 2)

    def forward(self, x):
        x = self.pool(self.activate(self.conv1(x)))
        x = self.pool(self.bn1(self.activate(self.conv2(x))))
        # print(x.shape)
        x = self.dropout(self.pool(self.bn2(self.activate(self.conv3(x)))))
        x = self.pool(self.bn3(self.activate(self.conv4(x))))
        x = self.pool(self.bn4(self.activate(self.conv5(x))))

        x = self.activate(self.conv6(x))
        # print(x.shape)
        x = x.view(-1, 1632)

        x = self.dropout(self.activate(self.dense1(x)))
        # print(self.dense2(x))
        return self.dense2(x)

# Number of neurons in the first fully-connected layer
hiddenSize = 64
# Number of feature filters in second convolutional layer
numFilters = 25
# Dropout rate
dropoutRate = 0.3
# Activation function
activation = "ReLU"
# Learning rate
learningRate = 0.001
# Momentum for SGD optimizer
momentum = 0.8
# Number of training epochs
numEpochs = 200

# %%
# Define Train and Validation function
from tqdm import tqdm
def train_epoch(cnn,device,dataloader,loss_fn,optimizer, m, std):
    cnn.train()
    cnnRunningLoss = 0
    total = 0
    R2 = 0
    for i, (inputs, labels) in enumerate(dataloader, 0):
        optimizer.zero_grad()
        # Normalization
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to(device)
        labels = labels.to(device)
        # Forward propagation
        cnnOutputs = cnn(inputs)

        l2_lambda = 0.01
        l2_reg = torch.tensor(0.).to(device)

        for param in cnn.parameters():
            l2_reg += torch.norm(param)

        # Backpropagation
        cnnLoss = criterion(cnnOutputs, labels)+l2_reg*l2_lambda
        cnnLoss.backward()

        # Gradient update
        optimizer.step()

        cnnRunningLoss += cnnLoss.item()
        total += 1
        # if (i+1) % 20 == 0:    # print every 2000 mini-batches
        #     print(cnnLoss)
        R2 += sklearn.metrics.r2_score(labels.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy())
    print('Training Loss {}, Trainging R-squared {}'.format(str(cnnRunningLoss/total), str(R2/total)))
    return cnnRunningLoss/total, R2
def valid_epoch(cnn,device,dataloader,loss_fn, m, std):
    cnn.eval()
    totalLoss = 0
    total = 0
    R2 = 0
    for inputs, labels in dataloader:
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to(device)
        labels = labels.to(device)
        cnnOutputs = cnn(inputs)
        cnnLoss = criterion(cnnOutputs, labels)#+l2_reg*l2_lambda
        # print(cnnLoss)
        totalLoss += cnnLoss.item()
        total +=1
        R2 += sklearn.metrics.r2_score(labels.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy())
    print('\nCNN validation R2: {}\n '.format(str(R2/total)))
    cnn.train()
    return totalLoss/total, R2

# %%
import sklearn
X_train_v, X_test, y_train_v, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train_v = torch.as_tensor(X_train_v, dtype=torch.float) # an alternative to torch.from_numpy
y_train_v = torch.as_tensor(y_train_v, dtype=torch.float)
X_test = torch.as_tensor(X_test, dtype=torch.float)
y_test = torch.as_tensor(y_test, dtype=torch.float)
splits=KFold(n_splits=5,shuffle=True,random_state=42)
train_dataset = TensorDataset(X_train_v, y_train_v)
test_dataset = TensorDataset(X_test, y_test)
batch_size=128
models = []
history = {'fold':[], 'train_loss': [], 'test_loss': [],'train_R2':[],'test_R2':[]}


for fold, (train_idx,val_idx) in enumerate(splits.split(np.arange(len(X_train_v)))):
    print('Fold {}'.format(fold + 1))
    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(val_idx)
    m = np.vstack(X_train_v[train_idx]).mean()
    std = np.vstack(X_train_v[train_idx]).std()
    train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler)
    test_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=test_sampler)

    model = CNNModel(hiddenSize, numFilters, dropoutRate, activation).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(list(model.parameters()), lr=learningRate, momentum=momentum)
    # optimizer = torch.optim.Adam(list(model.parameters()), lr=learningRate)
    best_test = -np.inf
    best_model = None
    for epoch in range(numEpochs):
        train_loss, train_R2=train_epoch(model,device,train_loader,criterion,optimizer, m, std)
        test_loss, test_R2=valid_epoch(model,device,test_loader,criterion, m, std)
        history['fold'].append(fold)
        history['train_loss'].append(train_loss)
        history['test_loss'].append(test_loss)
        history['train_R2'].append(train_R2)
        history['test_R2'].append(test_R2)
        if test_R2>best_test:
            best_test = test_R2
            best_model = model
    models.append([best_model, m, std])
# Out:
# Fold 1
# Training Loss 0.8849718868732452, Trainging R-squared -0.6621641966042092
#
# CNN validation R2: -0.4211800908004558
#
# Training Loss 0.85919588804245, Trainging R-squared -0.17834249252497825
#
# CNN validation R2: -0.4091937365700774
#
# Training Loss 0.8635482490062714, Trainging R-squared -0.3182495521111365
#
# CNN validation R2: -0.39591810584448894
#
# Training Loss 0.8586834967136383, Trainging R-squared -0.22280109393286984
#
# CNN validation R2: -0.38032548818842393
#
# Training Loss 0.8519959449768066, Trainging R-squared -0.18822630932065715
#
# CNN validation R2: -0.3669384973232732
#
# Training Loss 0.8593314290046692, Trainging R-squared -0.31583376532233126
#
# CNN validation R2: -0.3571416572141555
#
# Training Loss 0.8553756475448608, Trainging R-squared -0.18523011550246393
#
# CNN validation R2: -0.3506794363139367
#
# Training Loss 0.8470960557460785, Trainging R-squared -0.13367726094586385
#
# CNN validation R2: -0.3476421565936456
#
# Training Loss 0.8565646409988403, Trainging R-squared -0.2102686161417831
#
# CNN validation R2: -0.3440808132934511
#
# Training Loss 0.8521699011325836, Trainging R-squared -0.14270598374445748
#
# CNN validation R2: -0.341251130381119
#
# Training Loss 0.8494635224342346, Trainging R-squared -0.2271209969542209
#
# CNN validation R2: -0.3391457209458465
#
# Training Loss 0.8478115499019623, Trainging R-squared -0.07207028443451816
#
# CNN validation R2: -0.3360711229810195
#
# Training Loss 0.8453130722045898, Trainging R-squared -0.01768713657393317
#
# CNN validation R2: -0.33152876678622223
#
# Training Loss 0.8502542972564697, Trainging R-squared -0.08778285565195543
#
# CNN validation R2: -0.3259419404293433
#
# Training Loss 0.8509271144866943, Trainging R-squared -0.093792910591044
#
# CNN validation R2: -0.3182188549016385
#
# Training Loss 0.8525032699108124, Trainging R-squared -0.0732470451631492
#
# CNN validation R2: -0.3063914254398584
#
# Training Loss 0.8560682237148285, Trainging R-squared -0.016455070541703837
#
# CNN validation R2: -0.2975557289094367
#
# Training Loss 0.8511370420455933, Trainging R-squared -0.10645857385573862
#
# CNN validation R2: -0.2942116845067454
#
# Training Loss 0.856989324092865, Trainging R-squared -0.11572959059821009
#
# CNN validation R2: -0.2876322528744485
#
# Training Loss 0.8453765213489532, Trainging R-squared -0.1140506280691814
#
# CNN validation R2: -0.27922256081600016
#
# Training Loss 0.84519824385643, Trainging R-squared 0.07708029930645038
#
# CNN validation R2: -0.27031541560869454
#
# Training Loss 0.8474423587322235, Trainging R-squared 0.040968723573275745
#
# CNN validation R2: -0.25556891609308274
#
# Training Loss 0.8401978611946106, Trainging R-squared -0.018536175413454897
#
# CNN validation R2: -0.23414121471659632
#
# Training Loss 0.8447845578193665, Trainging R-squared 0.007013524121936621
#
# CNN validation R2: -0.20915090067193354
#
# Training Loss 0.8406628966331482, Trainging R-squared 0.054852691466697634
#
# CNN validation R2: -0.18749296677326138
#
# Training Loss 0.8439264595508575, Trainging R-squared -0.04038503894685544
#
# CNN validation R2: -0.17605191217700433
#
# Training Loss 0.8454341888427734, Trainging R-squared 0.037308850273480854
#
# CNN validation R2: -0.16721805845965293
#
# Training Loss 0.848806232213974, Trainging R-squared 0.031489691902017725
#
# CNN validation R2: -0.1665359925249163
#
# Training Loss 0.8439561724662781, Trainging R-squared 0.03954015946400019
#
# CNN validation R2: -0.15785691147218472
#
# Training Loss 0.8382096588611603, Trainging R-squared 0.057279023024852355
#
# CNN validation R2: -0.1452645735271098
#
# Training Loss 0.8433423936367035, Trainging R-squared 0.07544869146671035
#
# CNN validation R2: -0.1366007436245285
#
# Training Loss 0.8459075093269348, Trainging R-squared -0.2402490613717055
#
# CNN validation R2: -0.11840041374403182
#
# Training Loss 0.8391160070896149, Trainging R-squared 0.19094473472417842
#
# CNN validation R2: -0.09530277454220715
#
# Training Loss 0.8381012082099915, Trainging R-squared 0.15429873955794768
#
# CNN validation R2: -0.07638464828763725
#
# Training Loss 0.8404703140258789, Trainging R-squared 0.12202506112657119
#
# CNN validation R2: -0.06330308785469768
#
# Training Loss 0.832069605588913, Trainging R-squared 0.23692236826579488
#
# CNN validation R2: -0.056849482426390485
#
# Training Loss 0.8426510393619537, Trainging R-squared 0.0790986891870463
#
# CNN validation R2: -0.05783104671610745
#
# Training Loss 0.8341495990753174, Trainging R-squared 0.2057271178748775
#
# CNN validation R2: -0.05573712037080941
#
# Training Loss 0.8428092002868652, Trainging R-squared 0.12971131871957894
#
# CNN validation R2: -0.05406142701455302
#
# Training Loss 0.8399452865123749, Trainging R-squared 0.18834633808193305
#
# CNN validation R2: -0.06321921130934571
#
# Training Loss 0.8396711945533752, Trainging R-squared 0.10423425112409945
#
# CNN validation R2: -0.06851041835588623
#
# Training Loss 0.8391447067260742, Trainging R-squared 0.057762263015179505
#
# CNN validation R2: -0.06121642943533129
#
# Training Loss 0.8356423377990723, Trainging R-squared 0.10815782185370826
#
# CNN validation R2: -0.054944167340711614
#
# Training Loss 0.8444717526435852, Trainging R-squared 0.07909075171446728
#
# CNN validation R2: -0.057114705667870524
#
# Training Loss 0.8392906785011292, Trainging R-squared 0.21651378383989295
#
# CNN validation R2: -0.056153159720579604
#
# Training Loss 0.8459481000900269, Trainging R-squared 0.021572837396655775
#
# CNN validation R2: -0.05050127371074409
#
# Training Loss 0.8370387256145477, Trainging R-squared 0.2093440637306032
#
# CNN validation R2: -0.05538558744494004
#
# Training Loss 0.8469945192337036, Trainging R-squared 0.0687945285338176
#
# CNN validation R2: -0.05941521499593849
#
# Training Loss 0.8385268747806549, Trainging R-squared 0.20015804733029616
#
# CNN validation R2: -0.05730061311827217
#
# Training Loss 0.8449585437774658, Trainging R-squared 0.16200054056212712
#
# CNN validation R2: -0.049205538457049114
#
# Training Loss 0.8364794850349426, Trainging R-squared 0.1906599681395847
#
# CNN validation R2: -0.040115652964625825
#
# Training Loss 0.8375120759010315, Trainging R-squared 0.11346120479608354
#
# CNN validation R2: -0.03394095816876164
#
# Training Loss 0.8369664549827576, Trainging R-squared 0.2211879436062239
#
# CNN validation R2: -0.03226790883708519
#
# Training Loss 0.8342709243297577, Trainging R-squared 0.15917231630866235
#
# CNN validation R2: -0.04301501956014264
#
# Training Loss 0.8358324766159058, Trainging R-squared 0.21428235126890738
#
# CNN validation R2: -0.04624180066001904
#
# Training Loss 0.8281116783618927, Trainging R-squared 0.2956151131787146
#
# CNN validation R2: -0.04578322099747045
#
# Training Loss 0.8399624526500702, Trainging R-squared 0.1547801620027825
#
# CNN validation R2: -0.040106013373812366
#
# Training Loss 0.8356824219226837, Trainging R-squared 0.17882594712883648
#
# CNN validation R2: -0.03722921264055634
#
# Training Loss 0.8390965163707733, Trainging R-squared 0.15171483350673545
#
# CNN validation R2: -0.030022459734250218
#
# Training Loss 0.8338034451007843, Trainging R-squared 0.24274478581841114
#
# CNN validation R2: -0.021462873772576163
#
# Training Loss 0.8367774784564972, Trainging R-squared 0.2433897919694286
#
# CNN validation R2: -0.015428661670104815
#
# Training Loss 0.83707195520401, Trainging R-squared 0.18880231399788774
#
# CNN validation R2: -0.010543002080121044
#
# Training Loss 0.8378308415412903, Trainging R-squared 0.1838914808717302
#
# CNN validation R2: 0.0024468100138632654
#
# Training Loss 0.8310114443302155, Trainging R-squared 0.33093896035660164
#
# CNN validation R2: 0.013219976184722648
#
# Training Loss 0.8376680016517639, Trainging R-squared 0.0889100808134829
#
# CNN validation R2: 0.015934953548512487
#
# Training Loss 0.838439017534256, Trainging R-squared 0.2641753073131901
#
# CNN validation R2: 0.01430350281742554
#
# Training Loss 0.8425890207290649, Trainging R-squared 0.09808171630530038
#
# CNN validation R2: -0.002392586757952453
#
# Training Loss 0.8379212915897369, Trainging R-squared 0.18570212741066117
#
# CNN validation R2: -0.014505234014157375
#
# Training Loss 0.83649542927742, Trainging R-squared 0.17631479281015797
#
# CNN validation R2: -0.014584538967341298
#
# Training Loss 0.8315386772155762, Trainging R-squared 0.2237695373961963
#
# CNN validation R2: -0.018418749438632864
#
# Training Loss 0.8317405879497528, Trainging R-squared 0.3103467906470938
#
# CNN validation R2: -0.02274524232360664
#
# Training Loss 0.8322881162166595, Trainging R-squared 0.28886652324110573
#
# CNN validation R2: -0.015217753350097729
#
# Training Loss 0.8335363864898682, Trainging R-squared 0.332210927888159
#
# CNN validation R2: -0.007360799040994126
#
# Training Loss 0.827123761177063, Trainging R-squared 0.3102151769219522
#
# CNN validation R2: -0.0028895782175665796
#
# Training Loss 0.8367480337619781, Trainging R-squared 0.19571167772732187
#
# CNN validation R2: -0.00027269361098331
#
# Training Loss 0.8323790729045868, Trainging R-squared -0.23320274810778524
#
# CNN validation R2: 0.008479621287065253
#
# Training Loss 0.8343051970005035, Trainging R-squared 0.23825221001505026
#
# CNN validation R2: 0.017913484432739823
#
# Training Loss 0.8305382132530212, Trainging R-squared 0.34298104404162943
#
# CNN validation R2: 0.020461844704179555
#
# Training Loss 0.8337438106536865, Trainging R-squared 0.2619665983521706
#
# CNN validation R2: 0.016506481358046776
#
# Training Loss 0.8352133631706238, Trainging R-squared 0.21709249569541456
#
# CNN validation R2: 0.017333923435691068
#
# Training Loss 0.8312011063098907, Trainging R-squared 0.2833713940371334
#
# CNN validation R2: 0.0218388582495862
#
# Training Loss 0.827521026134491, Trainging R-squared 0.31155787447303407
#
# CNN validation R2: 0.027516994153251595
#
# Training Loss 0.8330931961536407, Trainging R-squared 0.20226308509187674
#
# CNN validation R2: 0.02346794761101839
#
# Training Loss 0.826330840587616, Trainging R-squared 0.34098834621191987
#
# CNN validation R2: 0.021046996716929334
#
# Training Loss 0.828922837972641, Trainging R-squared 0.3020254863180249
#
# CNN validation R2: 0.02406813533104535
#
# Training Loss 0.8288656175136566, Trainging R-squared 0.2315666862836293
#
# CNN validation R2: 0.03131131398209197
#
# Training Loss 0.8305724859237671, Trainging R-squared 0.35553161164080915
#
# CNN validation R2: 0.03569039416911318
#
# Training Loss 0.8263148665428162, Trainging R-squared 0.32807595633430875
#
# CNN validation R2: 0.03950748724425679
#
# Training Loss 0.8270813226699829, Trainging R-squared 0.27327086920715443
#
# CNN validation R2: 0.04785503648877709
#
# Training Loss 0.8346588313579559, Trainging R-squared 0.22999438075633247
#
# CNN validation R2: 0.049941197989024966
#
# Training Loss 0.8224987387657166, Trainging R-squared 0.40794669993404353
#
# CNN validation R2: 0.0471590598621307
#
# Training Loss 0.8285340666770935, Trainging R-squared 0.32315449580121747
#
# CNN validation R2: 0.037811956748772524
#
# Training Loss 0.837397426366806, Trainging R-squared 0.24658564018732027
#
# CNN validation R2: 0.03468432194982418
#
# Training Loss 0.8293710947036743, Trainging R-squared 0.32443882553957937
#
# CNN validation R2: 0.03767354646499793
#
# Training Loss 0.8303159475326538, Trainging R-squared 0.308001703513738
#
# CNN validation R2: 0.02609656691218437
#
# Training Loss 0.8310243189334869, Trainging R-squared 0.34041351675127374
#
# CNN validation R2: 0.027418823024365047
#
# Training Loss 0.8271690607070923, Trainging R-squared 0.3779052476580453
#
# CNN validation R2: 0.034007665659842035
#
# Training Loss 0.8277210891246796, Trainging R-squared 0.3165358216468189
#
# CNN validation R2: 0.03686655365698688
#
# Training Loss 0.8262145817279816, Trainging R-squared 0.3825373231993664
#
# CNN validation R2: 0.04170867692257213
#
# Training Loss 0.8271795213222504, Trainging R-squared 0.42890918302109915
#
# CNN validation R2: 0.04908624412623541
#
# Training Loss 0.834427535533905, Trainging R-squared 0.28571192182078864
#
# CNN validation R2: 0.04040631172974618
#
# Training Loss 0.8238657116889954, Trainging R-squared 0.2953468932848117
#
# CNN validation R2: 0.037842940659015833
#
# Training Loss 0.8247168362140656, Trainging R-squared 0.4065594471392031
#
# CNN validation R2: 0.03036437453989882
#
# Training Loss 0.8226345181465149, Trainging R-squared 0.4086791417669684
#
# CNN validation R2: 0.027010593886586498
#
# Training Loss 0.8396140933036804, Trainging R-squared 0.2450120108774902
#
# CNN validation R2: 0.025966820952274372
#
# Training Loss 0.8293098509311676, Trainging R-squared 0.18711324776612562
#
# CNN validation R2: 0.025519097695876625
#
# Training Loss 0.8255273699760437, Trainging R-squared 0.3778772896469662
#
# CNN validation R2: 0.025539517014351476
#
# Training Loss 0.8270952105522156, Trainging R-squared 0.33808340526982916
#
# CNN validation R2: 0.022663036378756662
#
# Training Loss 0.8239948153495789, Trainging R-squared 0.38818696425259563
#
# CNN validation R2: 0.012382957597484368
#
# Training Loss 0.8323403894901276, Trainging R-squared 0.2931923973868982
#
# CNN validation R2: 0.011275100845645036
#
# Training Loss 0.8250588774681091, Trainging R-squared 0.41916599369570817
#
# CNN validation R2: 0.014984939718013235
#
# Training Loss 0.8226791024208069, Trainging R-squared 0.44674571648962347
#
# CNN validation R2: 0.025409990427557927
#
# Training Loss 0.8241212368011475, Trainging R-squared 0.413069502137131
#
# CNN validation R2: 0.03453283421337677
#
# Training Loss 0.8264914453029633, Trainging R-squared 0.4323011384922886
#
# CNN validation R2: 0.04120005302995827
#
# Training Loss 0.8219690322875977, Trainging R-squared 0.4791885922130972
#
# CNN validation R2: 0.04289550749601312
#
# Training Loss 0.8203777372837067, Trainging R-squared 0.5055134776001919
#
# CNN validation R2: 0.042525622805811736
#
# Training Loss 0.8256943821907043, Trainging R-squared 0.2853371208534169
#
# CNN validation R2: 0.036216708298994926
#
# Training Loss 0.8217452466487885, Trainging R-squared 0.48497137080040764
#
# CNN validation R2: 0.03625723708652634
#
# Training Loss 0.8245716392993927, Trainging R-squared 0.31134165730793717
#
# CNN validation R2: 0.03517594261237428
#
# Training Loss 0.8259474039077759, Trainging R-squared 0.24915615776609515
#
# CNN validation R2: 0.033486154019443326
#
# Training Loss 0.8254925310611725, Trainging R-squared 0.41351926832440167
#
# CNN validation R2: 0.038334143233743345
#
# Training Loss 0.8207480013370514, Trainging R-squared 0.4133542406459689
#
# CNN validation R2: 0.052453650811368824
#
# Training Loss 0.8256198167800903, Trainging R-squared 0.3981230382080708
#
# CNN validation R2: 0.049529915906893096
#
# Training Loss 0.8255033195018768, Trainging R-squared 0.3501415070526097
#
# CNN validation R2: 0.03758534195999358
#
# Training Loss 0.8250384032726288, Trainging R-squared 0.35343452302966644
#
# CNN validation R2: 0.04012245091467104
#
# Training Loss 0.8237111568450928, Trainging R-squared 0.45055908203298983
#
# CNN validation R2: 0.04271208360461398
#
# Training Loss 0.8180198669433594, Trainging R-squared 0.47872043519894214
#
# CNN validation R2: 0.04627545513035419
#
# Training Loss 0.8189248144626617, Trainging R-squared 0.4436330456906313
#
# CNN validation R2: 0.04269586192420083
#
# Training Loss 0.8198366463184357, Trainging R-squared 0.4542829334456653
#
# CNN validation R2: 0.03959173901322505
#
# Training Loss 0.8204502463340759, Trainging R-squared 0.5059669713778325
#
# CNN validation R2: 0.0457992901678389
#
# Training Loss 0.8245986998081207, Trainging R-squared 0.3637948056269664
#
# CNN validation R2: 0.0513966277137049
#
# Training Loss 0.8186651766300201, Trainging R-squared 0.5296195390845095
#
# CNN validation R2: 0.057096003438998066
#
# Training Loss 0.828013002872467, Trainging R-squared 0.333731263303754
#
# CNN validation R2: 0.05436019444132678
#
# Training Loss 0.8217152953147888, Trainging R-squared 0.42810526944222255
#
# CNN validation R2: 0.05499384549515279
#
# Training Loss 0.8226472437381744, Trainging R-squared 0.4000995339987231
#
# CNN validation R2: 0.05964955690566126
#
# Training Loss 0.8225136995315552, Trainging R-squared 0.48912391562700674
#
# CNN validation R2: 0.06194262843792425
#
# Training Loss 0.8222008347511292, Trainging R-squared 0.5006548090951332
#
# CNN validation R2: 0.06475654769657307
#
# Training Loss 0.8257405757904053, Trainging R-squared 0.4605161839341176
#
# CNN validation R2: 0.06829131090493651
#
# Training Loss 0.8249591290950775, Trainging R-squared 0.4285174533550028
#
# CNN validation R2: 0.0581193596910522
#
# Training Loss 0.8191511929035187, Trainging R-squared 0.5160231246438167
#
# CNN validation R2: 0.04763154827938615
#
# Training Loss 0.8172893524169922, Trainging R-squared 0.5515525466750406
#
# CNN validation R2: 0.04325995900054469
#
# Training Loss 0.8220560848712921, Trainging R-squared 0.46843558107596506
#
# CNN validation R2: 0.039001836217807395
#
# Training Loss 0.8196659088134766, Trainging R-squared 0.5031074457086864
#
# CNN validation R2: 0.03332301929168513
#
# Training Loss 0.8188685774803162, Trainging R-squared 0.5315996243124448
#
# CNN validation R2: 0.02411046993107424
#
# Training Loss 0.8183508217334747, Trainging R-squared 0.4246130693056015
#
# CNN validation R2: 0.02188231167149912
#
# Training Loss 0.8180649280548096, Trainging R-squared 0.4498034591168829
#
# CNN validation R2: 0.020727056552339973
#
# Training Loss 0.8206329643726349, Trainging R-squared 0.4696406676774376
#
# CNN validation R2: 0.017710918997834002
#
# Training Loss 0.8198769390583038, Trainging R-squared 0.4726619185467791
#
# CNN validation R2: 0.017454847230994497
#
# Training Loss 0.8155252039432526, Trainging R-squared 0.5804581047514187
#
# CNN validation R2: 0.023804637263712736
#
# Training Loss 0.8172287046909332, Trainging R-squared 0.4831473983830869
#
# CNN validation R2: 0.028922265281219606
#
# Training Loss 0.8174631297588348, Trainging R-squared 0.5410932343903696
#
# CNN validation R2: 0.030895189503272413
#
# Training Loss 0.8185102343559265, Trainging R-squared 0.5490934890402683
#
# CNN validation R2: 0.031043033146398447
#
# Training Loss 0.8200227320194244, Trainging R-squared 0.4764994717562252
#
# CNN validation R2: 0.03192447839818613
#
# Training Loss 0.8231595754623413, Trainging R-squared 0.4160124238945165
#
# CNN validation R2: 0.032569816748400815
#
# Training Loss 0.8254480957984924, Trainging R-squared 0.4625549737629724
#
# CNN validation R2: 0.03009724481664483
#
# Training Loss 0.8279604315757751, Trainging R-squared 0.41088251211277216
#
# CNN validation R2: 0.03448229407853781
#
# Training Loss 0.8194324672222137, Trainging R-squared 0.5355928005427233
#
# CNN validation R2: 0.0374376569876419
#
# Training Loss 0.8207378685474396, Trainging R-squared 0.49914882522035076
#
# CNN validation R2: 0.04194454452280938
#
# Training Loss 0.8195548057556152, Trainging R-squared 0.46941948136352496
#
# CNN validation R2: 0.04070652132020641
#
# Training Loss 0.8152531981468201, Trainging R-squared 0.5527192004936891
#
# CNN validation R2: 0.041019825122500575
#
# Training Loss 0.8157433271408081, Trainging R-squared 0.45709720681099075
#
# CNN validation R2: 0.03741318548528427
#
# Training Loss 0.8191948235034943, Trainging R-squared 0.5110730538574664
#
# CNN validation R2: 0.0337989674317557
#
# Training Loss 0.8185842037200928, Trainging R-squared 0.41265207119036723
#
# CNN validation R2: 0.03152650864214862
#
# Training Loss 0.81873619556427, Trainging R-squared 0.4721887280795409
#
# CNN validation R2: 0.03527814863769335
#
# Training Loss 0.8150045871734619, Trainging R-squared 0.5527119449792273
#
# CNN validation R2: 0.03680507235603109
#
# Training Loss 0.8174078464508057, Trainging R-squared 0.5617348593836691
#
# CNN validation R2: 0.037917954960107025
#
# Training Loss 0.8202930390834808, Trainging R-squared 0.4096461418021055
#
# CNN validation R2: 0.03986184637982798
#
# Training Loss 0.8168034851551056, Trainging R-squared 0.5346818470594643
#
# CNN validation R2: 0.04084271497945968
#
# Training Loss 0.8181519508361816, Trainging R-squared 0.4898720986245215
#
# CNN validation R2: 0.0416391371880806
#
# Training Loss 0.8195756375789642, Trainging R-squared 0.4876850100798138
#
# CNN validation R2: 0.04215490135496319
#
# Training Loss 0.8222205936908722, Trainging R-squared 0.5102103864564845
#
# CNN validation R2: 0.04257511215787535
#
# Training Loss 0.8172304332256317, Trainging R-squared 0.5706667488729185
#
# CNN validation R2: 0.040225651908261106
#
# Training Loss 0.8201451599597931, Trainging R-squared 0.4189261399221809
#
# CNN validation R2: 0.04214630029607935
#
# Training Loss 0.8157476186752319, Trainging R-squared 0.5586973368131333
#
# CNN validation R2: 0.04726563251228094
#
# Training Loss 0.8195342421531677, Trainging R-squared 0.5180810172481616
#
# CNN validation R2: 0.055156162701166744
#
# Training Loss 0.8161278069019318, Trainging R-squared 0.5369043577161631
#
# CNN validation R2: 0.05668735204001113
#
# Training Loss 0.8134917616844177, Trainging R-squared 0.5887294597617565
#
# CNN validation R2: 0.05896062105999056
#
# Training Loss 0.8122177124023438, Trainging R-squared 0.558598658967085
#
# CNN validation R2: 0.06531056186590983
#
# Training Loss 0.8185668587684631, Trainging R-squared 0.5126129375951358
#
# CNN validation R2: 0.06609625799712854
#
# Training Loss 0.8141122758388519, Trainging R-squared 0.5876115425616055
#
# CNN validation R2: 0.06254342826121756
#
# Training Loss 0.8183394074440002, Trainging R-squared 0.488065237487197
#
# CNN validation R2: 0.061433267957084925
#
# Training Loss 0.8158147931098938, Trainging R-squared 0.5201932986866864
#
# CNN validation R2: 0.06267201114415066
#
# Training Loss 0.8171966075897217, Trainging R-squared 0.5429621601388388
#
# CNN validation R2: 0.05743407209338269
#
# Training Loss 0.8145704567432404, Trainging R-squared 0.5341656907993976
#
# CNN validation R2: 0.05156129985136665
#
# Training Loss 0.816308319568634, Trainging R-squared 0.5644708877866196
#
# CNN validation R2: 0.054790128344953615
#
# Training Loss 0.8159073889255524, Trainging R-squared 0.5411167334849444
#
# CNN validation R2: 0.05726931794970286
#
# Training Loss 0.8154861629009247, Trainging R-squared 0.525524232449699
#
# CNN validation R2: 0.05128025006681536
#
# Training Loss 0.8143987655639648, Trainging R-squared 0.5701873252930028
#
# CNN validation R2: 0.049004050298509405
#
# Training Loss 0.8191632032394409, Trainging R-squared 0.4451507256626681
#
# CNN validation R2: 0.0531178434276286
#
# Training Loss 0.8138114213943481, Trainging R-squared 0.557259363765862
#
# CNN validation R2: 0.05404564046970878
#
# Training Loss 0.8176670074462891, Trainging R-squared 0.46964396448794815
#
# CNN validation R2: 0.05367288829918154
#
# Training Loss 0.8173178732395172, Trainging R-squared 0.5541135961335564
#
# CNN validation R2: 0.05514350665165463
#
# Training Loss 0.816423237323761, Trainging R-squared 0.561748571605341
#
# CNN validation R2: 0.06728991354619579
#
# Training Loss 0.8147014677524567, Trainging R-squared 0.6042868614439474
#
# CNN validation R2: 0.07535464164365924
#
# Training Loss 0.8130957782268524, Trainging R-squared 0.5347525575695333
#
# CNN validation R2: 0.07518105068135905
#
# Training Loss 0.813902884721756, Trainging R-squared 0.4846446250138253
#
# CNN validation R2: 0.07063361997943607
#
# Training Loss 0.8143362700939178, Trainging R-squared 0.5211860054304851
#
# CNN validation R2: 0.06984344141012172
#
# Training Loss 0.8149492740631104, Trainging R-squared 0.5682189338160255
#
# CNN validation R2: 0.07278304350366288
#
# Training Loss 0.813661515712738, Trainging R-squared 0.47523886918509417
#
# CNN validation R2: 0.07210554162954153
#
# Training Loss 0.8109155297279358, Trainging R-squared 0.6470251320006878
#
# CNN validation R2: 0.06706136392092027
#
# Fold 2
# Training Loss 0.8780588805675507, Trainging R-squared -0.5510563988489977
#
# CNN validation R2: -0.928836877171483
#
# Training Loss 0.8817951381206512, Trainging R-squared -0.5435053167082664
#
# CNN validation R2: -0.8914973276449719
#
# Training Loss 0.8688366711139679, Trainging R-squared -0.3370945326670029
#
# CNN validation R2: -0.8567717088507207
#
# Training Loss 0.8767748773097992, Trainging R-squared -0.4105557903817854
#
# CNN validation R2: -0.8222161796641545
#
# Training Loss 0.8644523024559021, Trainging R-squared -0.24784422855910218
#
# CNN validation R2: -0.7888593759988618
#
# Training Loss 0.8621813058853149, Trainging R-squared -0.24722213277376043
#
# CNN validation R2: -0.7601704786671684
#
# Training Loss 0.8594019711017609, Trainging R-squared -0.2968793615835268
#
# CNN validation R2: -0.7372416605110008
#
# Training Loss 0.8611749112606049, Trainging R-squared -0.29028761527039915
#
# CNN validation R2: -0.7179969747907314
#
# Training Loss 0.8557439744472504, Trainging R-squared -0.09644703254367193
#
# CNN validation R2: -0.7044320691791365
#
# Training Loss 0.8463335335254669, Trainging R-squared -0.0877285922101721
#
# CNN validation R2: -0.6979588823915642
#
# Training Loss 0.8603872358798981, Trainging R-squared -0.08280314071017703
#
# CNN validation R2: -0.6952884820421844
#
# Training Loss 0.8592688143253326, Trainging R-squared -0.12102888414812168
#
# CNN validation R2: -0.6909470193840174
#
# Training Loss 0.8626116514205933, Trainging R-squared -0.19027656334897286
#
# CNN validation R2: -0.6843460138805615
#
# Training Loss 0.8498764038085938, Trainging R-squared -0.15567265205739841
#
# CNN validation R2: -0.6711957797342167
#
# Training Loss 0.8535794913768768, Trainging R-squared -0.060139121540261714
#
# CNN validation R2: -0.6603341716611044
#
# Training Loss 0.8536235094070435, Trainging R-squared -0.09621263920940776
#
# CNN validation R2: -0.6506363044506381
#
# Training Loss 0.8418274223804474, Trainging R-squared 0.1559321741169331
#
# CNN validation R2: -0.6386212694539729
#
# Training Loss 0.8456401824951172, Trainging R-squared -0.23075565595124667
#
# CNN validation R2: -0.628102075529798
#
# Training Loss 0.853128969669342, Trainging R-squared 0.01604947690647779
#
# CNN validation R2: -0.6098452294932362
#
# Training Loss 0.8494373559951782, Trainging R-squared -0.13840966257411752
#
# CNN validation R2: -0.594119751579776
#
# Training Loss 0.8537021279335022, Trainging R-squared 0.007543462333295892
#
# CNN validation R2: -0.5734986316071554
#
# Training Loss 0.8533298075199127, Trainging R-squared -0.037217193634359075
#
# CNN validation R2: -0.55279295710469
#
# Training Loss 0.8467877805233002, Trainging R-squared 0.07729719377192806
#
# CNN validation R2: -0.5372448503964515
#
# Training Loss 0.8531499803066254, Trainging R-squared 0.04859855001349994
#
# CNN validation R2: -0.5247435265323788
#
# Training Loss 0.8493252694606781, Trainging R-squared -0.009985111077720654
#
# CNN validation R2: -0.5195287894185012
#
# Training Loss 0.8473381400108337, Trainging R-squared 0.0704261347119452
#
# CNN validation R2: -0.5055029677008674
#
# Training Loss 0.8504201769828796, Trainging R-squared 0.04218462939169407
#
# CNN validation R2: -0.48794330312584544
#
# Training Loss 0.8473307490348816, Trainging R-squared -0.010846479394158254
#
# CNN validation R2: -0.47651992844525637
#
# Training Loss 0.8402398228645325, Trainging R-squared 0.10908361822269641
#
# CNN validation R2: -0.4519351364093881
#
# Training Loss 0.8456790447235107, Trainging R-squared 0.11983732155804874
#
# CNN validation R2: -0.4264813551227796
#
# Training Loss 0.8491059839725494, Trainging R-squared -0.04124639165084876
#
# CNN validation R2: -0.4033393168930973
#
# Training Loss 0.84268519282341, Trainging R-squared 0.13405783710858823
#
# CNN validation R2: -0.38141399463822434
#
# Training Loss 0.8463427722454071, Trainging R-squared 0.0697914431153642
#
# CNN validation R2: -0.34931968892375287
#
# Training Loss 0.8525102436542511, Trainging R-squared -0.038840079101027075
#
# CNN validation R2: -0.32042060140086626
#
# Training Loss 0.8439706265926361, Trainging R-squared 0.17349596880139018
#
# CNN validation R2: -0.2955958704126027
#
# Training Loss 0.843300849199295, Trainging R-squared 0.14755521568930827
#
# CNN validation R2: -0.27439868888146357
#
# Training Loss 0.8494181931018829, Trainging R-squared 0.02365966686215143
#
# CNN validation R2: -0.27363778549427087
#
# Training Loss 0.8464883863925934, Trainging R-squared 0.16138045081445826
#
# CNN validation R2: -0.25867289358228784
#
# Training Loss 0.8351915180683136, Trainging R-squared 0.20973830486082273
#
# CNN validation R2: -0.21279240660886584
#
# Training Loss 0.8408722281455994, Trainging R-squared 0.18736303333428533
#
# CNN validation R2: -0.16687605832078334
#
# Training Loss 0.8485540151596069, Trainging R-squared 0.07640858265792355
#
# CNN validation R2: -0.1351235481223652
#
# Training Loss 0.8389396369457245, Trainging R-squared 0.22183270520048093
#
# CNN validation R2: -0.08944542513419884
#
# Training Loss 0.8390887379646301, Trainging R-squared 0.14836532327324073
#
# CNN validation R2: -0.061449648945690605
#
# Training Loss 0.8410697877407074, Trainging R-squared 0.16019349111680045
#
# CNN validation R2: -0.0497344754912018
#
# Training Loss 0.8427908718585968, Trainging R-squared 0.19166756452785774
#
# CNN validation R2: -0.05042892454339698
#
# Training Loss 0.8427716791629791, Trainging R-squared 0.1752542060921394
#
# CNN validation R2: -0.04664238778350721
#
# Training Loss 0.8412448763847351, Trainging R-squared 0.15982592955384103
#
# CNN validation R2: -0.05397910689138902
#
# Training Loss 0.8417487740516663, Trainging R-squared 0.14880901562174764
#
# CNN validation R2: -0.07257620605688919
#
# Training Loss 0.8392535746097565, Trainging R-squared 0.1850330730569109
#
# CNN validation R2: -0.11348992327440732
#
# Training Loss 0.8373941779136658, Trainging R-squared 0.25839938704713505
#
# CNN validation R2: -0.1324860243144631
#
# Training Loss 0.8341927528381348, Trainging R-squared 0.24130937771604777
#
# CNN validation R2: -0.14912525321857406
#
# Training Loss 0.8453618884086609, Trainging R-squared 0.22812692528843592
#
# CNN validation R2: -0.17425541669236422
#
# Training Loss 0.8399830758571625, Trainging R-squared 0.14276987128638674
#
# CNN validation R2: -0.20211062550567754
#
# Training Loss 0.8477785885334015, Trainging R-squared 0.03848349382388905
#
# CNN validation R2: -0.22580512073021686
#
# Training Loss 0.8445224165916443, Trainging R-squared 0.03435734399272464
#
# CNN validation R2: -0.23809123311440983
#
# Training Loss 0.8354840576648712, Trainging R-squared 0.21889936364213358
#
# CNN validation R2: -0.2571711352658903
#
# Training Loss 0.8348678946495056, Trainging R-squared 0.28209647303335084
#
# CNN validation R2: -0.25731619001857464
#
# Training Loss 0.8408383131027222, Trainging R-squared 0.2307316260663454
#
# CNN validation R2: -0.24481450956401196
#
# Training Loss 0.8394811153411865, Trainging R-squared 0.17482728689528623
#
# CNN validation R2: -0.24726103522470266
#
# Training Loss 0.8440653383731842, Trainging R-squared 0.17235227038050943
#
# CNN validation R2: -0.24900073642446197
#
# Training Loss 0.8367003500461578, Trainging R-squared 0.22027525215699792
#
# CNN validation R2: -0.2303140132297694
#
# Training Loss 0.838411957025528, Trainging R-squared 0.207160050261038
#
# CNN validation R2: -0.21438829727481856
#
# Training Loss 0.8417243957519531, Trainging R-squared 0.12753816950085423
#
# CNN validation R2: -0.18392997552194207
#
# Training Loss 0.8355076611042023, Trainging R-squared 0.21822805492873631
#
# CNN validation R2: -0.13830380618322774
#
# Training Loss 0.837011843919754, Trainging R-squared 0.1878709506787784
#
# CNN validation R2: -0.0925983786829982
#
# Training Loss 0.8295868635177612, Trainging R-squared 0.31777089612476817
#
# CNN validation R2: -0.05866505624316265
#
# Training Loss 0.8402656614780426, Trainging R-squared 0.1930881283595706
#
# CNN validation R2: -0.03709348849494443
#
# Training Loss 0.8332877457141876, Trainging R-squared 0.22510394484375187
#
# CNN validation R2: -0.012631968550859296
#
# Training Loss 0.8409169614315033, Trainging R-squared 0.29930158452203526
#
# CNN validation R2: -0.008509069244793555
#
# Training Loss 0.8298696875572205, Trainging R-squared 0.29791422041933513
#
# CNN validation R2: -0.018983777685960768
#
# Training Loss 0.8367973864078522, Trainging R-squared 0.24606214197071358
#
# CNN validation R2: -0.04600499834782018
#
# Training Loss 0.8359625041484833, Trainging R-squared 0.2358177810841978
#
# CNN validation R2: -0.06932475792535842
#
# Training Loss 0.8330557346343994, Trainging R-squared 0.19901149700664406
#
# CNN validation R2: -0.1204339498968785
#
# Training Loss 0.8346342742443085, Trainging R-squared 0.3662617827436335
#
# CNN validation R2: -0.14375042039079972
#
# Training Loss 0.8384067416191101, Trainging R-squared 0.23023010408329875
#
# CNN validation R2: -0.13741964729250883
#
# Training Loss 0.8375915586948395, Trainging R-squared 0.12784521900316898
#
# CNN validation R2: -0.1209441661233917
#
# Training Loss 0.837898463010788, Trainging R-squared 0.25661337112665755
#
# CNN validation R2: -0.12064807330215921
#
# Training Loss 0.8360042572021484, Trainging R-squared 0.33381334069643986
#
# CNN validation R2: -0.1103338582761983
#
# Training Loss 0.8319642543792725, Trainging R-squared 0.344605132927325
#
# CNN validation R2: -0.10941559307428916
#
# Training Loss 0.8263697624206543, Trainging R-squared 0.38131482234255143
#
# CNN validation R2: -0.12210962232587447
#
# Training Loss 0.8358916640281677, Trainging R-squared 0.23204560098820318
#
# CNN validation R2: -0.13381701260527845
#
# Training Loss 0.8353223502635956, Trainging R-squared 0.276482005161817
#
# CNN validation R2: -0.15097722527723562
#
# Training Loss 0.8400207757949829, Trainging R-squared 0.1925934098096321
#
# CNN validation R2: -0.1841163376821245
#
# Training Loss 0.8367764949798584, Trainging R-squared 0.25182147659937937
#
# CNN validation R2: -0.19141695423538563
#
# Training Loss 0.8312727808952332, Trainging R-squared 0.30738396303236437
#
# CNN validation R2: -0.17853262390206665
#
# Training Loss 0.8371730744838715, Trainging R-squared 0.3393461994008786
#
# CNN validation R2: -0.16398197211794674
#
# Training Loss 0.8372097909450531, Trainging R-squared 0.23501666971558072
#
# CNN validation R2: -0.14372968539951292
#
# Training Loss 0.8260664641857147, Trainging R-squared 0.41106950237740875
#
# CNN validation R2: -0.14441513482382834
#
# Training Loss 0.8322992622852325, Trainging R-squared 0.27709451535047436
#
# CNN validation R2: -0.1328832852446108
#
# Training Loss 0.8350638747215271, Trainging R-squared 0.38762342861057564
#
# CNN validation R2: -0.09153384260794062
#
# Training Loss 0.8291966319084167, Trainging R-squared 0.4128811316212381
#
# CNN validation R2: -0.06809904728369492
#
# Training Loss 0.8333146274089813, Trainging R-squared 0.29159037418759365
#
# CNN validation R2: -0.05319264787987754
#
# Training Loss 0.8278359770774841, Trainging R-squared 0.33790183455826933
#
# CNN validation R2: -0.05220335083155914
#
# Training Loss 0.8320567011833191, Trainging R-squared 0.28067701254274463
#
# CNN validation R2: -0.051714011219116174
#
# Training Loss 0.8336000442504883, Trainging R-squared 0.31227913380144195
#
# CNN validation R2: -0.03876445303022508
#
# Training Loss 0.8352746963500977, Trainging R-squared 0.2356722166788737
#
# CNN validation R2: -0.029734459929665613
#
# Training Loss 0.83158078789711, Trainging R-squared 0.3556424082537681
#
# CNN validation R2: -0.023320443495572718
#
# Training Loss 0.8371832966804504, Trainging R-squared 0.2726685281510155
#
# CNN validation R2: -0.03795872905930103
#
# Training Loss 0.8276814520359039, Trainging R-squared 0.3757524099251574
#
# CNN validation R2: -0.06120345147763534
#
# Training Loss 0.8318203985691071, Trainging R-squared 0.22866900454470082
#
# CNN validation R2: -0.07583943598038212
#
# Training Loss 0.8338035643100739, Trainging R-squared 0.19511829067181863
#
# CNN validation R2: -0.08160289105381607
#
# Training Loss 0.8317787647247314, Trainging R-squared 0.3374818166236796
#
# CNN validation R2: -0.060334959456064985
#
# Training Loss 0.8284638226032257, Trainging R-squared 0.4014776348020893
#
# CNN validation R2: -0.056651552489250356
#
# Training Loss 0.8251568973064423, Trainging R-squared 0.3903298073975977
#
# CNN validation R2: -0.05347240418262811
#
# Training Loss 0.8282181024551392, Trainging R-squared 0.3643898153782351
#
# CNN validation R2: -0.05217633467204741
#
# Training Loss 0.829097330570221, Trainging R-squared 0.34649877902147375
#
# CNN validation R2: -0.056049552217941945
#
# Training Loss 0.8258764743804932, Trainging R-squared 0.388009568877142
#
# CNN validation R2: -0.08217676692685644
#
# Training Loss 0.8310909569263458, Trainging R-squared 0.3547820999862239
#
# CNN validation R2: -0.09313986487274828
#
# Training Loss 0.8369714617729187, Trainging R-squared 0.30810428197399653
#
# CNN validation R2: -0.12709974990624628
#
# Training Loss 0.8352980017662048, Trainging R-squared 0.2448214253130204
#
# CNN validation R2: -0.16888460880724498
#
# Training Loss 0.8239294588565826, Trainging R-squared 0.483663236384849
#
# CNN validation R2: -0.17527675167291845
#
# Training Loss 0.826663076877594, Trainging R-squared 0.36027530259978036
#
# CNN validation R2: -0.15435221120946307
#
# Training Loss 0.8277620375156403, Trainging R-squared 0.4301164156125177
#
# CNN validation R2: -0.11212174500199901
#
# Training Loss 0.8304428458213806, Trainging R-squared 0.35574982917711107
#
# CNN validation R2: -0.07013220554115218
#
# Training Loss 0.8227891027927399, Trainging R-squared 0.44309415301406563
#
# CNN validation R2: -0.07015995002090025
#
# Training Loss 0.833896815776825, Trainging R-squared 0.32055299373795787
#
# CNN validation R2: -0.06594209792128969
#
# Training Loss 0.8306804597377777, Trainging R-squared 0.36317589436466924
#
# CNN validation R2: -0.06836046325585576
#
# Training Loss 0.826341062784195, Trainging R-squared 0.36705779382459525
#
# CNN validation R2: -0.07273959590264084
#
# Training Loss 0.8310378193855286, Trainging R-squared 0.3301943796054102
#
# CNN validation R2: -0.06706432433883674
#
# Training Loss 0.8268155753612518, Trainging R-squared 0.39927931509483405
#
# CNN validation R2: -0.06292287866537011
#
# Training Loss 0.825544536113739, Trainging R-squared 0.4284566009196175
#
# CNN validation R2: -0.0757144667450847
#
# Training Loss 0.8294224739074707, Trainging R-squared 0.20332284938915615
#
# CNN validation R2: -0.08244931182836457
#
# Training Loss 0.827505350112915, Trainging R-squared 0.39905841317267465
#
# CNN validation R2: -0.09384949653052271
#
# Training Loss 0.8256913423538208, Trainging R-squared 0.3693287171870161
#
# CNN validation R2: -0.11019014584096981
#
# Training Loss 0.8244709968566895, Trainging R-squared 0.4709472514404576
#
# CNN validation R2: -0.13771336176007254
#
# Training Loss 0.8280176222324371, Trainging R-squared 0.4055489079719425
#
# CNN validation R2: -0.12881590194413534
#
# Training Loss 0.8233239948749542, Trainging R-squared 0.47475007765355426
#
# CNN validation R2: -0.10557214417332361
#
# Training Loss 0.8269593119621277, Trainging R-squared 0.40715044856230204
#
# CNN validation R2: -0.07355383126082499
#
# Training Loss 0.8284497261047363, Trainging R-squared 0.3706439713928026
#
# CNN validation R2: -0.044164465313936474
#
# Training Loss 0.8244206011295319, Trainging R-squared 0.40571039807084525
#
# CNN validation R2: -0.032388697428821445
#
# Training Loss 0.8205004632472992, Trainging R-squared 0.4918448685512967
#
# CNN validation R2: -0.02216321627622969
#
# Training Loss 0.8280892670154572, Trainging R-squared 0.3886982803758775
#
# CNN validation R2: -0.03321498648235849
#
# Training Loss 0.8183873295783997, Trainging R-squared 0.4798969025846855
#
# CNN validation R2: -0.059755466421860415
#
# Training Loss 0.8234962224960327, Trainging R-squared 0.300959132971802
#
# CNN validation R2: -0.07832518464845895
#
# Training Loss 0.8315899670124054, Trainging R-squared 0.3600463918510122
#
# CNN validation R2: -0.08101697332252006
#
# Training Loss 0.8251977562904358, Trainging R-squared 0.47172706272027476
#
# CNN validation R2: -0.07474667313963318
#
# Training Loss 0.824838399887085, Trainging R-squared 0.467393507802926
#
# CNN validation R2: -0.07901203950693292
#
# Training Loss 0.8188591599464417, Trainging R-squared 0.5494117540019322
#
# CNN validation R2: -0.09337765416872468
#
# Training Loss 0.826476663351059, Trainging R-squared 0.4081619307346868
#
# CNN validation R2: -0.08470172208445559
#
# Training Loss 0.8276630938053131, Trainging R-squared 0.4041958544878673
#
# CNN validation R2: -0.07837328013454625
#
# Training Loss 0.8228500485420227, Trainging R-squared 0.4010414060605926
#
# CNN validation R2: -0.062067576971336635
#
# Training Loss 0.8181228637695312, Trainging R-squared 0.5689306085935452
#
# CNN validation R2: -0.055978385379781004
#
# Training Loss 0.8264314830303192, Trainging R-squared 0.43341925262236014
#
# CNN validation R2: -0.06305916121291916
#
# Training Loss 0.8299961090087891, Trainging R-squared 0.31128910679778304
#
# CNN validation R2: -0.0705559928507824
#
# Training Loss 0.8180663287639618, Trainging R-squared 0.5624893660930282
#
# CNN validation R2: -0.07464508901500122
#
# Training Loss 0.8224280178546906, Trainging R-squared 0.5131149780102796
#
# CNN validation R2: -0.07455115269075901
#
# Training Loss 0.8211378157138824, Trainging R-squared 0.46972281045172404
#
# CNN validation R2: -0.08499249262616226
#
# Training Loss 0.8208513855934143, Trainging R-squared 0.5057150298440302
#
# CNN validation R2: -0.08170998732504575
#
# Training Loss 0.8216089308261871, Trainging R-squared 0.45055672027937105
#
# CNN validation R2: -0.04722549883655802
#
# Training Loss 0.8207216262817383, Trainging R-squared 0.5246809314306352
#
# CNN validation R2: -0.03727543051711829
#
# Training Loss 0.822195291519165, Trainging R-squared 0.49152143179672997
#
# CNN validation R2: -0.04627379847376911
#
# Training Loss 0.8210751414299011, Trainging R-squared 0.4345792576331494
#
# CNN validation R2: -0.060576883813551974
#
# Training Loss 0.8276710510253906, Trainging R-squared 0.42464720750852236
#
# CNN validation R2: -0.0938557424124648
#
# Training Loss 0.8182715177536011, Trainging R-squared 0.5367950253834073
#
# CNN validation R2: -0.10984284243259507
#
# Training Loss 0.8276821672916412, Trainging R-squared 0.38106757127081003
#
# CNN validation R2: -0.11196207189739216
#
# Training Loss 0.821508139371872, Trainging R-squared 0.39088773049094694
#
# CNN validation R2: -0.12058735445716029
#
# Training Loss 0.8201525807380676, Trainging R-squared 0.5281396222579751
#
# CNN validation R2: -0.14416097665253796
#
# Training Loss 0.8262634575366974, Trainging R-squared 0.4266554070189756
#
# CNN validation R2: -0.14507553674628287
#
# Training Loss 0.821376770734787, Trainging R-squared 0.3231002466376385
#
# CNN validation R2: -0.11478852890204683
#
# Training Loss 0.8225192129611969, Trainging R-squared 0.42597907564908283
#
# CNN validation R2: -0.09190143649059773
#
# Training Loss 0.827953040599823, Trainging R-squared 0.36777335871116884
#
# CNN validation R2: -0.024956180666381444
#
# Training Loss 0.8211815059185028, Trainging R-squared 0.5100335449072515
#
# CNN validation R2: 0.020615934669527103
#
# Training Loss 0.8231302201747894, Trainging R-squared 0.5182843687710186
#
# CNN validation R2: 0.040198757753324266
#
# Training Loss 0.8193339109420776, Trainging R-squared 0.4873950255730908
#
# CNN validation R2: 0.040593251283613796
#
# Training Loss 0.8220860958099365, Trainging R-squared 0.4790777738583366
#
# CNN validation R2: 0.024256424338059857
#
# Training Loss 0.8186187446117401, Trainging R-squared 0.5078130448720145
#
# CNN validation R2: 0.013050839429534777
#
# Training Loss 0.8239554166793823, Trainging R-squared 0.4589867620952685
#
# CNN validation R2: 0.008734147201285791
#
# Training Loss 0.8208107352256775, Trainging R-squared 0.48098546261679015
#
# CNN validation R2: -0.010038167750455962
#
# Training Loss 0.8213256001472473, Trainging R-squared 0.517207585165484
#
# CNN validation R2: -0.01863674359934464
#
# Training Loss 0.8263886868953705, Trainging R-squared 0.44245157496066234
#
# CNN validation R2: -0.024611928286638163
#
# Training Loss 0.8203628659248352, Trainging R-squared 0.5718797814114472
#
# CNN validation R2: -0.021923357664677845
#
# Training Loss 0.8196930885314941, Trainging R-squared 0.5073302929254742
#
# CNN validation R2: -0.02422144028926243
#
# Training Loss 0.8197541832923889, Trainging R-squared 0.555579651309982
#
# CNN validation R2: -0.03261262463228315
#
# Training Loss 0.8141096532344818, Trainging R-squared 0.614649760822924
#
# CNN validation R2: -0.0390204711447697
#
# Training Loss 0.8225020468235016, Trainging R-squared 0.4365368695961156
#
# CNN validation R2: -0.041702426855300956
#
# Training Loss 0.8236914575099945, Trainging R-squared 0.4794836250809732
#
# CNN validation R2: -0.05267983075988064
#
# Training Loss 0.814652144908905, Trainging R-squared 0.6178715814594251
#
# CNN validation R2: -0.07522464470558143
#
# Training Loss 0.8215280175209045, Trainging R-squared 0.5351008480930417
#
# CNN validation R2: -0.08595625925244599
#
# Training Loss 0.8202619552612305, Trainging R-squared 0.5211006413826083
#
# CNN validation R2: -0.07926523351436365
#
# Training Loss 0.8165043592453003, Trainging R-squared 0.5764442835672356
#
# CNN validation R2: -0.0739283827139916
#
# Training Loss 0.8152242004871368, Trainging R-squared 0.5910312879913913
#
# CNN validation R2: -0.07233198396905083
#
# Training Loss 0.8180351257324219, Trainging R-squared 0.5821831116449954
#
# CNN validation R2: -0.07120330281201398
#
# Training Loss 0.8155542314052582, Trainging R-squared 0.4059841362500923
#
# CNN validation R2: -0.07491452210301941
#
# Training Loss 0.8197812139987946, Trainging R-squared 0.5010304719231675
#
# CNN validation R2: -0.08594504870669051
#
# Training Loss 0.8192683160305023, Trainging R-squared 0.5390351112587018
#
# CNN validation R2: -0.08265615210457256
#
# Training Loss 0.81625035405159, Trainging R-squared 0.5727128539118214
#
# CNN validation R2: -0.08899870284433459
#
# Training Loss 0.8177965581417084, Trainging R-squared 0.4889123265411519
#
# CNN validation R2: -0.08725408342503621
#
# Training Loss 0.8211586475372314, Trainging R-squared 0.4475092036596363
#
# CNN validation R2: -0.08315967188253354
#
# Training Loss 0.8223923742771149, Trainging R-squared 0.4769399282425768
#
# CNN validation R2: -0.0908718199687219
#
# Training Loss 0.8264245688915253, Trainging R-squared 0.36023910674619686
#
# CNN validation R2: -0.11349969225554357
#
# Training Loss 0.8174514770507812, Trainging R-squared 0.5854369820572773
#
# CNN validation R2: -0.15851299730776586
#
# Training Loss 0.8205811083316803, Trainging R-squared 0.48527894352755835
#
# CNN validation R2: -0.19811377794594726
#
# Training Loss 0.8178830146789551, Trainging R-squared 0.560604889011565
#
# CNN validation R2: -0.2152036077936253
#
# Training Loss 0.8208653628826141, Trainging R-squared 0.5099511748735749
#
# CNN validation R2: -0.21593003966258706
#
# Training Loss 0.8173970878124237, Trainging R-squared 0.4346923826694785
#
# CNN validation R2: -0.1925263931518843
#
# Training Loss 0.8153311610221863, Trainging R-squared 0.6025682491153397
#
# CNN validation R2: -0.13473779933847252
#
# Training Loss 0.8220567107200623, Trainging R-squared 0.5227652033618628
#
# CNN validation R2: -0.0992038165825122
#
# Training Loss 0.8183160722255707, Trainging R-squared 0.5481596480702763
#
# CNN validation R2: -0.06996221162712418
#
# Training Loss 0.816778689622879, Trainging R-squared 0.5517001542765425
#
# CNN validation R2: -0.061658999691579564
#
# Training Loss 0.8156319558620453, Trainging R-squared 0.5813942322974233
#
# CNN validation R2: -0.05722435501534534
#
# Fold 3
# Training Loss 0.8751191198825836, Trainging R-squared -0.4003903273470478
#
# CNN validation R2: -0.13099564894362592
#
# Training Loss 0.8830834627151489, Trainging R-squared -0.5194200381526259
#
# CNN validation R2: -0.11672678495983313
#
# Training Loss 0.8618880808353424, Trainging R-squared -0.18506444631112606
#
# CNN validation R2: -0.10092352082504874
#
# Training Loss 0.8676840960979462, Trainging R-squared -0.32274155591309195
#
# CNN validation R2: -0.08559273997539008
#
# Training Loss 0.8681379556655884, Trainging R-squared -0.24456106198162858
#
# CNN validation R2: -0.07175472490306989
#
# Training Loss 0.8590891063213348, Trainging R-squared -0.1984363209787373
#
# CNN validation R2: -0.058163889925387235
#
# Training Loss 0.8747571408748627, Trainging R-squared -0.4803291477852014
#
# CNN validation R2: -0.04345809847229187
#
# Training Loss 0.8544415533542633, Trainging R-squared -0.0939378597327859
#
# CNN validation R2: -0.027885094030296598
#
# Training Loss 0.8505322337150574, Trainging R-squared -0.08444505828035537
#
# CNN validation R2: -0.01480266173283784
#
# Training Loss 0.8656431436538696, Trainging R-squared -0.5595288439817695
#
# CNN validation R2: -0.0057944214803296035
#
# Training Loss 0.8519496619701385, Trainging R-squared -0.31726782568146017
#
# CNN validation R2: 0.0011656422879969264
#
# Training Loss 0.8446347415447235, Trainging R-squared -0.20143243430095348
#
# CNN validation R2: 0.005474909438536346
#
# Training Loss 0.8549472093582153, Trainging R-squared -0.05215820762081175
#
# ...
#
# CNN validation R2: 0.08885846765877525
#
# Training Loss 0.8336535096168518, Trainging R-squared 0.18965902726816206
#
# CNN validation R2: 0.09076501893069738
#
# Training Loss 0.8302547931671143, Trainging R-squared 0.25026570838193773
#
# CNN validation R2: 0.09135477535250325
#
# Training Loss 0.8326235711574554, Trainging R-squared 0.25874459418888995
#
# CNN validation R2: 0.09310658116188664
#
# Training Loss 0.8318729102611542, Trainging R-squared 0.2770626624229329
#
# CNN validation R2: 0.09729808602948792
#
# Training Loss 0.8266364932060242, Trainging R-squared 0.2755020041365325
#
# CNN validation R2: 0.1016502889950231
#
# Training Loss 0.8322787880897522, Trainging R-squared 0.24985309011534348
#
# CNN validation R2: 0.10290083926720212
#
# Training Loss 0.8279774785041809, Trainging R-squared 0.29325278168324476
#
# CNN validation R2: 0.1103001640061605
#
# Training Loss 0.8300618529319763, Trainging R-squared 0.2778628341524688
#
# CNN validation R2: 0.10828905385868803
#
# Training Loss 0.8387805223464966, Trainging R-squared 0.10251837475126549
#
# CNN validation R2: 0.10993310518565574
#
# Training Loss 0.8252691924571991, Trainging R-squared 0.35331597752727834
#
# CNN validation R2: 0.10697347504342697
#
# Training Loss 0.8355692327022552, Trainging R-squared 0.2105603701136167
#
# CNN validation R2: 0.10100750059024721
#
# Training Loss 0.8334893584251404, Trainging R-squared 0.22073947839079971
#
# CNN validation R2: 0.09697922932219338
#
# Training Loss 0.8282184302806854, Trainging R-squared 0.3572063443344463
#
# CNN validation R2: 0.09514885026113068
#
# Training Loss 0.8347479999065399, Trainging R-squared 0.2465233186271525
#
# CNN validation R2: 0.09878091513279236
#
# Training Loss 0.8269898295402527, Trainging R-squared 0.3173419909892957
#
# CNN validation R2: 0.11197896098938476
#
# Training Loss 0.8308836221694946, Trainging R-squared 0.23373522812930098
#
# CNN validation R2: 0.12320479301860071
#
# Training Loss 0.8300663828849792, Trainging R-squared 0.24499340636755434
#
# CNN validation R2: 0.1288216713161499
#
# Training Loss 0.8286947011947632, Trainging R-squared 0.36707417363665557
#
# CNN validation R2: 0.12883621558382435
#
# Training Loss 0.8296988010406494, Trainging R-squared 0.3787463926700322
#
# CNN validation R2: 0.13055478329376624
#
# Training Loss 0.8328843712806702, Trainging R-squared 0.349758404443861
#
# CNN validation R2: 0.1315661240268009
#
# Training Loss 0.842011958360672, Trainging R-squared 0.11329275519811599
#
# CNN validation R2: 0.1384603848124354
#
# Training Loss 0.8324907124042511, Trainging R-squared 0.06753698423439289
#
# CNN validation R2: 0.13134745079840826
#
# Training Loss 0.8317892551422119, Trainging R-squared 0.27963116202653593
#
# CNN validation R2: 0.12722715276831986
#
# Training Loss 0.8286464810371399, Trainging R-squared 0.32857504316787156
#
# CNN validation R2: 0.13213553582163978
#
# Training Loss 0.8221940696239471, Trainging R-squared 0.4474259785284215
#
# CNN validation R2: 0.13323879567065905
#
# Training Loss 0.8330449163913727, Trainging R-squared 0.2920829305729228
#
# CNN validation R2: 0.12723197372813855
#
# Training Loss 0.8305823802947998, Trainging R-squared 0.28783432798528485
#
# CNN validation R2: 0.11544948391627802
#
# Training Loss 0.8249299228191376, Trainging R-squared 0.39028036117311915
#
# CNN validation R2: 0.11041321746943006
#
# Training Loss 0.824017733335495, Trainging R-squared 0.3565173644869044
#
# CNN validation R2: 0.11604304905558299
#
# Training Loss 0.8371272683143616, Trainging R-squared 0.057003348587661595
#
# CNN validation R2: 0.11736241303480416
#
# Training Loss 0.8268840610980988, Trainging R-squared 0.3704402316389813
#
# CNN validation R2: 0.11844621797105148
#
# Training Loss 0.8311043977737427, Trainging R-squared 0.2147157326594429
#
# CNN validation R2: 0.11865632697595901
#
# Training Loss 0.8279120624065399, Trainging R-squared 0.34857446671184933
#
# CNN validation R2: 0.1209476544325992
#
# Training Loss 0.8256317973136902, Trainging R-squared 0.3792789081437978
#
# CNN validation R2: 0.12790469174242425
#
# Training Loss 0.8280447721481323, Trainging R-squared 0.3483610846925045
#
# CNN validation R2: 0.1250680049605084
#
# Training Loss 0.825980544090271, Trainging R-squared 0.3132307093135881
#
# CNN validation R2: 0.12386403643025828
#
# Training Loss 0.8243307173252106, Trainging R-squared 0.39148195573868944
#
# CNN validation R2: 0.1191232190701394
#
# Training Loss 0.8262183964252472, Trainging R-squared 0.35043594526628524
#
# CNN validation R2: 0.11932929681116733
#
# Training Loss 0.8285686671733856, Trainging R-squared 0.27382690290658346
#
# CNN validation R2: 0.12618934078641325
#
# Training Loss 0.8231927752494812, Trainging R-squared 0.36686910250681126
#
# CNN validation R2: 0.12763220531919395
#
# Training Loss 0.826563149690628, Trainging R-squared 0.3877173789618866
#
# CNN validation R2: 0.13003922178916172
#
# Training Loss 0.8266085386276245, Trainging R-squared 0.30317998884746655
#
# CNN validation R2: 0.13477088041857405
#
# Training Loss 0.83118537068367, Trainging R-squared 0.2554430300739142
#
# CNN validation R2: 0.13863289995997513
#
# Training Loss 0.8305386006832123, Trainging R-squared 0.35873019365383896
#
# CNN validation R2: 0.14453384205405484
#
# Training Loss 0.8225512504577637, Trainging R-squared 0.4358077201652194
#
# CNN validation R2: 0.15004243038731974
#
# Training Loss 0.8256997764110565, Trainging R-squared 0.39232893962001
#
# CNN validation R2: 0.1509144780570184
#
# Training Loss 0.8276183605194092, Trainging R-squared 0.1744993753963052
#
# CNN validation R2: 0.14765086704134284
#
# Training Loss 0.8270990550518036, Trainging R-squared 0.371936321548193
#
# CNN validation R2: 0.1481189671712464
#
# Training Loss 0.8235781788825989, Trainging R-squared 0.3894258361670249
#
# CNN validation R2: 0.15293294278262431
#
# Training Loss 0.8319112956523895, Trainging R-squared 0.2990163187752706
#
# CNN validation R2: 0.1614760438253809
#
# Training Loss 0.8258172869682312, Trainging R-squared 0.3114148693426163
#
# CNN validation R2: 0.15845296802987746
#
# Training Loss 0.822858065366745, Trainging R-squared 0.45213840271937844
#
# CNN validation R2: 0.1507283615978049
#
# Training Loss 0.827276349067688, Trainging R-squared 0.3799225064318933
#
# CNN validation R2: 0.151078007018271
#
# Training Loss 0.8256670832633972, Trainging R-squared 0.43055987381431504
#
# CNN validation R2: 0.15954543786895903
#
# Training Loss 0.8194038271903992, Trainging R-squared 0.4692655132123337
#
# CNN validation R2: 0.1595355856677369
#
# Training Loss 0.8245886862277985, Trainging R-squared 0.43086232063047086
#
# CNN validation R2: 0.15830525092400627
#
# Training Loss 0.8189212679862976, Trainging R-squared 0.43273088746864924
#
# CNN validation R2: 0.15226907997341144
#
# Training Loss 0.825913667678833, Trainging R-squared 0.35190100952543457
#
# CNN validation R2: 0.14919556787543603
#
# Training Loss 0.826297402381897, Trainging R-squared 0.28274482276136065
#
# CNN validation R2: 0.15498810858573203
#
# Training Loss 0.8228941559791565, Trainging R-squared 0.4652563896557096
#
# CNN validation R2: 0.16496679379773732
#
# Training Loss 0.8229537904262543, Trainging R-squared 0.4291310010936972
#
# CNN validation R2: 0.17021106870817793
#
# Training Loss 0.820859968662262, Trainging R-squared 0.4205081390464199
#
# CNN validation R2: 0.16879854322130844
#
# Training Loss 0.8263068795204163, Trainging R-squared 0.27501119486142356
#
# CNN validation R2: 0.1663615123083675
#
# Training Loss 0.8316403925418854, Trainging R-squared 0.20809220732030598
#
# CNN validation R2: 0.15801830796678984
#
# Training Loss 0.8219491839408875, Trainging R-squared 0.36219268022448675
#
# CNN validation R2: 0.1487645560445115
#
# Training Loss 0.8174740970134735, Trainging R-squared 0.47646034297717965
#
# CNN validation R2: 0.14922753406022027
#
# Training Loss 0.8171789348125458, Trainging R-squared 0.4924169981486168
#
# CNN validation R2: 0.15965668660530558
#
# Training Loss 0.8202723562717438, Trainging R-squared 0.34200066006721286
#
# CNN validation R2: 0.1662341735872323
#
# Training Loss 0.8219304084777832, Trainging R-squared 0.4092883784084208
#
# CNN validation R2: 0.16516972368615712
#
# Training Loss 0.8314008712768555, Trainging R-squared 0.35392751866702843
#
# CNN validation R2: 0.1690421251619198
#
# Training Loss 0.8220763206481934, Trainging R-squared 0.4056386469773294
#
# CNN validation R2: 0.17054980099370054
#
# Training Loss 0.824998140335083, Trainging R-squared 0.4372531300281466
#
# CNN validation R2: 0.17484379383543175
#
# Training Loss 0.8208776712417603, Trainging R-squared 0.4633849137062637
#
# CNN validation R2: 0.18167895817918472
#
# Training Loss 0.8206643164157867, Trainging R-squared 0.448838069050141
#
# CNN validation R2: 0.18694484778600384
#
# Training Loss 0.826384425163269, Trainging R-squared 0.42037728376226896
#
# CNN validation R2: 0.18109109780461263
#
# Training Loss 0.8223165571689606, Trainging R-squared 0.4249486971473745
#
# CNN validation R2: 0.17707198978763317
#
# Training Loss 0.8228885233402252, Trainging R-squared 0.3121754693672507
#
# CNN validation R2: 0.17422537145196154
#
# Training Loss 0.8181599378585815, Trainging R-squared 0.36619072562683797
#
# CNN validation R2: 0.1711768187783811
#
# Training Loss 0.8209491074085236, Trainging R-squared 0.4547279243817265
#
# CNN validation R2: 0.16728204740641794
#
# Training Loss 0.8259285986423492, Trainging R-squared 0.3411437657271732
#
# CNN validation R2: 0.15810473266010483
#
# Training Loss 0.8257677555084229, Trainging R-squared 0.31009407161457603
#
# CNN validation R2: 0.1526832953334203
#
# Training Loss 0.822725385427475, Trainging R-squared 0.4336012280579409
#
# CNN validation R2: 0.168387457801777
#
# Training Loss 0.8204423189163208, Trainging R-squared 0.45958235514396584
#
# CNN validation R2: 0.17957892558747424
#
# Training Loss 0.81551793217659, Trainging R-squared 0.5643685960046203
#
# CNN validation R2: 0.1875490173118775
#
# Training Loss 0.8252754807472229, Trainging R-squared 0.40099295585087225
#
# CNN validation R2: 0.17716229517701165
#
# Training Loss 0.8179509937763214, Trainging R-squared 0.47622379517493185
#
# CNN validation R2: 0.15767465859306984
#
# Training Loss 0.819871723651886, Trainging R-squared 0.4315978375522096
#
# CNN validation R2: 0.1494640921745874
#
# Training Loss 0.8228254020214081, Trainging R-squared 0.4716933548458898
#
# CNN validation R2: 0.15709427921266572
#
# Training Loss 0.819742739200592, Trainging R-squared 0.45673852734898923
#
# CNN validation R2: 0.16511984151319725
#
# Training Loss 0.8176881372928619, Trainging R-squared 0.4675871942723637
#
# CNN validation R2: 0.17945040592453054
#
# Training Loss 0.820075511932373, Trainging R-squared 0.42774246345826666
#
# CNN validation R2: 0.1941751094412727
#
# Training Loss 0.8202452659606934, Trainging R-squared 0.36767703633786375
#
# CNN validation R2: 0.2083805361257185
#
# Training Loss 0.8166610896587372, Trainging R-squared 0.47852676567547325
#
# CNN validation R2: 0.2069619085431766
#
# Training Loss 0.8153960108757019, Trainging R-squared 0.5711675331695494
#
# CNN validation R2: 0.19867059483369637
#
# Training Loss 0.8129261136054993, Trainging R-squared 0.5935855290257798
#
# CNN validation R2: 0.18473279758219102
#
# Training Loss 0.81964111328125, Trainging R-squared 0.4713880726526385
#
# CNN validation R2: 0.17737516699315165
#
# Training Loss 0.8151719570159912, Trainging R-squared 0.5413827721173703
#
# CNN validation R2: 0.1784171663497815
#
# Training Loss 0.8208011984825134, Trainging R-squared 0.4716618438569995
#
# CNN validation R2: 0.18476926266125848
#
# Training Loss 0.8217451572418213, Trainging R-squared 0.5158527331445435
#
# CNN validation R2: 0.1851948592546564
#
# Training Loss 0.8222309350967407, Trainging R-squared 0.4225308534443562
#
# CNN validation R2: 0.18995009504821536
#
# Training Loss 0.8161411583423615, Trainging R-squared 0.5449305150149623
#
# CNN validation R2: 0.18974695401670294
#
# Training Loss 0.8165619671344757, Trainging R-squared 0.5262539410144549
#
# CNN validation R2: 0.19528324134648994
#
# Training Loss 0.8209254145622253, Trainging R-squared 0.4225156461597561
#
# CNN validation R2: 0.19255957155203113
#
# Training Loss 0.8196823000907898, Trainging R-squared 0.46681412632130803
#
# CNN validation R2: 0.18961842645761184
#
# Training Loss 0.819524496793747, Trainging R-squared 0.4218825736904184
#
# CNN validation R2: 0.19970545669766504
#
# Training Loss 0.825921356678009, Trainging R-squared 0.40034178008271437
#
# CNN validation R2: 0.198033101663665
#
# Training Loss 0.8165403008460999, Trainging R-squared 0.4983063169851
#
# CNN validation R2: 0.19376612437517665
#
# Training Loss 0.8213163912296295, Trainging R-squared 0.3540087267804659
#
# CNN validation R2: 0.18536784084806263
#
# Training Loss 0.8157739341259003, Trainging R-squared 0.5418564862321759
#
# CNN validation R2: 0.17461072632600055
#
# Training Loss 0.8166617751121521, Trainging R-squared 0.5416891192322011
#
# CNN validation R2: 0.18089956753411934
#
# Training Loss 0.8215878307819366, Trainging R-squared 0.3114126902146329
#
# CNN validation R2: 0.19383147201203715
#
# Training Loss 0.8154983222484589, Trainging R-squared 0.4274705240264678
#
# CNN validation R2: 0.19742182934613123
#
# Training Loss 0.8164218366146088, Trainging R-squared 0.5172956171924079
#
# CNN validation R2: 0.18996219320422725
#
# Training Loss 0.815323680639267, Trainging R-squared 0.5160062674115813
#
# CNN validation R2: 0.18387954769778758
#
# Training Loss 0.8172915875911713, Trainging R-squared 0.4907927980385004
#
# CNN validation R2: 0.18036887112430344
#
# Training Loss 0.817955732345581, Trainging R-squared 0.3984384476917394
#
# CNN validation R2: 0.18118763393279091
#
# Training Loss 0.8151350617408752, Trainging R-squared 0.5384754611758021
#
# CNN validation R2: 0.18676066257724772
#
# Training Loss 0.8226690590381622, Trainging R-squared 0.4277212886842764
#
# CNN validation R2: 0.1889382740616236
#
# Training Loss 0.8225516378879547, Trainging R-squared 0.27919239451840794
#
# CNN validation R2: 0.18939616192640935
#
# Training Loss 0.8194097876548767, Trainging R-squared 0.43833041892309715
#
# CNN validation R2: 0.19163502957207162
#
# Training Loss 0.8153053820133209, Trainging R-squared 0.509262474521766
#
# CNN validation R2: 0.1954294885754746
#
# Training Loss 0.8158042430877686, Trainging R-squared 0.5476295860041069
#
# CNN validation R2: 0.19551701602666366
#
# Training Loss 0.8175580203533173, Trainging R-squared 0.4571204034342955
#
# CNN validation R2: 0.19507978373273244
#
# Training Loss 0.8185569047927856, Trainging R-squared 0.5067680373515359
#
# CNN validation R2: 0.19215789733244387
#
# Training Loss 0.8193609416484833, Trainging R-squared 0.4672958981008906
#
# CNN validation R2: 0.18983356309700405
#
# Training Loss 0.816793829202652, Trainging R-squared 0.4663619718318116
#
# CNN validation R2: 0.18515003223620785
#
# Training Loss 0.819987952709198, Trainging R-squared 0.40651103357650875
#
# CNN validation R2: 0.18969649091841584
#
# Training Loss 0.8202058970928192, Trainging R-squared 0.4679262225226797
#
# CNN validation R2: 0.19728207638614897
#
# Training Loss 0.8117078542709351, Trainging R-squared 0.6294718308892844
#
# CNN validation R2: 0.19899868270579485
#
# Training Loss 0.8198787569999695, Trainging R-squared 0.4901950458128248
#
# CNN validation R2: 0.19668618414241018
#
# Training Loss 0.8187958598136902, Trainging R-squared 0.4979339897862122
#
# CNN validation R2: 0.1936719461404633
#
# Training Loss 0.8169671297073364, Trainging R-squared 0.505233367612194
#
# CNN validation R2: 0.19063033452927836
#
# Training Loss 0.8197830617427826, Trainging R-squared 0.4828279678560512
#
# CNN validation R2: 0.18579859514383518
#
# Training Loss 0.817268580198288, Trainging R-squared 0.5044875076201123
#
# CNN validation R2: 0.1902103357578553
#
# Training Loss 0.81698077917099, Trainging R-squared 0.540319405039655
#
# CNN validation R2: 0.19143737330231952
#
# Training Loss 0.8217568695545197, Trainging R-squared 0.5012188451260086
#
# CNN validation R2: 0.19341811678687187
#
# Training Loss 0.8108744323253632, Trainging R-squared 0.5717823387327327
#
# CNN validation R2: 0.1913726099613442
#
# Training Loss 0.813570499420166, Trainging R-squared 0.5857826856800423
#
# CNN validation R2: 0.18093956465053246
#
# Training Loss 0.8155823647975922, Trainging R-squared 0.5494623278507
#
# CNN validation R2: 0.17037130235051062

# %%
r2 = []
r2_r = []
r2_v = []
for best_model, m, std in models:
    i = 0
    # best_model=models[1]
    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    best_model.eval()
    for inputs, labels in test_loader:
        inputs = ((inputs.reshape(-1,1,dim,20)-m)/std).to(device)
        labels = labels.to(device)
        if i == 0:
            cnnOutputs = best_model(inputs).to('cpu')
            l = labels.to('cpu')
        else:
            cnnOutputs = torch.cat((cnnOutputs, best_model(inputs).to('cpu')), 0)
            l = torch.cat((l, labels.to('cpu')), 0)
        i+=1
    r2_v.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy()[:,1], cnnOutputs.to('cpu').detach().numpy()[:,1]))
    r2_r.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy()[:,0], cnnOutputs.to('cpu').detach().numpy()[:,0]))
    r2.append(sklearn.metrics.r2_score(l.to('cpu').detach().numpy(), cnnOutputs.to('cpu').detach().numpy()))

# %%
np.mean(r2)
# Out:
# -0.0015366657230377779

# %%
np.mean(r2_v)
# Out:
# -0.1777840330997134

# %%
np.mean(r2_r)
# Out:
# 0.1747106743685461

# %%
print("Average R2: {}, Arousal R2: {}, Valence R2: {}".format(np.mean(r2), np.mean(r2_r), np.mean(r2_v)))
# Out:
# Average R2: -0.0015366657230377779, Arousal R2: 0.1747106743685461, Valence R2: -0.1777840330997134
